# %%
import nltk

# %%
import nltk
nltk.download()

# %% [markdown]
# # Tokenizar Texto

# %%
# LEER TEXTO DESDE URL

from bs4 import BeautifulSoup
 
import urllib.request
  
response = urllib.request.urlopen('https://librefinanciero.com') #Obtiene el contenido HTML de la página web http://librefinanciero.com/
 
html = response.read()
 
soup = BeautifulSoup(html,"html5lib") # Limpia el texto HTML capturado
 
text = soup.get_text(strip=True)
 
print (text)
# Out:
# .heateorSssInstagramBackground{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 											.heateor_sss_horizontal_sharing .heateorSssSharing,.heateor_sss_standard_follow_icons_container .heateorSssSharing{
# 							color: #fff;
# 						border-width: 0px;
# 			border-style: solid;
# 			border-color: transparent;
# 		}
# 				.heateor_sss_horizontal_sharing .heateorSssTCBackground{
# 			color:#666;
# 		}
# 				.heateor_sss_horizontal_sharing .heateorSssSharing:hover,.heateor_sss_standard_follow_icons_container .heateorSssSharing:hover{
# 						border-color: transparent;
# 		}
# 		.heateor_sss_vertical_sharing .heateorSssSharing,.heateor_sss_floating_follow_icons_container .heateorSssSharing{
# 							color: #fff;
# 						border-width: 0px;
# 			border-style: solid;
# 			border-color: transparent;
# 		}
# 				.heateor_sss_vertical_sharing .heateorSssTCBackground{
# 			color:#666;
# 		}
# 				.heateor_sss_vertical_sharing .heateorSssSharing:hover,.heateor_sss_floating_follow_icons_container .heateorSssSharing:hover{
# 						border-color: transparent;
# 		}
#
# 		@media screen and (max-width:783px) {.heateor_sss_vertical_sharing{display:none!important}}@media screen and (max-width:783px) {.heateor_sss_floating_follow_icons_container{display:none!important}}div.heateor_sss_mobile_footer{display:none;}@media screen and (max-width:783px){i.heateorSssTCBackground{background-color:white!important}div.heateor_sss_bottom_sharing{width:100%!important;left:0!important;}div.heateor_sss_bottom_sharing li{width:14.285714285714% !important;}div.heateor_sss_bottom_sharing .heateorSssSharing{width: 100% !important;}div.heateor_sss_bottom_sharing div.heateorSssTotalShareCount{font-size:1em!important;line-height:28px!important}div.heateor_sss_bottom_sharing div.heateorSssTotalShareText{font-size:.7em!important;line-height:0px!important}div.heateor_sss_mobile_footer{display:block;height:40px;}.heateor_sss_bottom_sharing{padding:0!important;display:block!important;width: auto!important;bottom:-2px!important;top: auto!important;}.heateor_sss_bottom_sharing .heateor_sss_square_count{line-height: inherit;}.heateor_sss_bottom_sharing .heateorSssSharingArrow{display:none;}.heateor_sss_bottom_sharing .heateorSssTCBackground{margin-right: 1.1em !important}}🥇Alcanza la Libertad Financiera y Retírate🥇 | 【Libre Financiero】{"@context":"https://schema.org","@graph":[{"@type":["Person","Organization"],"@id":"https://librefinanciero.com/#/schema/person/eac2ac957f89526d68f1baa1de35a76b","name":"Iv\u00e1n_LF","image":{"@type":"ImageObject","@id":"https://librefinanciero.com/#personlogo","inLanguage":"en-US","url":"https://secure.gravatar.com/avatar/546a137bb72d3d2a3175321274b534ca?s=96&d=mm&r=g","caption":"Iv\u00e1n_LF"},"logo":{"@id":"https://librefinanciero.com/#personlogo"}},{"@type":"WebSite","@id":"https://librefinanciero.com/#website","url":"https://librefinanciero.com/","name":"\u3010Libre Financiero - Alcanza la Independencia y Ret\u00edrate\u3011","description":"","publisher":{"@id":"https://librefinanciero.com/#/schema/person/eac2ac957f89526d68f1baa1de35a76b"},"potentialAction":[{"@type":"SearchAction","target":"https://librefinanciero.com/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://librefinanciero.com/#primaryimage","inLanguage":"en-US","url":"https://librefinanciero.com/wp-content/uploads/2019/04/Cabecera-v3-jpg.jpg","width":2000,"height":608,"caption":"Libertad Financiera"},{"@type":"WebPage","@id":"https://librefinanciero.com/#webpage","url":"https://librefinanciero.com/","name":"\ud83e\udd47Alcanza la Libertad Financiera y Ret\u00edrate\ud83e\udd47 | \u3010Libre Financiero\u3011","isPartOf":{"@id":"https://librefinanciero.com/#website"},"about":{"@id":"https://librefinanciero.com/#/schema/person/eac2ac957f89526d68f1baa1de35a76b"},"primaryImageOfPage":{"@id":"https://librefinanciero.com/#primaryimage"},"datePublished":"2019-03-29T20:59:50+00:00","dateModified":"2020-09-10T09:08:31+00:00","description":"\u00bfQuieres alcanzar la Libertad Financiera y tener la vida que deseas? \u21e8 S\u00ed que se puede y en este blog encontrar\u00e1s las respuestas\u2705","inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://librefinanciero.com/"]}]}]}(window.gaDevIds=window.gaDevIds||[]).push("dZGIzZG");
# 	var mi_version         = '7.12.3';
# 	var mi_track_user      = true;
# 	var mi_no_track_reason = '';
#
# 	var disableStr = 'ga-disable-UA-137899195-1';
#
# 	/* Function to detect opted out users */
# 	function __gaTrackerIsOptedOut() {
# 		return document.cookie.indexOf(disableStr + '=true') > -1;
# 	}
#
# 	/* Disable tracking if the opt-out cookie exists. */
# 	if ( __gaTrackerIsOptedOut() ) {
# 		window[disableStr] = true;
# 	}
#
# 	/* Opt-out function */
# 	function __gaTrackerOptout() {
# 	  document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 	  window[disableStr] = true;
# 	}
#
# 	if ( 'undefined' === typeof gaOptout ) {
# 		function gaOptout() {
# 			__gaTrackerOptout();
# 		}
# 	}
#
# 	if ( mi_track_user ) {
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 			(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 			m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','__gaTracker');
#
# 		__gaTracker('create', 'UA-137899195-1', 'auto');
# 		__gaTracker('set', 'forceSSL', true);
# 		__gaTracker('require', 'displayfeatures');
# 		__gaTracker('require', 'linkid', 'linkid.js');
# 		__gaTracker('send','pageview');
# 	} else {
# 		console.log( "" );
# 		(function() {
# 			/* https://developers.google.com/analytics/devguides/collection/analyticsjs/ */
# 			var noopfn = function() {
# 				return null;
# 			};
# 			var noopnullfn = function() {
# 				return null;
# 			};
# 			var Tracker = function() {
# 				return null;
# 			};
# 			var p = Tracker.prototype;
# 			p.get = noopfn;
# 			p.set = noopfn;
# 			p.send = noopfn;
# 			var __gaTracker = function() {
# 				var len = arguments.length;
# 				if ( len === 0 ) {
# 					return;
# 				}
# 				var f = arguments[len-1];
# 				if ( typeof f !== 'object' || f === null || typeof f.hitCallback !== 'function' ) {
# 					console.log( 'Not running function __gaTracker(' + arguments[0] + " ....) because you are not being tracked. " + mi_no_track_reason );
# 					return;
# 				}
# 				try {
# 					f.hitCallback();
# 				} catch (ex) {
#
# 				}
# 			};
# 			__gaTracker.create = function() {
# 				return new Tracker();
# 			};
# 			__gaTracker.getByName = noopnullfn;
# 			__gaTracker.getAll = function() {
# 				return [];
# 			};
# 			__gaTracker.remove = noopfn;
# 			window['__gaTracker'] = __gaTracker;
# 					})();
# 		}window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/librefinanciero.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.5.3"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }.has-text-align-justify{text-align:justify;}#wplp_widget_840.wplp_container.default:hover .flex-next,#wplp_widget_840.wplp_container .flex-direction-nav .flex-prev{color : rgb(51, 51, 51) !important}#wplp_widget_840.wplp_container.default:hover .flex-next:hover,#wplp_widget_840.wplp_container.default:hover .flex-prev:hover{color :rgb(54, 54, 54) !important}#wplp_widget_840.wplp_container .read-more{float:right;background-color : transparent}#wplp_widget_840.wplp_container .read-more{border :1px solid transparent;border-radius: 2px;}#wplp_widget_840.wplp_container .read-more{color : #1e73be}#wplp_widget_840.wplp_container .read-more{padding: 3px 7px}#wplp_widget_840 .wplp_listposts li.parent ul li:hover .img_cropper:before,#wplp_widget_840 .wplp_listposts li.parent ul li:hover .img_cropper:after {opacity:0}#wplp_widget_840 .wplp_listposts li .img_cropper:after {background:transparent;-webkit-box-shadow: inset 0 0 10px 2px transparent;box-shadow: inset 0 0 10px 2px transparent;}#wplp_widget_840 .wplp_listposts li .img_cropper:before{content:'\f109';}#wplp_widget_840 .wplp_listposts li .img_cropper:before{color:#ff0000}#wplp_widget_840 .wplp_listposts li .img_cropper:before{background:#2C8FC7}#wplp_widget_840 .wplp_listposts li .img_cropper:before {content: none ;}/* <![CDATA[ */
# var monsterinsights_frontend = {"js_events_tracking":"true","download_extensions":"doc,pdf,ppt,zip,xls,docx,pptx,xlsx","inbound_paths":"[{\"path\":\"\\\/go\\\/\",\"label\":\"affiliate\"},{\"path\":\"\\\/recommend\\\/\",\"label\":\"affiliate\"}]","home_url":"https:\/\/librefinanciero.com","hash_tracking":"false"};
# /* ]]> *//* <![CDATA[ */
# var GDPR = {"ajaxurl":"https:\/\/librefinanciero.com\/wp-admin\/admin-ajax.php","logouturl":"","i18n":{"aborting":"Aborting","logging_out":"You are being logged out.","continue":"Continue","cancel":"Cancel","ok":"OK","close_account":"Close your account?","close_account_warning":"Your account will be closed and all data will be permanently deleted and cannot be recovered. Are you sure?","are_you_sure":"Are you sure?","policy_disagree":"By disagreeing you will no longer have access to our site and will be logged out."},"is_user_logged_in":"","refresh":"1"};
# /* ]]> *//* <![CDATA[ */
# var WPLP_840 = {"id":"840","pagination":"2","autoanimate":"0","autoanimatetrans":"1","animationloop":"1","slideshowspeed":"0","slidespeed":"0","pausehover":"1","pauseaction":"1","slidedirection":"0","touch":"1"};
# /* ]]> */img#wpstats{display:none}.header-content,.main-navigation ul#primary-menu ul{background: #dddddd; }
# .main-navigation ul ul li{border-bottom:#dddddd; }
#
# .main-navigation ul li a,.main-navigation ul li ul a{color:#000000;}
# .header-search .search-field:focus, .header-search .search-field:active{color:#000000;}
#
# .main-navigation ul ul.sub-menu a:hover{background:  #dddddd;}
# .main-navigation .current-menu-item a, .header-content .pulito-clean-blog-lite-sn a:hover, .header-content .pulito-clean-blog-lite-sn a:focus, .header-content .pulito-clean-blog-lite-sn a:active{color:#0039f4;}
# .main-navigation a:hover, .main-navigation .current-menu-item .children a:hover, .main-navigation .current-menu-item .sub-menu a:hover { color: #0039f4;}
#
# .entry-content .link-more a.more-link{	color: #000}
# .entry-content .link-more a.more-link:hover,.site-content .hentry.format-quote a.more-link:hover{color: #08f;}
# h2.entry-title a:hover, .site-content a:hover, .site-content a:active, .site-content .hentry.format-quote a:hover{color: #08f;}
# .widget ul li a{color: #0c0c0c;}
# .widget ul li a:hover{color: #08f;}
# h1,h1.entry-title{	color: #2463e2;}
# h2, h2.page-title, h2.entry-title a:link, h2 a, h2 a:visited{	color: #218cd3;}
# h3, footer h3{color: #000000;}
# h4{	color: #000000;}
# h5{	color: #000000;}
# h6{	color: #000000;}.heading_red{
# 	color:red;
# }
#
# .heading_gray{
# 	color:gray;
# }
#
# .heading_yellow{
# 	color:gold;
# }
#
# .heading_blue{
# 	color:#00BFFF;
# }
#
# .heading_green{
# 	color:#32CD32;
# }
#
# .heading_orange{
# 	color:orange;
# }
#
# .heading_green2{
# 	color:#008000;
# }
#
# .imagen_e2e{
# 	left: 0px;
# 	width: 2500px;
# 	padding-right:0px;
# 	position:relative;
# 	}
#
# .tags-links{
# 	display:none;
# }
#
# .mc4wp-form-fields{
# 	border-bottom-color:red;
# 	align-content:center!important;
# }
#
# .attachment-post-thumbnail {display: none}Skip to contentMenuInicio¡Empieza Aquí!Pasos a SeguirPaso 1: Calcula tu salario/hora REALPaso 2: Controla y Categoriza tus Ingresos y Gastos PersonalesPaso 3: Valora tus GastosPaso 4: Visualiza tu Estado Financiero PersonalPaso 5: Reduce tus Gastos y Aumenta tus IngresosPaso 6: Añade tus Inversiones a la fotoPaso 7: El “Punto de Corte” de la Independencia FinancieraEstrategias de InversiónInversión en Renta Fija & Renta VariableInversión en Préstamos P2P – CrowlendingInversión en Desarrollo PersonalBlogLibros RecomendadosSobre Mí¿Estás interesado en seguir gastando 10-12 horas diarias de tu energía en un trabajo hasta que un día consigas jubilarte a los 70 años en el mejor de los casos?Si la respuesta es SÍ, entonces este NO es tu blog, en caso contrario, bienvenido a la comunidadLibreFinancierodonde aprenderás qué es la libertad financiera y cómo ponerla en práctica.PERO… ¿QUÉ ES LA INDEPENDENCIA FINANCIERA?La independencia o libertad financiera no significa tener un trabajo estable o hacerse rico, la independencia financiera es alcanzar una situación en la queNOdependas de intercambiar tu tiempo por dinero, sino conseguir que tu dinero trabaje para ti y cubrir tu estilo de vida.ESPERA, ESPERA, ¿VOY A TENER QUE CAMBIAR MI ESTILO DE VIDA?Lo que
# probablemente tengas que hacer es ajustar tu estilo de vida para aprovechar lo
# que realmente importa en lugar de gastar dinero inconscientemente como la
# mayoría de las personas en países avanzados hacemos.Es importante que entiendas que obtener la independencia financieraNOdepende de tu profesión, sino de la“Tasa de ahorro”calculada como la diferencia entre tus ingresos y tus gastos, pero sobre todo de los gastos como te demostraré en este blog.¿CUÁL ES EL OBJETIVO DE ESTE BLOG DE LIBERTAD FINANCIERA?Este
# blog no trata de venderte nada, sino compartir información para poder salir de
# la esclavitud del siglo XXI y dejar de depender del intercambio de tu energía
# (tiempo) por dinero.Si lo que quieres es un lugar donde puedas aprender técnicas para salir de este círculo y que un día te olvides del trabajo que te consume 10-12 horas diarias de tu energía sumando el trabajo activo, los desplazamientos hacia el trabajo, el tiempo para poder desconectar,… has llegado al lugar adecuado.¿CÓMO CONSEGUIREMOS LA LIBERTAD FINANCIERA?Conseguir la independencia financiera no es un camino sencillo, no hay ninguna panacea (y el que te diga lo contrario te está mintiendo), es un camino de consistencia y tener un objetivo claro para salir de lo que se llama“la carrera de la rata”, es decir, dejar de realimentar el círculo vicioso en el que, en la mayoría de los casos, estamos sumergidos:Círculo Carrera de la Rata © LibreFinanciero.comEs
# Sí, es totalmente cierto, en la época en la que estamos, prácticamente cualquier activo se está devaluando, pero nuestro enfoque financiero es la inversión consistente a largo plazo, tenemos que ver el momento actual como una oportunidad de compra y seguir en el mercado.
#
#
#
# La clave del éxito es superar emocionalmente ese momento de tensión cuando estamos viendo bajar nuestras inversiones y NO vender, sino hacer justo lo contrario. En este post lo explico con mucho más detalle, pero a modo de referencia para que veas la devaluación de diferentes índices bursátiles:
#
#
#
# Evolución S&P500
#
#
#
# Evolución Euro Stoxx 50
#
#
#
# Resumen índices bursátiles
#
#
#
# Es decir, por ejemplo en el momento mínimo del índice S&P500 tras la aparición del COVID-19, podríamos haber adquirido el mismo activo por un 33,8% menos. Esto dicho así sería muy ventajista y obviamente no queremos caer en la especulación, sería muy difícil haber acertado justo el momento mínimo, pero también es cierto que si nuestra estrategia está basada en la inversión consistente de manera mensual, es muy probable que nos hayamos aprovechado de esta situación.
#
#
#
# Para poner un escenario basado en los últimos meses, vamos a ver la misma comparativa utilizando el promedio de la media móvil de los últimos 3 meses:
#
#
#
# Resumen índices bursátiles – Diferencia M.A.
#
#
#
# En este caso, lo que vemos es que en estos últimos 3 meses nos habríamos aprovechado de obtener el mismo activo con un 14,8% de rebaja en el caso del S&P500 y un 23,1% en el caso del EURO STOXX 50 (de hecho, con una estrategia de inversión mensual te hubieras aprovechado en varias ocasiones).
#
#
#
# Ya sabemos que en la bolsa, rentabilidades pasadas no garantizan rentabilidades futuras, de hecho es probable que siga habiendo vaivenes en el mercado, pero lo importante es que consigamos mantenernos firmes y no desistir de nuestra estrategia largoplacista. Recuerda que “tiempo en el mercado” (estrategia largo plazo) siempre vencerá a “temporizar al mercado” (especulación).
#
#
#
# ¿Cómo impacta una crisis del mercado en cada fase de la libertad financiera?
#
#
#
# Como ya sabemos, a grandes rasgos existen 2 fases bien diferenciadas en el enfoque de la libertad financiera:
#
#
#
# Fase 1 Acumulación: Periodo durante el cual estamos acumulando riqueza a través de diferentes activos. Si seguimos la regla del 4%, el objetivo es conseguir un portfolio valorado en 25 veces nuestros gastos anuales.Fase 2 Retirada: Periodo en el cual hemos alcanzado el valor objetivo a partir del cual podremos vivir de las rentabilidades que generan nuestros activos.
#
#
#
# Una crisis económica en la fase 1 de acumulación no deja de ser una oportunidad de compra para adquirir nuevos activos a precio de saldo, sin embargo, donde hay un mayor riesgo es en la fase 2 de retirada, puesto que para seguir manteniendo nuestro nivel de vida, es necesario “retirar” un mayor porcentaje de nuestra riqueza para cubrir los gastos. Vamos a verlo con un ejemplo:
#
#
#
# Gastos anuales: 15.000€Portfolio de activos necesario (regla 4%): 15.000€ x 25 = 375.000€
#
#
#
# Imaginemos que ya hemos alcanzado ese valor en nuestros activos, sabemos que a largo plazo un índice como el MSCI tiene un promedio de 6,7% anual, por tanto la situación normal en la fase de retirada es la siguiente tras 1 año:
#
#
#
# Valor portfolio: 375.000€ x (100% + 6,7%) = 400.125€Retirada de dinero: 15.000€ (3,7% del valor de nuestro portfolio)Valor portfolio final = 385.125€
#
#
#
# Esto es lo habitual considerando la rentabilidad a largo plazo promedio, hemos retirado 15.000€ para cubrir nuestros gastos y además el valor del portfolio es aún mayor.
#
#
#
# Pero ¿qué ocurre si cuando justo empezamos la fase de retirada hay una caída en el mercado? Pues que tras 1 año el resultado es el siguiente suponiendo que el mercado cae un 20%:
#
#
#
# Valor portfolio: 375.000€ x (100% – 20%) = 300.000€Retirada de dinero: 15.000€ (5% del valor de nuestro portfolio)Valor portfolio final = 285.000€
#
#
#
# Por lo tanto nuestro activo sufre un daño considerable puesto que retirar los 15.000€ que cubran nuestros gastos supone un peso porcentual mayor que en el escenario habitual.
#
#
#
# ¿Qué me recomiendas hacer para mitigar el riesgo si estoy en la fase de retirada y aparece una crisis económica?
#
#
#
# La solución inmediata es no retirar valor de tu portfolio durante la etapa de crisis financiera, pero claro, tienes que cubrir tus gastos, por tanto lo ideal es poder utilizar el fondo de emergencia que hemos comentado en otras ocasiones.
#
#
#
# Si vemos la evolución histórica de un índice de referencia como el MSCI World, se pueden identificar diferentes crisis fácilmente:
#
#
#
# Evolución MSCI World
#
#
#
# Analicemos cuál debería ser el fondo de emergencia, para ello podemos hacer un ejercicio donde simulemos qué hubiera ocurrido con nuestro portfolio si hubiéramos comenzado la fase de retirada en los diferentes años desde 1970 hasta 2010 y así verificar cuál sería el valor actual de nuestra cartera a cierre de año 2019, lo cual nos da un abanico de 40 simulaciones basándonos en los datos históricos.
#
#
#
# Escenario 1: Aplicamos la regla del 4%
#
#
#
# Si hubiéramos aplicado la regla del 4% anualmente independientemente de los vaivénes del mercado y considerando que, debido a la inflación y por tanto al aumento del coste de vida vamos a tener que aumentar la retirada de dinero en un 1% anualmente, el resultado hubiera sido el siguiente:
#
#
#
# Valor portfolio en función del año en el que comience la fase de retirada – Tasa 4%
#
#
#
# Como vemos, existen años en los que, si hubiéramos comenzado la fase de retirada, el valor del portfolico actual a cierre de 2019 hubiera estado por debajo del valor inicial (linea verde = 375.000€).
#
#
#
# Estadísticamente teniendo en cuenta estas simulaciones:
#
#
#
# Probabilidad de mantener o incrementar el portfolio = 54%Probabilidad de valor portfolio > 70% valor original = 66%
#
#
#
# Escenario 2: Optimizando la tasa de retirada
#
#
#
# Podemos optimizar la tasa de retirada para que en los años donde la renta variable es más adversa, la tasa de retirada sea inferior o nula (de ahí la necesidad del fondo de emergencia). Podemos por ejemplo tomar la siguiente fórmula tras explorar con diferentes combinaciones:
#
#
#
# Si rentabilidad < -5% –> Tasa de retirada 0%Si rentabilidad en rango  –> Tasa de retirada 2%Si rentabilidad > 0% –> Tasa de retirada 4%Máximo 2 años consecutivos con tasa de retirada 0% (en este caso, el 3er año aplicamos tasa de retirada del 4% independientemente de lo que haga el mercado)
#
#
#
# Con esta sencilla regla, esta hubiera sido la evolución de rentabilidad del índice MSCI y la tasa de retirada que hubiéramos aplicado:
#
#
#
# Tasa retirada optimizada
#
#
#
# Como vemos, la situación más adversa habría sucedido en los años 1973-1974 y 2000-2001 donde se habrían encadenado 2 años con tasa de retirada 0, de hecho en el año 2002 se hubiera activado la regla que habíamos puesto relativa a que no hubiera más de 2 años consecutivos con retirada 0.
#
#
#
# El resultado de las simulaciones sería:
#
#
#
# Valor portfolio en función del año en el que comience la fase de retirada – Tasa optimizada
#
#
#
# Estadísticamente teniendo en cuenta estas simulaciones con tasa de retirada optimizada:
#
#
#
# Probabilidad de mantener o incrementar el portfolio = 71%Probabilidad de valor portfolio > 70% valor original = 83%
#
#
#
# La situación de este escenario 2 es mucho más favorable como cabía esperar, puesto que en el 71% de las simulaciones mantenemos o incrementamos el portfolio.
#
#
#
# Por tanto, es una buena aproximación disponer de un fondo de emergencia que pueda cubrir 2 años de tus gastos si estamos pensando en comenzar la fase de retirada (y no dispones de ninguna otra fuente de ingresos).
#
#
#
# ¿Qué podemos aprender de una crisis respecto a nuestra situación finaciera?
#
#
#
# Si tenemos que coger una de las múltiples lecciones aprendidas, la clave está en la diversificación en el sentido más amplio de la palabra, es decir, disponer de múltiples fuentes de ingresos o bien múltiples tipos de activos (no solo renta variable, sino también otras opciones como Crowlending P2P) reducirá el riesgo de que nuestra economía colapse, puesto que, aunque la economía global baje, es menos probable que esto suceda conforme mayor número de fuentes de ingresos o activos tengamos ya que es improbable que colapsen al mismo tiempo.
#
#
#
# Por esta razón, mi recomendación es que busques otros tipos de fuentes de ingresos, por ejemplo fuentes de ingresos pasivos como las que detallaba en el post “Ingresos pasivos – El acelerador para alcanzar la libertad financiera” y utilizar diferentes estrategias de inversión como las comentadas en este artículo.
#
#
#
# Conclusión
#
#
#
# En resumen, siempre que hay una crisis parece que se acaba el mundo, pero tenemos que tener en cuenta que esta crisis también pasará y lo superaremos, esperemos que sea lo más pronto posible y que mientras tanto puedas aprovechar las oportunidades que también nos brinda.
#
#
#
# La historia nos ha enseñado que hay un bucle infinito de épocas de bonanza y épocas de debacle, como persona involucrada en el movimiento de libertad financiera, necesitas estrategias para ambas etapas y, si tienes la suerte de estar cerca de la fase de retirada, considera la propuesta de ese fondo de emergencia que te ayude a mitigar el riesgo de encadenar periodos adversos extensos.
#
#
#
# No obstante, no hay mejor mitigación de riesgos que la propia diversificación.
#
#
#
# Nadie dijo que la vida fuera fácil, incluso una vez alcanzada la libertad financiera,  la clave es nuestra estrategia para superar tiempos adversos....Read more...3 Caminos para Alcanzar la Libertad Financiera – El Triángulo del DineroSi has seguido este blog, sabes que la clave para alcanzar la libertad financiera es la tasa de ahorro, pero, ¿hay solo un camino para alcanzar la libertad financiera? Claro que no, es por ello que en este post te explico los 3 caminos que tienes para alcanzar la libertad financiera.
#
#
#
# Antes que nada déjame mostrarte las 3 variables fundamentales del triángulo del dinero:
#
#
#
#
#
#
#
# Los 3 vértices de este triángulo serían:
#
#
#
# Ingresos: Dinero que consigues con tu trabajo, tu negocio,…Gastos: Dinero que gastas en tu día a día.Inversión: Dinero que obtienes por invertir tu dinero actual.
#
#
#
# Tus finanzas se encuentran en el medio de este triángulo, lo que tienes que tener en cuenta es que si alguno de estos vértices colapsa, entonces lo harán tus finanzas personales, puesto que es necesario un equilibrio entre estas variables. Por ejemplo:
#
#
#
# Si tus ingresos colapsan, no importa lo bien que controles tus gastos puesto que no obtienes suficiente dinero. Ni que decir tiene que no tendrás dinero disponible para invertir. Es el caso de una persona que no tiene trabajo o bien su salario es precario.Si no controlas tus gastos, da lo mismo cuantos ingresos tengas puesto que lo vas a gastar igualmente y tampoco tendrás dinero ahorrado para invertir. Es el caso de personas que tienen un puesto de trabajo muy bien remunerado pero derrochan dinero comprando toda clase de lujos (están 100% envueltos en la denominada “carrera de la rata”).Por último, si tus inversiones son nefastas, no importa lo que ahorres para invertir, puesto que estarás continuamente tirando dinero. Esto ocurre con personas que basan sus inversiones en la pura especulación y que no tienen los conocimientos necesarios en inversión.
#
#
#
# Por tanto, si consigues tener un salario decente para el país en el que vives, controlas tus gastos ahorrando al menos el 10% de lo que ganas e inviertes en fondos índice con un ROI esperado del 6% anual, puedes decir que tienes un balance en tus finanzas personales y que eres una persona “promedio” y por tanto tienes un camino financiero “promedio” (trabajar hasta la jubilación, es decir, hasta los 65-70 años).
#
#
#
# El Triángulo del Dinero en la Libertad Financiera
#
#
#
# Tú no eres una persona “promedio“, por eso te voy a mostrar como el Triángulo del Dinero funciona para una persona con mentalidad LF (Libertad Financiera).
#
#
#
# Las personas LF son entre promedio y ligeramente buenas en 2 de los 3 vértices del triángulo del dinero, pero excepcionalmente buenas en el 3er vértice. En función de cuál sea este vértice excepcional, te enmarcas en uno de los siguientes 3 caminos:
#
#
#
# Camino # 1: El Emprendedor
#
#
#
# El Emprendedor es una persona experta en hacer dinero. Es capaz de caer rendido en la cama con un montón de ideas y levantarse con un plan de negocio en su cabeza.
#
#
#
# Es bastante habitual que estas personas no desconecten nunca, siempre tienen un ajetreo mental muy por encima del resto de la sociedad y normalmente trabajan semanalmente más de 60 horas.
#
#
#
# Si conoces a alguien que parece que tiene energía infinita y siempre está pensando en cómo y dónde añadir valor proponiendo ideas y modelos de negocio, esa persona es un Emprendedor.
#
#
#
# Además, suele ser una persona extrovertida y que le encanta comunicarse con los demás, algo clave para conseguir colaboraciones para sus ideas y proyectos.
#
#
#
# Un riesgo que tiene el perfil Emprendedor es que sabe que a veces se necesita invertir dinero en los negocios para conseguir aún más dinero, por tanto debe saber controlar sus gastos en el desarrollo de sus negocios para no ir a la bancarrota, puesto que puede darse el caso en el que su afán por obtener retorno es tal que no analice 100% la viabilidad de sus ideas.
#
#
#
# Camino # 2: El Optimizador
#
#
#
# El Optimizador es un experto en optimizar sus gastos. Es esa persona que siempre está buscando un cupón descuento y que hace lo imposible por no pagar una comisión.
#
#
#
# La persona con perfil Optimizador lleva un control exhaustivo de sus gastos (como se explica en este post) y es capaz de responderte a cuánto gastó en comida entre el día 12 y el 18 del mes pasado. De hecho es algo que le encanta hacer puesto que le aporta una sensación de control total.
#
#
#
# Normalmente este tipo de personas suelen ser algo introvertidas, les gusta dedicar más tiempo a registrar y analizar todo en su hoja de cálculo que en interactuar con los demás. Es bastante común que te digan que no puedes controlar tus ingresos ni tampoco tus inversiones, pero sí que puedes controlar tus gastos al detalle.
#
#
#
# La clave del perfil Optimizador es que consigue sacar el máximo rendimiento de cada centavo, obteniendo unas tasas de ahorro entre el 60-75%.
#
#
#
# Por supuesto no adquieren ninguna posesión sin analizar al milímetro que será algo que les aporte valor a largo plazo, es decir, analizar la relación “coste/duración” haciendo que sea lo mínima posible o, lo que es lo mismo, que la calidad del producto sea muy buena (larga duración) a un coste lo más bajo posible (por ejemplo esperando a la época idónea).
#
#
#
# El principal peligro del Optimizador es ser demasiado conservador en sus inversiones. Por naturaleza tiene una alta aversión al riesgo y piensa que la clave para reducir costes es minimizar el riesgo, cuando en realidad, en el largo plazo, el riesgo de perder dinero debido a la inflación es superior al riesgo de invertir en fondo índice como se explica aquí.
#
#
#
# Camino # 3: El Inversor
#
#
#
# Es aquella persona que sabe como convertir el dinero en más dinero, de tal manera que anualmente pueda conseguir retornos de la inversión del 15-25% anual.
#
#
#
# Típicamente tiene varias vías de inversión (renta variable, sector inmobiliario, inversión en startups,…) y tiene la mentalidad de que el trabajo convencional es para perdedores, el dinero puede trabajar mucho más duro de lo que una persona nunca podría.
#
#
#
# La realidad es que este tipo de personas se encuentran muy rara vez (no todos somos Warren Buffet), es muy complicado que de manera sostenida una persona consiga obtener rentabilidades elevadas y, si lo consigue durante algunos años, en muchas ocasiones es fruto de la suerte. Cuando la suerte sustituye a la habilidad no suele haber un buen final.
#
#
#
# Por tanto, aunque es posible conseguir la libertad financiera por este camino, también es el camino donde más fácil puedes caer en pensar que sabes lo que estás haciendo cuando en realidad no es así.
#
#
#
# Selecciona tu camino…
#
#
#
# Todos los que estamos detrás de la libertad financiera pensamos que tenemos un enfoque muy parecido, pero la realidad es que cada persona es diferente y debes ser tú el/la que elijas tu propio camino en base a tu personalidad.
#
#
#
# Si una persona se siente obligada a ir por un camino de libertad financiera que no se corresponde con su personalidad, estará constantemente intranquila. Por ejemplo, si a un Optimizador se le obliga a tomar el camino del Inversor, no estará confortable puesto que tiene una alta aversión al riesgo y probablemente no consiga su objetivo.
#
#
#
# Y tú, ¿qué camino de estos 3 vas a elegir? Compártelo con la comunidad en los comentarios de este post 😉...Read more...Crea un Presupuesto Personal y Mejora tu EconomíaComenzamos el año 2020, ¿qué mejor época del año para sumar un nuevo hábito que mejore tus finanzas? En este post te voy a enseñar a crear un presupuesto personal con el que mejorar tu economía sustancialmente.
#
#
#
#
#
#
#
# Lo primero, ¿Qué es un presupuesto?
#
#
#
# Un presupuesto no es más que un plan o previsión de lo que vas a hacer con tu dinero. Son muy útiles y se utilizan a todos los niveles (presupuestos del estado, presupuesto de una empresa, presupuesto en tus finanzas personales,…).
#
#
#
# Un presupuesto nos aporta establecer un objetivo que nos sirva de guía para cumplir con lo que deseamos, de tal manera que posteriormente tratemos de ceñirnos al plan definido.
#
#
#
# Muchas personas ven a un presupuesto como algo que les quita libertad, cuando en realidad es todo lo contrario, te sirve para cumplir con tus metas a la par que asignas de antemano una cantidad específica a aquéllos gastos que no son primordiales, lo cual realmente te está dando la libertad de gastar intencionadamente.
#
#
#
# ¿Cómo establezco el presupuesto?
#
#
#
# Hay una regla muy extendida y es la denominada 50-20-30 basada en:
#
#
#
# 50% de tus ingresos destinados a tus gastos esenciales (alquiler, comida, suministros,…).20% de tus ingresos para el ahorro / inversión.30% de tus ingresos dirigidos al ocio (ir al cine, comprar ropa adicional a la estrictamente necesaria, viajes,…).
#
#
#
# La verdad es que esta regla es un buen punto de partida para todas aquéllas personas que no se han planteado previamente ahorrar dinero (o no les ha sido posible).
#
#
#
# Definir un presupuesto hace que te enfoques en tu objetivo, vamos a ver un ejemplo:
#
#
#
# Pepito ingresa mensualmente 1.800€ netos y quiere utilizar la regla 50-20-30, esto significa que:
#
#
#
# Sus gastos esenciales no deberían sobrepasar los 900€.El ahorro/inversión sumaría 360€.Los restantes 540€ irían destinados al ocio.
#
#
#
#
#
# ¿Cómo sé cuáles son mis gastos esenciales?
#
#
#
# Es importante para este ejercicio que hayas analizado tu patrón de consumo y sepas cuál es el importe de tus gastos esenciales mes a mes.
#
#
#
# Seguro que ya has leído bastante de este blog y sabes cómo controlar tus gastos, si necesitas algo de refresco puedes visitar este artículo.
#
#
#
# ¿Qué ocurre si el 50% del salario no me da para mis gastos esenciales?
#
#
#
# Pues debemos utilizar las prioridades siguientes:
#
#
#
# Prioridad 1: Gastos esencialesPrioridad 2: Ahorro / inversiónPrioridad 3: Ocio
#
#
#
# Obviamente si no te queda otra que utilizar digamos el 65% del salario para tus gastos esenciales, la primera partida a recortar sería la del ocio, quedando entonces en una regla 65-20-15.
#
#
#
# Mi recomendación cuando estés realizando el presupuesto es que empieces a asignar tu dinero a las prioridades 1 y 2 para después lo restante lo asocies a la prioridad 3, de hecho en función de tu objetivo temporal para alcanzar la libertad financiera, es posible que para ti la prioridad 2 (ahorro) suponga la mayor cantidad de las 3 partidas.
#
#
#
# ¿Debo aplicar la regla igual todos los meses?
#
#
#
# NO, todo lo contrario, cada mes puedes ajustar en función de tus necesidades, algunos meses sabrás que la vuelta al cole te costará cara, otro mes es Navidad, otro mes tienes un mantenimiento del coche,… Lo importante no es la rigidez en las proporciones gastos-ocio-ahorro, sino que, una vez definamos el presupuesto para un mes concreto (al inicio del mes), nos mantengamos alineados a ese presupuesto.
#
#
#
# En determinadas ocasiones incluso vas a tener imprevistos que harán que tu presupuesto se resienta, por tanto una regla razonable es asignarles el 5% de tus ingresos.
#
#
#
# Es importante que estos imprevistos los categorices, si resulta que se repiten muy asiduamente, quizás es buena idea que en el presupuesto del próximo mes ya sean otro gasto común más en lugar de algo eventual.
#
#
#
# He fracasado en mi presupuesto el primer mes…
#
#
#
# Es normal, hasta que no pasan 3-4 meses después de utilizar esta herramienta, no habrás aprendido lo suficiente para hacer un presupuesto estable.
#
#
#
# Lo importante no es fallar, sino aprender de los errores y definir cuál es la regla que mejor funciona en tu caso.
#
#
#
# ¿Qué herramientas me recomiendas?
#
#
#
# Pues ya me conoces, no hay nada más simple y efectivo que utilizar una hoja de cálculo para hacer tu presupuesto, además puedes utilizar la plantilla que obtendrás si te registras en la comunidad LibreFinanciero (la encontrarás más abajo) y tener todo recopilado en el mismo libro.
#
#
#
# Si quieres otra alternativa, puedes descargar una aplicación para PC o smartphone bastante completa en esta página.
#
#
#
# Al final lo importantes es que realices un seguimiento de cómo tu presupuesto se asemeja a tu resultado real mes a mes y te ayude a mejorar en tu objetivo. Te recomiendo que pruebes a hacer presupuestos, no tienes nada que perder y sí mucho que ganar, una vez cojas el hábito no vas a querer dejarlo 😉...Read more...3 vías para reducir tus impuestosBenditos impuestos, sirven para financiar al estado para construirnos nuevas infraestructuras, prestarnos servicios públicos como sanidad, educación,… (al menos en teoría) pero la realidad es que a ninguno nos gusta pagarlos.
#
#
#
# Estamos a punto de cerrar el año fiscal y es el momento de que pases a la acción para reducir los impuestos en tu próxima declaración de la renta. Por este motivo, te dejo 3 vías para bajar tu carga impositiva.
#
#
#
# Estas opciones y la cuantía que indico aplican en España, aunque si vives en otro país las oportunidades son similares (al final del post dejo un apartado para otros países si es tu caso).
#
#
#
# #1 Planes de Pensiones
#
#
#
# Los planes de pensiones son una muy buena opción para reducir los impuestos.
#
#
#
# En España, puedes deducirte en tu declaración hasta 8.000€ anuales por las aportaciones a fondos de pensiones (o el 30% de los rendimientos netos del trabajo, la cantidad que sea menor).
#
#
#
# En este post expliqué en más detalle el funcionamiento del plan de pensiones de Indexa con muy bajas comisiones y cómo configurarlo paso a paso (en el apartado “MODO 2: Invertir en renta variable a través de fondo de pensiones“). Si utilizas el siguiente enlace tendrás los primeros 10.000€ sin comisiones en fondo de inversión:
#
#
#
#  Inversión Indexa
#
#
#
# Para traer un ejemplo de ese post:
#
#
#
# Escenario 1:
#
#
#
# Pepe ingresa anualmente 25.200€ netos, con lo cual tiene un porcentaje de tributación del 22,7% actualmente, es decir, 5.720€ van directos a impuestos.
#
#
#
# Escenario 2:
#
#
#
# Pepe ingresa anualmente 25.200€ netos pero aporta a un plan de pensiones 8.000€ durante todo el año, su base de cotización por tanto es 17.200€ (25.200 – 8.000) con lo que consigue que su porcentaje de tributación sea del 20,3% sobre esos 17.200€ y 0% sobre los otros 8.000€, en total su porcentaje de tributación global sería del 13,9% de lo que ingresa, pagando 3.502€ en impuestos en ese año.
#
#
#
# Es decir, ha ahorrado 2.218€ en impuestos en este ejercicio (te recomiendo encarecidamente que visites el siguiente post de inversión en renta fija y renta variable para ver cómo impacta en el futuro este vehículo de inversión con el enfoque de libertad financiera).
#
#
#
# #2 Donaciones
#
#
#
# Afortunadamente, las donaciones a ONGs, fundaciones y entidades sin ánimo de lucro deducen en tu declaración. Además, si las haces a las mismas entidades, aún más.
#
#
#
# Las cantidades serían:
#
#
#
# 75% sobre los primeros 150 euros, es decir, aportar 150€ a una ONG solo te acabaría costando 37,5€, el resto lo deducirás en tu próxima declaración y te devolverán los impuestos asociados en esos 112,5€.30% sobre lo que exceda de 150€ (este porcentaje sube al 35% si es el tercer año que donas a la misma entidad y cada donación ha sido igual o superior a la del año anterior).
#
#
#
# Resumen deducciones por donación (fuente: Fundación Lealtad)
#
#
#
# Si optas por esta vía mi recomendación es que sigas los siguientes pasos:
#
#
#
# Define tus prioridades, es decir, piensa a qué colectivos o actividades quieres ayudar en base a tus valores.Verifica las ONGs acreditadas, en el portal de Fundación Lealtad puedes buscarlas e informarte de la misión de cada una.Una vez seleccionada la ONG, solicítale tu certificado fiscal para que después tengas el justificante de cara a la declaración de la renta.
#
#
#
# #3 Invertir en empresas de reciente creación
#
#
#
# Recuerda que en este blog recomendamos la inversión indexada para generar riqueza a largo plazo y evitar caer en la especulación, pero bien es cierto que esta alternativa es algo a tener en cuenta por sus ventajas fiscales.
#
#
#
# Si inviertes en empresas de reciente creación (startups), podrás deducir el 30% de las cantidades aportadas con un máximo de 60.000€ anuales. Además, no tributarás por el beneficio obtenido si vuelves a invertir en otra startup.
#
#
#
# El objetivo es incentivar que los ahorradores impulsen nuevos proyectos desviando parte de capital hacia empresas emergentes como alternativa a la inversión bursátil tradicional.
#
#
#
# Tal y como indica la ley,  debes adquirir las acciones o participaciones en el momento de la constitución de la empresa o mediante la ampliación de capital efectuada en los 3 años siguientes a su constitución.
#
#
#
# Debes tener en cuenta que esto no se trata de pura especulación, la inversión debe permanecer en tu patrimonio por un plazo superior a 3 años e inferior a 12 y no puede superar el 40% del capital social de la entidad.
#
#
#
# En este enlace de la AEAT tienes toda la información sobre este punto.
#
#
#
# Para aplicar esta deducción debes obtener una certificación expedida por la entidad cuyas acciones o participaciones hayas adquirido. En ella debe indicarse que se cumplen los requisitos exigidos para la aplicación de la deducción en el período impositivo de la adquisición. La entidad a su vez debe presentar el modelo 165 (en el mes de enero) que identifica los socios a los que ha expedido el certificado.
#
#
#
# Como consejo final, te recomiendo que diversifiques todo lo que puedas en este tipo de inversiones, es mejor tener 5 inversiones de 5.000€ que 1 de 25.000€. Ten en cuenta que el riesgo asumido al invertir en startups es considerable, en contrapartida las potenciales ganancias también son elevadas y gracias a la deducción fiscal al menos ya te has quitado los impuestos que pagas de IRPF sobre el 30% de lo invertido, no está nada mal.
#
#
#
# Te recomiendo si optas por esta opción que analices el sector al que se dedica la startup para poder valorar si tanto la idea como el modelo negocio tiene potencial y es sostenible.
#
#
#
# Desde luego que, si te gusta el análisis empresarial, invertir en startups es una gran vía para reducir tus impuestos, si bien es cierto que las técnicas y claves para analizar startups daría para otro post (de hecho daría para un libro). Si estás interesad@ ponlo en comentarios y lo tendré en cuenta para futuras publicaciones en el blog.
#
#
#
# Ejemplo escenario pesimista inversión startups
#
#
#
# Te pongo un ejemplo de un escenario pesimista para que veas las ventajas fiscales:
#
#
#
# Un inversor aporta capital a 3 empresas de reciente creación:
#
#
#
# Empresa A: Aportación 1.000€ Empresa B: Aportación 1.000€Empresa C: Aportación 1.000€
#
#
#
# Al inversor le genera una reducción fiscal del 30% sobre el capital invertido, es decir, 900€.
#
#
#
# ...
# 							const peRecentPostsPanel = $('#pe_recent_posts-2 .carousel-inner > .item');
# 							peRecentPostscarouselContainer.carousel({
# 								interval: 5000,
# 								pause: "hover"
# 							})
#
# 							$('#pe_recent_posts-2 ol.carousel-indicators li:first-child').attr('aria-selected', 'true');
#
# 							peRecentPostsArrow.on('keydown', function(event) {
#
# 								if (event.which == 32) { // Space key
# 									event.preventDefault();
# 									$(this).click();
# 								}
#
# 							});
#
# 							peRecentPostsIndicators.on('keydown', function(event) {
#
# 								$(this).parent().children().attr('aria-selected', 'false');
# 								$('#pe_recent_posts-2 ol.carousel-indicators li:first-child').attr('aria-selected', 'true');
#
# 								if (event.which == 9) { // Tab key
# 									if (event.shiftKey) { // + Shift Tab key
#
# 										$(this).siblings('li:not(.active)').attr('tabindex', '-1');
#
# 									} else {
#
# 										event.preventDefault();
# 										let tabID = $(this).attr('aria-controls');
# 										$(this).click();
# 										$(this).parent().siblings('.carousel-inner').find('#' + tabID).focus();
#
# 									}
#
# 								}
#
# 								if (event.which == 13) { // Enter key
# 									$(this).click();
# 								}
#
# 								if (event.which == 39) { // Right arrow
#
# 									event.preventDefault();
# 									if ($(this).is(':last-child')) {
# 										$(this).siblings().first().focus().click().attr('aria-selected', 'true');
# 									} else {
# 										$(this).next().focus().click().attr('aria-selected', 'true');
# 									}
#
# 								}
#
# 								if (event.which == 37) { // Left arrow
#
# 									event.preventDefault();
# 									if ($(this).is(':first-child')) {
# 										$(this).siblings().last().focus().click().attr('aria-selected', 'true');
# 									} else {
# 										$(this).prev().focus().click().attr('aria-selected', 'true');
# 									}
#
# 								}
#
# 								if (event.which == 36) { // Home key
#
# 									event.preventDefault();
# 									$(this).parent().children('li:first-child').focus().click().attr('aria-selected', 'true');
#
# 								}
#
# 								if (event.which == 35) { // End key
#
# 									event.preventDefault();
# 									$(this).parent().children('li:last-child').focus().click().attr('aria-selected', 'true');
#
# 								}
#
# 							});
#
# 							peRecentPostsPanel.on('keydown', function(event) {
#
# 								let tabPanel = event.target.getAttribute('id');
#
# 								if (event.which == 9) { // Tab key
#
# 									$(this).parent('.carousel-inner').siblings('.carousel-indicators').children('li').attr('tabindex', '0');
#
# 									if (event.shiftKey) { // + Shift Tab key
# 										if ($(this).parent().parent().hasClass('bullets-on-board')) {
# 											if (!$(this).find('a').is(":focus")) {
# 												event.preventDefault();
# 												$(this).parent('.carousel-inner').siblings('.carousel-indicators').children('li[aria-controls="' + tabPanel + '"]').focus();
# 											}
# 										}
#
# 									}
#
# 								}
#
# 							});
#
# 							if (peRecentPostscarouselContainer.hasClass('one-row-mobile-on') && $(window).width() < 768) { // one row for mobiles
# 								$("#pe_recent_posts-2 ul.thumbnails").wrap("<div class='pe-item-mobile item el-in-row-1'></div>"); //wrap items
# 								$("#pe_recent_posts-2 .pe-item-mobile").unwrap(); // remove original '.item' divs
# 								$("#pe_recent_posts-2 .pe-item-mobile:first-of-type").addClass('active'); // add class active for the first item
# 								if (peRecentPostscarouselContainer.children('.carousel-indicators').length > 0) { //only if indicators (bullets) are enabled
# 									const peRecentPostsItemsNumber = $('.pe-item-mobile').length; // get numer of items
# 									$(peRecentPostsIndicators.parent('ol')).empty(); // remove indicators (bullets) items
# 									for (i = 0; i < peRecentPostsItemsNumber; i++) { // add bullets for mobile
# 										peRecentPostsIndicatorsContainer.append('<li data-target="#myCarousel-pe_recent_posts-2" data-slide-to="' + i + '" tabindex="0">' + i + '</li>');
# 									}
# 									$(peRecentPostsIndicatorsContainer).children('li:first-child').addClass('active'); // add class active for the first bullet
# 								}
# 							}
# 						}
# 					);Unirse a LibreFinanciero.comÚnete y Consigue la Plantilla Excel Definitiva para Controlar tus Finanzas Personales✅ Controlarás todos tus ingresos, gastos e inversiones de manera sencilla✅ Visualiza tu estado económico para que seas consciente de cuánto te queda para alcanzar la Libertad Financiera✅ Estarás al tanto del nuevo contenido de LibreFinanciero con artículos que aporten valor a tus finanzas personalesHe leído las condiciones en base a la política de privacidadNO HAY NINGÚN TIPO DE SPAM NI PUBLICIDAD AL SUSCRIBIRTETe llegará un enlace a tu email para la descarga de las plantillas que te ayudarán con tu futuro financieroBúsquedaSearch for:SearchÚltimos PostItem 1Item 2Item 3Item 4Item 5COVID-19: ¿Es el fin de la Libertad Financiera?July 6, 2020Estamos viviendo unos tiempos complicados debido a la pandemia generada por el COVID-19 que ha puest...Read more3 Caminos para Alcanzar la Libertad Financiera – El Triángulo del DineroFebruary 26, 2020Si has seguido este blog, sabes que la clave para alcanzar la libertad financiera es la tasa de ahor...Read moreCrea un Presupuesto Personal y Mejora tu EconomíaJanuary 1, 2020Comenzamos el año 2020, ¿qué mejor época del año para sumar un nuevo hábito que mejore tus finanzas?...Read more3 vías para reducir tus impuestosDecember 1, 2019Benditos impuestos, sirven para financiar al estado para construirnos nuevas infraestructuras, prest...Read moreMinimalismo – 4 Métodos para aplicarlo y mejorar tus FinanzasOctober 21, 2019¿Has tenido la sensación de que tienes demasiadas preocupaciones, demasiadas obligaciones o demasiad...Read more¿Cómo asegurar el cumplimiento de mis objetivos financieros?October 1, 2019Adoptar una mentalidad enfocada en alcanzar la libertad financiera es un gran paso, qué duda cabe, p...Read moreCómo ahorrar dinero comprando productos en el momento más adecuadoSeptember 16, 2019Todos tenemos que acometer la compra de determinados productos como coche, casa, ropa, tecnología, v...Read moreIngresos Pasivos – El Acelerador para Alcanzar la Libertad FinancieraSeptember 2, 2019[ ⚠️ ¡Advertencia! Este post puede hacer que dejes tu trabajo de inmediato] ¿Has escuchado hablar de...Read more20 Consejos Financieros para Mejorar tu EconomíaAugust 26, 2019Vuelta al trabajo para muchos y sí, hemos tenido gastos en exceso después de disfrutar de esas merec...Read moreCosas que importan… Y cosas que NOAugust 4, 2019Has tenido un día duro en el trabajo, llegas a casa y no eres capaz de desconectar hasta tal punto q...Read morePirámide de las Necesidades FinancierasJune 28, 2019A lo largo de este blog, te he estado mostrando los pasos a seguir para alcanzar la libertad financi...Read more¿Compensa amortizar la hipoteca anticipadamente?May 27, 2019Gran parte de la sociedad tiene una deuda hipotecaria por la vivienda y seguro que cada uno se plant...Read moreHitos Independencia FinancieraApril 14, 2019Post dedicado a explicar los diferentes hitos que irás alcanzando en tu camino hacia la Libertad Fin...Read morejQuery(document).ready(
# 						function($) {
# 							const peRecentPostscarouselContainer = $('#pe_recent_posts-3 .pe-recent-posts-outer');
# 							const peRecentPostsArrows = $('#pe_recent_posts-3 .pe-recent-posts-outer .pe-carousel-navigation-container');
# 							const peRecentPostsArrow = $('#pe_recent_posts-3 .pe-recent-posts-outer .pe-carousel-navigation-container .carousel-control');
# 							const peRecentPostsIndicatorsContainer = $('#pe_recent_posts-3 .carousel-indicators');
# 							const peRecentPostsIndicators = $('#pe_recent_posts-3 .carousel-indicators li');
# 							const peRecentPostsPanel = $('#pe_recent_posts-3 .carousel-inner > .item');
# 							peRecentPostscarouselContainer.carousel({
# 								interval: 5000,
# 								pause: "null"
# 							})
#
# 							$('#pe_recent_posts-3 ol.carousel-indicators li:first-child').attr('aria-selected', 'true');
#
# 							peRecentPostsArrow.on('keydown', function(event) {
#
# 								if (event.which == 32) { // Space key
# 									event.preventDefault();
# 									$(this).click();
# 								}
#
# 							});
#
# 							peRecentPostsIndicators.on('keydown', function(event) {
#
# 								$(this).parent().children().attr('aria-selected', 'false');
# 								$('#pe_recent_posts-3 ol.carousel-indicators li:first-child').attr('aria-selected', 'true');
#
# 								if (event.which == 9) { // Tab key
# 									if (event.shiftKey) { // + Shift Tab key
#
# 										$(this).siblings('li:not(.active)').attr('tabindex', '-1');
#
# 									} else {
#
# 										event.preventDefault();
# 										let tabID = $(this).attr('aria-controls');
# 										$(this).click();
# 										$(this).parent().siblings('.carousel-inner').find('#' + tabID).focus();
#
# 									}
#
# 								}
#
# 								if (event.which == 13) { // Enter key
# 									$(this).click();
# 								}
#
# 								if (event.which == 39) { // Right arrow
#
# 									event.preventDefault();
# 									if ($(this).is(':last-child')) {
# 										$(this).siblings().first().focus().click().attr('aria-selected', 'true');
# 									} else {
# 										$(this).next().focus().click().attr('aria-selected', 'true');
# 									}
#
# 								}
#
# 								if (event.which == 37) { // Left arrow
#
# 									event.preventDefault();
# 									if ($(this).is(':first-child')) {
# 										$(this).siblings().last().focus().click().attr('aria-selected', 'true');
# 									} else {
# 										$(this).prev().focus().click().attr('aria-selected', 'true');
# 									}
#
# 								}
#
# 								if (event.which == 36) { // Home key
#
# 									event.preventDefault();
# 									$(this).parent().children('li:first-child').focus().click().attr('aria-selected', 'true');
#
# 								}
#
# 								if (event.which == 35) { // End key
#
# 									event.preventDefault();
# 									$(this).parent().children('li:last-child').focus().click().attr('aria-selected', 'true');
#
# 								}
#
# 							});
#
# 							peRecentPostsPanel.on('keydown', function(event) {
#
# 								let tabPanel = event.target.getAttribute('id');
#
# 								if (event.which == 9) { // Tab key
#
# 									$(this).parent('.carousel-inner').siblings('.carousel-indicators').children('li').attr('tabindex', '0');
#
# 									if (event.shiftKey) { // + Shift Tab key
# 										if ($(this).parent().parent().hasClass('bullets-on-board')) {
# 											if (!$(this).find('a').is(":focus")) {
# 												event.preventDefault();
# 												$(this).parent('.carousel-inner').siblings('.carousel-indicators').children('li[aria-controls="' + tabPanel + '"]').focus();
# 											}
# 										}
#
# 									}
#
# 								}
#
# 							});
#
# 							if (peRecentPostscarouselContainer.hasClass('one-row-mobile-on') && $(window).width() < 768) { // one row for mobiles
# 								$("#pe_recent_posts-3 ul.thumbnails").wrap("<div class='pe-item-mobile item el-in-row-3'></div>"); //wrap items
# 								$("#pe_recent_posts-3 .pe-item-mobile").unwrap(); // remove original '.item' divs
# 								$("#pe_recent_posts-3 .pe-item-mobile:first-of-type").addClass('active'); // add class active for the first item
# 								if (peRecentPostscarouselContainer.children('.carousel-indicators').length > 0) { //only if indicators (bullets) are enabled
# 									const peRecentPostsItemsNumber = $('.pe-item-mobile').length; // get numer of items
# 									$(peRecentPostsIndicators.parent('ol')).empty(); // remove indicators (bullets) items
# 									for (i = 0; i < peRecentPostsItemsNumber; i++) { // add bullets for mobile
# 										peRecentPostsIndicatorsContainer.append('<li data-target="#myCarousel-pe_recent_posts-3" data-slide-to="' + i + '" tabindex="0">' + i + '</li>');
# 									}
# 									$(peRecentPostsIndicatorsContainer).children('li:first-child').addClass('active'); // add class active for the first bullet
# 								}
# 							}
# 						}
# 					);© 2019 - LibreFinanciero.com. El uso no autorizado o copia de este material sin el consentimiento expreso y por escrito del autor está estrictamente prohibido. Puede utilizar enlaces a este blog siempre y cuando aparezca claramente la autoría de LibreFinanciero.com y la redirección al contenido original.Inicio¡Empieza Aquí!Pasos a SeguirPaso 1: Calcula tu salario/hora REALPaso 2: Controla y Categoriza tus Ingresos y Gastos PersonalesPaso 3: Valora tus GastosPaso 4: Visualiza tu Estado Financiero PersonalPaso 5: Reduce tus Gastos y Aumenta tus IngresosPaso 6: Añade tus Inversiones a la fotoPaso 7: El “Punto de Corte” de la Independencia FinancieraEstrategias de InversiónInversión en Renta Fija & Renta VariableInversión en Préstamos P2P – CrowlendingInversión en Desarrollo PersonalBlogLibros RecomendadosSobre MíEste sitio web utiliza cookies propias y de terceros según se recoge en la Política de Privacidad y Política de Cookies para mejorar la experiencia de usuario. Puedes modificar las preferencias en cualquier momento. Acepto el uso de cookies para estos fines:Privacy PreferencesI AgreePrivacy Preference CenterOptionsConsent ManagementCookie SettingsAnalyticsPolítica de Privacidad / Política de CookiesConsent ManagementPolítica de Privacidad / Política de CookiesRequiredConsiento el uso de datos conforme a la política de privacidad y política de cookies de este blogNecesariaSe usan para almacenar tu nombre, IP, email y otros datos que dejas expresamente en los formularios de comentarios, contacto y acceso.AdvertisingSe usan para almacenar tu nombre, IP, email y otros datos que dejas expresamente en los formularios de comentarios, contacto y acceso.AnalyticsSe usan para identificar tu IP y poder comprender mejor a nuestros visitantes y ofrecerles una mejor experiencia.Cookies UsedONOFF__utma,__utmt,__utmb__utmc,__utmz,__utmvgoogle.comOpt Out__utma,__utmt,__utmb__utmc,__utmz,__utmvOtherOKInsert math asBlockInlineAdditional settingsFormula colorText color#333333Formula IDFormula classesType math usingLaTeXPreview\({}\)Nothing to previewInsertfunction atomicBlocksShare( url, title, w, h ){
# 			var left = ( window.innerWidth / 2 )-( w / 2 );
# 			var top  = ( window.innerHeight / 2 )-( h / 2 );
# 			return window.open(url, title, 'toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=no, resizable=no, copyhistory=no, width=600, height=600, top='+top+', left='+left);
# 		}/* <![CDATA[ */
# var MabAjax = {"ajaxurl":"https:\/\/librefinanciero.com\/wp-admin\/admin-ajax.php","action":"mab-process-optin","wpspinner":"https:\/\/librefinanciero.com\/wp-admin\/images\/wpspin_light.gif","wpspinner2x":"https:\/\/librefinanciero.com\/wp-admin\/images\/wpspin_light-2x.gif","spinner":"https:\/\/librefinanciero.com\/wp-admin\/images\/spinner.gif","spinner2x":"https:\/\/librefinanciero.com\/wp-admin\/images\/spinner-2x.gif","baseStylesUrl":"https:\/\/librefinanciero.com\/wp-content\/plugins\/magic-action-box\/styles\/"};
# /* ]]> */function heateorSssLoadEvent(e) {var t=window.onload;if (typeof window.onload!="function") {window.onload=e}else{window.onload=function() {t();e()}}};	var heateorSssSharingAjaxUrl = 'https://librefinanciero.com/wp-admin/admin-ajax.php', heateorSssCloseIconPath = 'https://librefinanciero.com/wp-content/plugins/sassy-social-share/public/../images/close.png', heateorSssPluginIconPath = 'https://librefinanciero.com/wp-content/plugins/sassy-social-share/public/../images/logo.png', heateorSssHorizontalSharingCountEnable = 0, heateorSssVerticalSharingCountEnable = 0, heateorSssSharingOffset = -10; var heateorSssMobileStickySharingEnabled = 1;var heateorSssCopyLinkMessage = "Link copied.";var heateorSssUrlCountFetched = [], heateorSssSharesText = 'Shares', heateorSssShareText = 'Share';function heateorSssPopup(e) {window.open(e,"popUpWindow","height=400,width=600,left=400,top=100,resizable,scrollbars,toolbar=0,personalbar=0,menubar=no,location=no,directories=no,status")};var heateorSssWhatsappShareAPI = "web";_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:9.0.2',blog:'161189322',post:'9',tz:'2',srv:'librefinanciero.com'} ]);
# 	_stq.push([ 'clickTrackerInit', '161189322', '9' ]);

# %%
#Crear tokens por palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text,"spanish")
tokens=[word.lower() for word in tokens if word.isalpha()] # Remover los signos de puntuación
print(tokens)
# Out:
# ['background', 'circle', 'at', 'color', 'fff', 'solid', 'transparent', 'color', 'hover', 'hover', 'transparent', 'color', 'fff', 'solid', 'transparent', 'color', 'hover', 'hover', 'transparent', 'media', 'screen', 'and', 'display', 'none', 'important', 'media', 'screen', 'and', 'display', 'none', 'important', 'display', 'none', 'media', 'screen', 'and', 'white', 'important', 'important', 'important', 'li', 'important', 'width', 'important', 'important', 'important', 'important', 'important', 'display', 'block', 'important', 'display', 'block', 'important', 'width', 'auto', 'important', 'bottom', 'important', 'top', 'auto', 'important', 'inherit', 'display', 'none', 'important', 'la', 'libertad', 'financiera', 'y', 'context', 'https', 'graph', 'type', 'person', 'organization', 'id', 'https', 'name', 'image', 'type', 'imageobject', 'id', 'https', 'personlogo', 'inlanguage', 'url', 'https', 'caption', 'logo', 'id', 'https', 'personlogo', 'type', 'website', 'id', 'https', 'website', 'url', 'https', 'name', 'financiero', 'alcanza', 'la', 'independencia', 'y', 'description', 'publisher', 'id', 'https', 'potentialaction', 'type', 'searchaction', 'target', 'https', 'required', 'inlanguage', 'type', 'imageobject', 'id', 'https', 'primaryimage', 'inlanguage', 'url', 'https', 'width', 'height', 'caption', 'libertad', 'financiera', 'type', 'webpage', 'id', 'https', 'webpage', 'url', 'https', 'name', 'la', 'libertad', 'financiera', 'y', 'ispartof', 'id', 'https', 'website', 'about', 'id', 'https', 'primaryimageofpage', 'id', 'https', 'primaryimage', 'datepublished', 'datemodified', 'description', 'alcanzar', 'la', 'libertad', 'financiera', 'y', 'tener', 'la', 'vida', 'que', 'deseas', 'que', 'se', 'puede', 'y', 'en', 'este', 'blog', 'las', 'inlanguage', 'potentialaction', 'type', 'readaction', 'target', 'https', 'dzgizzg', 'var', 'var', 'true', 'var', 'var', 'disablestr', 'function', 'to', 'detect', 'opted', 'out', 'users', 'function', 'return', 'disablestr', 'disable', 'tracking', 'if', 'the', 'cookie', 'exists', 'if', 'window', 'disablestr', 'true', 'function', 'function', 'disablestr', 'dec', 'utc', 'window', 'disablestr', 'true', 'if', 'typeof', 'gaoptout', 'function', 'gaoptout', 'if', 'function', 'i', 's', 'o', 'g', 'r', 'a', 'm', 'i', 'i', 'r', 'r', 'i', 'r', 'r', 'arguments', 'i', 'r', 'new', 'date', 'o', 'o', 'a', 'm', 'window', 'document', 'true', 'else', 'function', 'https', 'var', 'noopfn', 'function', 'return', 'null', 'var', 'noopnullfn', 'function', 'return', 'null', 'var', 'tracker', 'function', 'return', 'null', 'var', 'p', 'noopfn', 'noopfn', 'noopfn', 'var', 'function', 'var', 'len', 'if', 'len', 'return', 'var', 'f', 'arguments', 'if', 'typeof', 'f', 'f', 'null', 'typeof', 'running', 'function', 'arguments', 'because', 'you', 'are', 'not', 'being', 'return', 'try', 'catch', 'ex', 'function', 'return', 'new', 'tracker', 'noopnullfn', 'function', 'return', 'noopfn', 'window', 'baseurl', 'https', 'ext', 'svgurl', 'https', 'svgext', 'source', 'concatemoji', 'https', 'function', 'e', 'a', 't', 'var', 'r', 'n', 'o', 'i', 'canvas', 'function', 'c', 'e', 't', 'var', 'this', 'e', 'var', 'return', 'this', 't', 'function', 'l', 'e', 'if', 'return', 'switch', 'top', 'arial', 'e', 'case', 'flag', 'return', 'c', 'c', 'c', 'case', 'emoji', 'return', 'c', 'return', 'function', 'd', 'e', 'var', 'script', 'head', 't', 'for', 'flag', 'emoji', 'everything', 'everythingexceptflag', 'o', 'i', 'o', 'i', 'o', 'i', 'o', 'flag', 'o', 'i', 'o', 'domcontentloaded', 'n', 'load', 'n', 'onload', 'n', 'onreadystatechange', 'function', 'complete', 'd', 'd', 'd', 'window', 'document', 'display', 'inline', 'important', 'border', 'none', 'important', 'none', 'important', 'height', 'important', 'width', 'important', 'margin', 'important', 'important', 'background', 'none', 'important', 'padding', 'important', 'justify', 'hover', 'color', 'rgb', 'important', 'hover', 'hover', 'hover', 'hover', 'color', 'rgb', 'important', 'float', 'right', 'transparent', 'bo ...

# %%
#Verificar frecuencia de palabras 
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print (str(key) + ':' + str(val))
# Out:
# background:6
# circle:1
# at:1
# color:31
# fff:2
# solid:3
# transparent:9
# hover:23
# media:6
# screen:3
# and:6
# display:10
# none:11
# important:29
# white:1
# li:21
# width:5
# block:2
# auto:2
# bottom:1
# top:3
# inherit:1
# la:509
# libertad:80
# financiera:95
# y:305
# context:1
# https:31
# graph:1
# type:7
# person:1
# organization:1
# id:11
# name:3
# image:1
# imageobject:2
# personlogo:2
# inlanguage:4
# url:8
# caption:2
# logo:1
# website:3
# financiero:15
# alcanza:3
# independencia:29
# description:2
# publisher:1
# potentialaction:2
# searchaction:1
# target:2
# required:1
# primaryimage:2
# height:2
# webpage:2
# ispartof:1
# about:1
# primaryimageofpage:1
# datepublished:1
# datemodified:1
# alcanzar:44
# tener:46
# vida:34
# que:734
# deseas:2
# se:92
# puede:23
# en:526
# este:128
# blog:18
# las:115
# readaction:1
# dzgizzg:1
# var:27
# true:5
# disablestr:5
# function:29
# to:5
# detect:1
# opted:1
# out:3
# users:1
# return:14
# disable:1
# tracking:1
# if:42
# the:5
# cookie:1
# exists:1
# window:7
# dec:1
# utc:1
# typeof:4
# gaoptout:2
# i:18
# s:4
# o:65
# g:1
# r:7
# a:381
# m:2
# arguments:3
# new:2
# date:2
# document:4
# else:8
# noopfn:5
# null:5
# noopnullfn:2
# tracker:2
# p:2
# len:2
# f:3
# running:1
# because:1
# you:5
# are:6
# not:4
# being:2
# try:1
# catch:1
# ex:1
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# source:1
# concatemoji:1
# e:21
# t:5
# n:4
# canvas:1
# c:8
# this:40
# l:1
# switch:1
# arial:1
# case:2
# flag:3
# emoji:2
# d:4
# script:1
# head:1
# for:12
# everything:1
# everythingexceptflag:1
# domcontentloaded:1
# load:1
# onload:1
# onreadystatechange:1
# complete:1
# inline:1
# border:2
# margin:1
# padding:2
# justify:1
# rgb:2
# float:1
# right:3
# ul:12
# before:5
# after:2
# inset:2
# content:2
# cdata:4
# doc:1
# pdf:1
# ppt:1
# zip:1
# xls:1
# docx:1
# pptx:1
# xlsx:1
# false:1
# gdpr:1
# ajaxurl:2
# logouturl:1
# aborting:2
# logged:2
# continue:2
# cancel:2
# ok:2
# close:1
# your:2
# account:2
# will:4
# be:4
# closed:1
# all:1
# data:1
# permanently:1
# deleted:1
# can:1
# recovered:1
# sure:2
# by:1
# disagreeing:1
# no:183
# longer:1
# have:1
# access:1
# our:1
# site:1
# refresh:1
# pagination:1
# autoanimate:1
# autoanimatetrans:1
# animationloop:1
# slideshowspeed:1
# slidespeed:1
# pausehover:1
# pauseaction:1
# slidedirection:1
# touch:1
# wpstats:1
# dddddd:3
# focus:4
# active:7
# link:2
# visited:1
# footer:1
# red:2
# gray:1
# gold:1
# orange:1
# left:4
# position:1
# relative:1
# center:1
# skip:1
# aquí:7
# pasos:14
# seguirpaso:2
# calcula:3
# tu:189
# realpaso:2
# controla:2
# categoriza:2
# tus:138
# ingresos:87
# gastos:73
# personalespaso:2
# valora:2
# gastospaso:2
# visualiza:4
# estado:16
# personalpaso:2
# reduce:2
# aumenta:3
# ingresospaso:2
# añade:2
# inversiones:23
# fotopaso:2
# el:400
# punto:23
# de:908
# corte:3
# financieraestrategias:2
# inversióninversión:2
# renta:18
# fija:3
# variableinversión:2
# préstamos:5
# crowlendinginversión:2
# desarrollo:3
# personalbloglibros:2
# recomendadossobre:2
# interesado:1
# seguir:17
# gastando:1
# horas:10
# diarias:2
# energía:5
# un:204
# trabajo:36
# hasta:24
# día:26
# consigas:3
# jubilarte:1
# los:167
# años:34
# mejor:30
# casos:2
# si:135
# respuesta:7
# es:320
# sí:28
# entonces:14
# caso:24
# contrario:5
# bienvenido:1
# comunidadlibrefinancierodonde:1
# aprenderás:1
# qué:22
# cómo:13
# ponerla:1
# significa:10
# estable:3
# hacerse:1
# rico:1
# una:150
# situación:19
# quenodependas:1
# intercambiar:2
# tiempo:29
# por:188
# eres:13
# diferente:5
# estás:11
# buscando:3
# convencional:2
# recomiendo:11
# comiences:2
# sección:3
# posteriormente:3
# puedes:59
# ver:13
# recomendaciones:1
# propongo:3
# ser:22
# capaz:9
# controlar:7
# ello:15
# únete:1
# consigue:8
# plantilla:16
# excel:6
# definitiva:3
# controlarás:2
# económico:6
# seas:3
# consciente:4
# cuánto:4
# queda:5
# estarás:5
# nuevo:6
# contenido:3
# librefinanciero:6
# artículos:8
# aporten:2
# valor:58
# personaleshe:2
# leído:3
# condiciones:2
# base:18
# política:9
# privacidadno:2
# ningún:5
# tipo:14
# spam:2
# ni:9
# publicidad:2
# suscribirtete:2
# llegará:2
# enlace:13
# email:4
# descarga:2
# plantillas:2
# ayudarán:2
# financieroúltimos:1
# fin:5
# viviendo:3
# unos:6
# tiempos:5
# complicados:3
# debido:6
# pandemia:3
# generada:3
# puesto:35
# jaque:2
# nuestra:13
# ya:30
# solo:19
# desde:10
# vista:6
# también:21
# social:2
# dramático:1
# afectando:1
# salud:3
# millones:2
# planeta:1
# atrevo:1
# hablar:4
# puntos:3
# números:2
# hablan:1
# solos:1
# lamentablemente:2
# acabó:1
# lejos:3
# realidad:11
# algo:27
# debemos:4
# estas:16
# crisis:10
# económicas:1
# esa:11
# seguridad:6
# percibimos:1
# ir:8
# traste:1
# noche:2
# mañana:4
# situaciones:3
# están:6
# totalmente:4
# fuera:4
# nuestro:9
# alcance:1
# esta:35
# razón:2
# estrategia:8
# hace:11
# seamos:2
# menos:21
# vulnerables:1
# plazo:24
# futuras:3
# volverá:1
# haber:10
# sale:1
# aún:8
# reforzado:1
# etapa:2
# vivimos:3
# tengo:2
# activos:11
# variable:10
# bajan:1
# su:32
# cada:43
# cierto:4
# época:6
# prácticamente:3
# cualquier:9
# devaluando:1
# consistente:4
# largo:18
# tenemos:9
# actual:10
# oportunidad:2
# compra:11
# mercado:14
# clave:16
# éxito:6
# superar:4
# emocionalmente:1
# ese:22
# tensión:1
# viendo:1
# bajar:2
# nuestras:3
# vender:8
# justo:7
# post:28
# explico:4
# mucho:16
# detalle:6
# modo:6
# referencia:2
# devaluación:1
# diferentes:16
# índices:3
# bursátiles:3
# evolución:10
# euro:2
# stoxx:2
# mínimo:5
# índice:7
# tras:13
# aparición:1
# podríamos:1
# adquirido:2
# mismo:15
# dicho:3
# sería:13
# muy:46
# ventajista:1
# obviamente:3
# queremos:2
# caer:5
# especulación:5
# difícil:1
# acertado:1
# basada:2
# mensual:12
# probable:4
# hayamos:1
# aprovechado:3
# poner:7
# escenario:12
# basado:2
# últimos:5
# meses:18
# vamos:13
# misma:5
# comparativa:4
# utilizando:5
# promedio:12
# móvil:1
# vemos:8
# habríamos:1
# rebaja:2
# hecho:12
# hubieras:1
# varias:6
# ocasiones:9
# sabemos:3
# bolsa:2
# rentabilidades:5
# pasadas:1
# garantizan:1
# siga:2
# habiendo:1
# vaivenes:1
# consigamos:1
# mantenernos:1
# firmes:1
# desistir:1
# largoplacista:1
# recuerda:5
# siempre:11
# vencerá:1
# autoría:1
# redirección:1
# míeste:1
# sitio:1
# recoge:1
# privacidad:4
# modificar:1
# preferencias:1
# acepto:1
# fines:1
# privacy:1
# preferencesi:1
# agreeprivacy:1
# preference:1
# centeroptionsconsent:1
# managementcookie:1
# settingsanalyticspolítica:1
# cookiesconsent:1
# managementpolítica:1
# cookiesrequiredconsiento:1
# blognecesariase:1
# usan:3
# ip:3
# dejas:2
# expresamente:2
# formularios:2
# contacto:2
# comprender:1
# visitantes:1
# ofrecerles:1
# math:2
# asblockinlineadditional:1
# settingsformula:1
# colortext:1
# idformula:1
# classestype:1
# nothing:1
# previewinsertfunction:1
# atomicblocksshare:1
# title:2
# w:2
# h:2
# mabajax:1
# action:1
# wpspinner:1
# spinner:1
# basestylesurl:1
# heateorsssloadevent:1
# heateorssssharingajaxurl:1
# heateorssscloseiconpath:1
# heateorssspluginiconpath:1
# heateorssshorizontalsharingcountenable:1
# heateorsssverticalsharingcountenable:1
# heateorssssharingoffset:1
# heateorsssmobilestickysharingenabled:1
# heateorssscopylinkmessage:1
# copied:1
# heateorsssurlcountfetched:1
# heateorssssharestext:1
# heateorssssharetext:1
# heateorssspopup:1
# popupwindow:1
# resizable:1
# scrollbars:1
# status:1
# heateorssswhatsappshareapi:1
# j:1
# tz:1
# srv:1

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq.plot(30, cumulative=False)

# %% [markdown]
# # 2. Eliminar Palabras de Parada

# %%
from nltk.corpus import stopwords

clean_tokens = tokens[:]
 
for token in tokens:
 
    if token in stopwords.words('spanish'):
 
        clean_tokens.remove(token)

# %%
print(clean_tokens)
# Out:
# ['libertad', 'financiera', 'background', 'circle', 'at', 'color', 'fff', 'solid', 'transparent', 'color', 'hover', 'hover', 'transparent', 'color', 'fff', 'solid', 'transparent', 'color', 'hover', 'hover', 'transparent', 'media', 'screen', 'and', 'display', 'none', 'important', 'media', 'screen', 'and', 'display', 'none', 'important', 'display', 'none', 'media', 'screen', 'and', 'white', 'important', 'important', 'important', 'li', 'important', 'width', 'important', 'important', 'important', 'important', 'important', 'display', 'block', 'important', 'display', 'block', 'important', 'width', 'auto', 'important', 'bottom', 'important', 'top', 'auto', 'important', 'inherit', 'display', 'none', 'important', 'context', 'https', 'graph', 'type', 'person', 'organization', 'id', 'https', 'name', 'image', 'type', 'imageobject', 'id', 'https', 'personlogo', 'url', 'https', 'caption', 'logo', 'id', 'https', 'personlogo', 'sameas', 'type', 'website', 'id', 'https', 'website', 'url', 'https', 'name', 'financiero', 'alcanza', 'independencia', 'publisher', 'id', 'https', 'potentialaction', 'type', 'searchaction', 'target', 'https', 'required', 'type', 'imageobject', 'id', 'https', 'primaryimage', 'url', 'https', 'width', 'height', 'type', 'webpage', 'id', 'https', 'webpage', 'url', 'https', 'inlanguage', 'name', 'libertad', 'financiera', 'ispartof', 'id', 'https', 'website', 'about', 'id', 'https', 'primaryimageofpage', 'id', 'https', 'primaryimage', 'datepublished', 'datemodified', 'description', 'alcanzar', 'libertad', 'financiera', 'tener', 'vida', 'deseas', 'puede', 'blog', 'var', 'var', 'true', 'var', 'var', 'disablestr', 'function', 'to', 'detect', 'opted', 'out', 'users', 'function', 'return', 'disablestr', 'disable', 'tracking', 'if', 'the', 'cookie', 'exists', 'if', 'window', 'disablestr', 'true', 'function', 'function', 'disablestr', 'dec', 'utc', 'window', 'disablestr', 'true', 'if', 'function', 'i', 's', 'g', 'r', 'm', 'i', 'i', 'r', 'r', 'i', 'r', 'r', 'arguments', 'i', 'r', 'date', 'm', 'window', 'document', 'true', 'else', 'function', 'https', 'var', 'noopfn', 'function', 'return', 'null', 'var', 'noopnullfn', 'function', 'return', 'null', 'var', 'tracker', 'function', 'return', 'null', 'var', 'p', 'noopfn', 'noopfn', 'noopfn', 'var', 'function', 'var', 'len', 'if', 'len', 'return', 'var', 'f', 'arguments', 'if', 'typeof', 'f', 'f', 'null', 'typeof', 'running', 'function', 'arguments', 'because', 'you', 'are', 'not', 'being', 'return', 'try', 'catch', 'ex', 'function', 'return', 'new', 'tracker', 'noopnullfn', 'function', 'return', 'noopfn', 'window', 'baseurl', 'https', 'ext', 'svgurl', 'https', 'svgext', 'source', 'concatemoji', 'https', 'function', 'b', 'c', 'function', 'd', 'b', 'var', 'this', 'var', 'this', 'b', 'var', 'return', 'function', 'var', 'b', 'if', 'return', 'switch', 'top', 'arial', 'case', 'flag', 'return', 'b', 'case', 'emoji', 'return', 'b', 'return', 'function', 'f', 'var', 'script', 'head', 'c', 'var', 'g', 'h', 'i', 'j', 'canvas', 'for', 'flag', 'emoji', 'everything', 'everythingexceptflag', 'i', 'j', 'i', 'j', 'i', 'j', 'i', 'flag', 'i', 'j', 'i', 'domcontentloaded', 'h', 'load', 'h', 'onload', 'h', 'onreadystatechange', 'function', 'complete', 'f', 'f', 'f', 'window', 'document', 'display', 'inline', 'important', 'border', 'none', 'important', 'none', 'important', 'height', 'important', 'width', 'important', 'margin', 'important', 'important', 'background', 'none', 'important', 'padding', 'important', 'hover', 'color', 'rgb', 'important', 'hover', 'hover', 'hover', 'hover', 'color', 'rgb', 'important', 'float', 'right', 'transparent', 'border', 'solid', 'transparent', 'color', 'padding', 'ul', 'li', 'hover', 'before', 'ul', 'li', 'hover', 'after', 'li', 'after', 'background', 'transparent', 'inset', 'transparent', 'inset', 'transparent', 'li', 'before', 'content', 'li', 'before', 'color', 'li', 'before', 'background', 'cdata', 'var', 'true', 'doc', 'exe', 'js', 'pdf', 'ppt', 'tgz', 'zip', 'xls', 'https' ...

# %%
#Verificar frecuencia de palabras 
freq_clean = nltk.FreqDist(clean_tokens)
for key,val in freq_clean.items():
    print (str(key) + ':' + str(val))

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq_clean.plot(30, cumulative=False)

# %% [markdown]
# # 3a. Obtener Sinónimos

# %%
from nltk.corpus import wordnet
 
synonyms = []
 
for syn in wordnet.synsets('investment'):

    for lemma in syn.lemmas():
 
        synonyms.append(lemma.name())
 
print(synonyms)
# Out:
# ['investing', 'investment', 'investment', 'investment_funds', 'investment', 'investment', 'investment', 'investment', 'investiture']

# %%
#Reemplazar tokens sinónimos
for ind,sin in enumerate(synonyms):
    clean_tokens_sin = [word.replace(synonyms[ind],'investment') for word in clean_tokens]

# %%
#Reemplazar tokens sinónimos manual
sinonimos = ['libertad', 'independencia']
for ind,sin in enumerate(sinonimos):
    clean_tokens_sin = [word.replace(sinonimos[ind],'libertad') for word in clean_tokens]

# %%
#Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin = nltk.FreqDist(clean_tokens_sin)
for key,val in freq_clean_sin.items():
    print (str(key) + ':' + str(val))

# %%
#Visualizar Tokens
freq_clean_sin.plot(30, cumulative=False)

# %% [markdown]
# # 3b. Obtener Antónimos

# %%
from nltk.corpus import wordnet
 
antonyms = []
 
for syn in wordnet.synsets("good"):
 
    for l in syn.lemmas():
 
        if l.antonyms():
 
            antonyms.append(l.antonyms()[0].name())
 
print(antonyms)
# Out:
# ['evil', 'evilness', 'bad', 'badness', 'bad', 'evil', 'ill']

# %% [markdown]
# # 4. Derivación Regresiva

# %%
from nltk.stem import PorterStemmer
 
stemmer = PorterStemmer()
 
print(stemmer.stem('eating'))
# Out:
# eat

# %%
#Derivación regresiva textos en español
from nltk.stem import SnowballStemmer
 
spanish_stemmer = SnowballStemmer('spanish')
 
print(spanish_stemmer.stem("trabajando"))
print(spanish_stemmer.stem("trabajo"))
# Out:
# trabaj
# trabaj

# %%
clean_tokens_sin_stems = [spanish_stemmer.stem(token) for token in clean_tokens_sin]

# %%
clean_tokens_sin_stems
# Out:
# ['libert',
#  'financ',
#  'background',
#  'circl',
#  'at',
#  'color',
#  'fff',
#  'sol',
#  'transparent',
#  'color',
#  'hov',
#  'hov',
#  'transparent',
#  'color',
#  'fff',
#  'sol',
#  'transparent',
#  'color',
#  'hov',
#  'hov',
#  'transparent',
#  'medi',
#  'scre',
#  'and',
#  'display',
#  'non',
#  'important',
#  'medi',
#  'scre',
#  'and',
#  'display',
#  'non',
#  'important',
#  'display',
#  'non',
#  'medi',
#  'scre',
#  'and',
#  'whit',
#  'important',
#  'important',
#  'important',
#  'li',
#  'important',
#  'width',
#  'important',
#  'important',
#  'important',
#  'important',
#  'important',
#  'display',
#  'block',
#  'important',
#  'display',
#  'block',
#  'important',
#  'width',
#  'aut',
#  'important',
#  'bottom',
#  'important',
#  'top',
#  'aut',
#  'important',
#  'inherit',
#  'display',
#  'non',
#  'important',
#  'context',
#  'https',
#  'graph',
#  'type',
#  'person',
#  'organization',
#  'id',
#  'https',
#  'nam',
#  'imag',
#  'type',
#  'imageobject',
#  'id',
#  'https',
#  'personlog',
#  'url',
#  'https',
#  'caption',
#  'log',
#  'id',
#  'https',
#  'personlog',
#  'sam',
#  'type',
#  'websit',
#  'id',
#  'https',
#  'websit',
#  'url',
#  'https',
#  'nam',
#  'financier',
#  'alcanz',
#  'libert',
#  'publish',
#  'id',
#  'https',
#  'potentialaction',
#  'type',
#  'searchaction',
#  'target',
#  'https',
#  'requir',
#  'type',
#  'imageobject',
#  'id',
#  'https',
#  'primaryimag',
#  'url',
#  'https',
#  'width',
#  'height',
#  'type',
#  'webpag',
#  'id',
#  'https',
#  'webpag',
#  'url',
#  'https',
#  'inlanguag',
#  'nam',
#  'libert',
#  'financ',
#  'ispartof',
#  'id',
#  'https',
#  'websit',
#  'about',
#  'id',
#  'https',
#  'primaryimageofpag',
#  'id',
#  'https',
#  'primaryimag',
#  'datepublish',
#  'datemodifi',
#  'description',
#  'alcanz',
#  'libert',
#  'financ',
#  'ten',
#  'vid',
#  'des',
#  'pued',
#  'blog',
#  'var',
#  'var',
#  'tru',
#  'var',
#  'var',
#  'disablestr',
#  'function',
#  'to',
#  'detect',
#  'opted',
#  'out',
#  'users',
#  'function',
#  'return',
#  'disablestr',
#  'disabl',
#  'tracking',
#  'if',
#  'the',
#  'cooki',
#  'exists',
#  'if',
#  'window',
#  'disablestr',
#  'tru',
#  'function',
#  'function',
#  'disablestr',
#  'dec',
#  'utc',
#  'window',
#  'disablestr',
#  'tru',
#  'if',
#  'function',
#  'i',
#  's',
#  'g',
#  'r',
#  'm',
#  'i',
#  'i',
#  'r',
#  'r',
#  'i',
#  'r',
#  'r',
#  'arguments',
#  'i',
#  'r',
#  'dat',
#  'm',
#  'window',
#  'document',
#  'tru',
#  'else',
#  'function',
#  'https',
#  'var',
#  'noopfn',
#  'function',
#  'return',
#  'null',
#  'var',
#  'noopnullfn',
#  'function',
#  'return',
#  'null',
#  'var',
#  'track',
#  'function',
#  'return',
#  'null',
#  'var',
#  'p',
#  'noopfn',
#  'noopfn',
#  'noopfn',
#  'var',
#  'function',
#  'var',
#  'len',
#  'if',
#  'len',
#  'return',
#  'var',
#  'f',
#  'arguments',
#  'if',
#  'typeof',
#  'f',
#  'f',
#  'null',
#  'typeof',
#  'running',
#  'function',
#  'arguments',
#  'becaus',
#  'you',
#  'are',
#  'not',
#  'being',
#  'return',
#  'try',
#  'catch',
#  'ex',
#  'function',
#  'return',
#  'new',
#  'track',
#  'noopnullfn',
#  'function',
#  'return',
#  'noopfn',
#  'window',
#  'baseurl',
#  'https',
#  'ext',
#  'svgurl',
#  'https',
#  'svgext',
#  'sourc',
#  'concatemoji',
#  'https',
#  'function',
#  'b',
#  'c',
#  'function',
#  'd',
#  'b',
#  'var',
#  'this',
#  'var',
#  'this',
#  'b',
#  'var',
#  'return',
#  'function',
#  'var',
#  'b',
#  'if',
#  'return',
#  'switch',
#  'top',
#  'arial',
#  'cas',
#  'flag',
#  'return',
#  'b',
#  'cas',
#  'emoji',
#  'return',
#  'b',
#  'return',
#  'function',
#  'f',
#  'var',
#  'script',
#  'head',
#  'c',
#  'var',
#  'g',
#  'h',
#  'i',
#  'j',
#  'canv',
#  'for',
#  'flag',
#  'emoji',
#  'everything',
#  'everythingexceptflag',
#  'i',
#  'j',
#  'i',
#  'j',
#  'i',
#  'j',
#  'i',
#  'flag',
#  'i',
#  'j',
#  'i',
#  'domcontentload',
#  'h',
#  'load',
#  'h',
#  'onlo',
#  'h',
#  'onreadystatechang',
#  'function',
#  'complet',
#  'f',
#  'f',
#  'f',
#  'window',
#  'document',
#  'display',
#  'inlin',
#  'important',
#  'bord',
#  'non',
#  'important',
#  'non',
#  'important',
#  'height',
#  'important',
#  'width',
#  'important',
#  'margin',
#  'important',
#  'important',
#  'background',
#  'non',
#  'important',
#  'padding',
#  'important',
#  'hov',
#  'color',
#  'rgb',
#  'important',
#  'hov',
#  'hov',
#  'hov',
#  'hov',
#  'color',
#  'rgb',
#  'important',
#  'float',
#  'right',
#  'transparent',
#  'bord',
#  'sol',
#  'transparent',
#  'color',
#  'padding',
#  'ul',
#  'li',
#  'hov',
#  'befor',
#  'ul',
#  'li',
#  'hov',
#  'after',
#  'li',
#  'after',
#  'background',
#  'transparent',
#  'inset',
#  'transparent',
#  'inset',
#  'transparent',
#  'li',
#  'befor',
#  'content',
#  'li',
#  'befor',
#  'color',
#  'li',
#  'befor',
#  'background',
#  'cdat',
#  'var',
#  'tru',
#  'doc',
#  'exe',
#  'js',
#  'pdf',
#  'ppt',
#  'tgz',
#  'zip',
#  'xls',
#  'https',
#  'fals',
#  'cdat',
#  'var',
#  'gdpr',
#  'ajaxurl',
#  'https',
#  'logouturl',
#  'aborting',
#  'aborting',
#  'you',
#  'are',
#  'being',
#  'logg',
#  'out',
#  'continu',
#  'continu',
#  'cancel',
#  'cancel',
#  'ok',
#  'ok',
#  'clos',
#  'your',
#  'account',
#  'your',
#  'account',
#  'will',
#  'be',
#  'clos',
#  'and',
#  'all',
#  'dat',
#  'will',
#  'be',
#  'permanently',
#  'delet',
#  'and',
#  'can',
#  'not',
#  'be',
#  'recover',
#  'are',
#  'you',
#  'sur',
#  'are',
#  'you',
#  'sur',
#  'by',
#  'disagreeing',
#  'you',
#  'will',
#  'long',
#  'hav',
#  'access',
#  'to',
#  'our',
#  'sit',
#  'and',
#  'will',
#  'be',
#  'logg',
#  'out',
#  'refresh',
#  'wpstats',
#  'display',
#  'non',
#  'ul',
#  'ul',
#  'background',
#  'dddddd',
#  'ul',
#  'ul',
#  'li',
#  'dddddd',
#  'ul',
#  'li',
#  'ul',
#  'li',
#  'ul',
#  'color',
#  'focus',
#  'activ',
#  'color',
#  'ul',
#  'hov',
#  'background',
#  'dddddd',
#  'hov',
#  'focus',
#  'activ',
#  'color',
#  'hov',
#  'hov',
#  'hov',
#  'color',
#  'color',
#  'hov',
#  'hov',
#  'color',
#  'hov',
#  'hov',
#  'activ',
#  'hov',
#  'color',
#  'ul',
#  'li',
#  'color',
#  'ul',
#  'li',
#  'hov',
#  'color',
#  'color',
#  'link',
#  'visit',
#  'color',
#  'foot',
#  'color',
#  'color',
#  'color',
#  'color',
#  'color',
#  'red',
#  'color',
#  'gray',
#  'color',
#  'gold',
#  'color',
#  'color',
#  'color',
#  'orang',
#  'color',
#  'left',
#  'width',
#  'position',
#  'relativ',
#  'display',
#  'non',
#  'red',
#  'cent',
#  'important',
#  'display',
#  'non',
#  'skip',
#  'to',
#  'aqu',
#  'pas',
#  'seguirpas',
#  'calcul',
#  'realpas',
#  'control',
#  'categoriz',
#  'ingres',
#  'gast',
#  'personalespas',
#  'valor',
#  'gastospas',
#  'visualiz',
#  'financier',
#  'personalpas',
#  'reduc',
#  'gast',
#  'aument',
#  'ingresospas',
#  'añad',
#  'inversion',
#  'fotopas',
#  'punt',
#  'cort',
#  'libert',
#  'financieraestrategi',
#  'inversioninversion',
#  'rent',
#  'fij',
#  'rent',
#  'variableinversion',
#  'prest',
#  'crowlendinginversion',
#  'desarroll',
#  'personalbloglibr',
#  'recomendadossobr',
#  'interes',
#  'segu',
#  'gast',
#  'hor',
#  'diari',
#  'energ',
#  'trabaj',
#  'dia',
#  'consig',
#  'jubilart',
#  'años',
#  'mejor',
#  'cas',
#  'si',
#  'respuest',
#  'entonc',
#  'blog',
#  'cas',
#  'contrari',
#  'bienven',
#  'comunidadlibrefinancierodond',
#  'aprend',
#  'libert',
#  'financ',
#  'com',
#  'pon',
#  'libert',
#  'financ',
#  'libert',
#  'libert',
#  'financ',
#  'signif',
#  'ten',
#  'trabaj',
#  'establ',
#  'hac',
#  'ric',
#  'libert',
#  'financ',
#  'alcanz',
#  'situacion',
#  'quenodepend',
#  'intercambi',
#  'tiemp',
#  'diner',
#  'sin',
#  'consegu',
#  'diner',
#  'trabaj',
#  'cubr',
#  'estil',
#  'esper',
#  'ten',
#  'cambi',
#  'estil',
#  'vid',
#  'probabl',
#  'hac',
#  'ajust',
#  'estil',
#  'vid',
#  'aprovech',
#  'realment',
#  'import',
#  'lug',
#  'gast',
#  'diner',
#  'inconscient',
#  'mayor',
#  'person',
#  'pais',
#  'avanz',
#  'import',
#  'entiend',
#  'obten',
#  'libert',
#  'financieranodepend',
#  'profesion',
#  'sin',
#  'tas',
#  'ahorr',
#  'calcul',
#  'diferent',
#  'ingres',
#  'gast',
#  'gast',
#  'demostr',
#  'objet',
#  'blog',
#  'libert',
#  'financ',
#  'blog',
#  'trat',
#  'vendert',
#  'sin',
#  'compart',
#  'inform',
#  'pod',
#  'sal',
#  'esclavitud',
#  'sigl',
#  'xxi',
#  'dej',
#  'depend',
#  'intercambi',
#  'energ',
#  'tiemp',
#  'quier',
#  'lug',
#  'pued',
#  'aprend',
#  'tecnic',
#  'sal',
#  'circul',
#  'dia',
#  'olvid',
#  'trabaj',
#  'consum',
#  'hor',
#  'diari',
#  'energ',
#  'sum',
#  'trabaj',
#  'activ',
#  'desplaz',
#  'haci',
#  'trabaj',
#  'tiemp',
#  'pod',
#  'desconect',
#  'lleg',
#  'lug',
#  'consegu',
#  'libert',
#  'financ',
#  'consegu',
#  'libert',
#  'financ',
#  'camin',
#  'sencill',
#  'ningun',
#  'panace',
#  'dig',
#  'contrari',
#  'mint',
#  'camin',
#  'consistent',
#  'ten',
#  'objet',
#  'clar',
#  'sal',
#  'llam',
#  'carrer',
#  'rat',
#  'dec',
#  'dej',
#  'realiment',
#  'circul',
#  'vicios',
#  'mayor',
#  'cas',
#  'sumerg',
#  'circul',
#  'carrer',
#  'rat',
#  'dec',
#  'socied',
#  'enseñ',
#  'trabaj',
#  'paragan',
#  'dinerocon',
#  'increment',
#  'nivel',
#  'vidaal',
#  'aument',
#  'nivel',
#  'vid',
#  'adquier',
#  'posesion',
#  'cas',
#  'coch',
#  'comienz',
#  'endeudart',
#  'gener',
#  'interes',
#  'necesit',
#  'trabaj',
#  'gan',
#  'diner',
#  'hac',
#  'frent',
#  'lasdeudasy',
#  'vuelt',
#  'pas',
#  'intent',
#  'increment',
#  'nivel',
#  'vid',
#  'mejor',
#  'cas',
#  'mejor',
#  'coch',
#  'continu',
#  'bucl',
#  'resum',
#  'cuant',
#  'gan',
#  'gast',
#  'cambi',
#  'cicl',
#  'vid',
#  'alcanz',
#  'libert',
#  'financ',
#  'sigu',
#  'pilar',
#  'pilar',
#  'libert',
#  'financ',
#  'leer',
#  'numer',
#  'libr',
#  'relat',
#  'finanz',
#  'personal',
#  'gust',
#  'compart',
#  'contig',
#  'aprend',
#  'import',
#  'veas',
#  'altern',
#  'vid',
#  'predefin',
#  'trabaj',
#  'sol',
#  'sol',
#  'jubil',
#  'enfoqu',
#  'vid',
#  'cambi',
#  'enseñ',
#  'libert',
#  'financ',
#  'escuel',
#  'pues',
#  'quizas',
#  'interes',
#  'socied',
#  'aprend',
#  'enfoqu',
#  'afront',
#  'futur',
#  'financier',
#  'prefier',
#  'sig',
#  'rebañ',
#  'llev',
#  'rut',
#  'preestablec',
#  'asi',
#  'sig',
#  'comet',
#  'mism',
#  'error',
#  'benefici',
#  'imaginat',
#  'cambi',
#  'mund',
#  'si',
#  'tod',
#  'person',
#  'lug',
#  'trabaj',
#  'jubil',
#  'retir',
#  'menospreci',
#  'ningun',
#  'asignatur',
#  'concret',
#  'bien',
#  'cambi',
#  'hor',
#  'asignatur',
#  'tipic',
#  'introduc',
#  'concept',
#  'basic',
#  'inversion',
#  'inflacion',
#  'tip',
#  'interes',
#  'ayud',
#  'mayor',
#  'ejempl',
#  'moment',
#  'decid',
#  'si',
#  'convien',
#  'hipotec',
#  'quizas',
#  'si',
#  'enseñ',
#  'much',
#  'gent',
#  'plant',
#  'vid',
#  'maner',
#  'interes',
#  'determin',
#  'embarg',
#  'diferent',
#  'busc',
#  'altern',
#  'vid',
#  'convencional',
#  'recom',
#  'comienc',
#  'seccion',
#  'aqu',
#  'posterior',
#  'seccion',
#  'pas',
#  'segu',
#  'pued',
#  'ver',
#  'recomend',
#  'propong',
#  'pod',
#  'alcanz',
#  'libert',
#  'des',
#  'ser',
#  'capaz',
#  'control',
#  'futur',
#  'ello',
#  'unet',
#  'consig',
#  'plantill',
#  'excel',
#  'definit',
#  'control',
#  'finanz',
#  'control',
#  'ingres',
#  'gast',
#  'inversion',
#  'maner',
#  'visualiz',
#  'econom',
#  'conscient',
#  'cuant',
#  'qued',
#  'alcanz',
#  'libert',
#  'nuev',
#  'conten',
#  'librefinancier',
#  'articul',
#  'aport',
#  'valor',
#  'finanz',
#  'personalesh',
#  'leid',
#  'condicion',
#  'bas',
#  'polit',
#  'privacidadn',
#  'ningun',
#  'tip',
#  'spam',
#  'public',
#  'suscribirtet',
#  'lleg',
#  'enlac',
#  'email',
#  'descarg',
#  'plantill',
#  'ayud',
#  'futur',
#  'financieroult',
#  'asegur',
#  'cumplimient',
#  'objet',
#  'financier',
#  'adopt',
#  'mental',
#  'enfoc',
#  'alcanz',
#  'libert',
#  'financ',
#  'gran',
#  'pas',
#  'dud',
#  'cab',
#  ...]

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_stems = nltk.FreqDist(clean_tokens_sin_stems)
for key,val in freq_clean_sin_stems.items():
    print (str(key) + ':' + str(val))
    
#Visualizar Tokens
freq_clean_sin_stems.plot(30, cumulative=False)
# Out:
# libert:81
# financ:71
# background:6
# circl:1
# at:1
# color:31
# fff:2
# sol:18
# transparent:9
# hov:23
# medi:6
# scre:3
# and:6
# display:10
# non:10
# important:29
# whit:1
# li:14
# width:5
# block:2
# aut:2
# bottom:1
# top:3
# inherit:1
# context:1
# https:30
# graph:1
# type:6
# person:10
# organization:1
# id:12
# nam:3
# imag:1
# imageobject:2
# personlog:2
# url:8
# caption:1
# log:1
# sam:1
# websit:3
# financier:24
# alcanz:49
# publish:1
# potentialaction:1
# searchaction:1
# target:1
# requir:1
# primaryimag:2
# height:2
# webpag:2
# inlanguag:1
# ispartof:1
# about:1
# primaryimageofpag:1
# datepublish:1
# datemodifi:1
# description:1
# ten:34
# vid:25
# des:3
# pued:67
# blog:12
# var:31
# tru:5
# disablestr:5
# function:24
# to:5
# detect:2
# opted:1
# out:3
# users:1
# return:14
# disabl:1
# tracking:1
# if:9
# the:1
# cooki:6
# exists:1
# window:5
# dec:27
# utc:1
# i:12
# s:1
# g:2
# r:6
# m:2
# arguments:3
# dat:12
# document:4
# else:2
# noopfn:5
# null:5
# noopnullfn:2
# track:2
# p:2
# len:2
# f:7
# typeof:3
# running:1
# becaus:1
# you:5
# are:4
# not:3
# being:2
# try:1
# catch:1
# ex:1
# new:1
# baseurl:1
# ext:1
# svgurl:1
# svgext:1
# sourc:1
# concatemoji:1
# b:6
# c:2
# d:1
# this:4
# switch:1
# arial:1
# cas:29
# flag:3
# emoji:2
# script:1
# head:1
# h:6
# j:6
# canv:1
# for:2
# everything:1
# everythingexceptflag:1
# domcontentload:1
# load:1
# onlo:1
# onreadystatechang:1
# complet:6
# inlin:1
# bord:2
# margin:1
# padding:2
# rgb:2
# float:1
# right:1
# ul:12
# befor:4
# after:2
# inset:2
# content:1
# cdat:5
# doc:1
# exe:1
# js:1
# pdf:1
# ppt:1
# tgz:1
# zip:1
# xls:1
# fals:1
# gdpr:1
# ajaxurl:2
# logouturl:1
# aborting:2
# logg:2
# continu:8
# cancel:2
# ok:2
# clos:2
# your:2
# account:2
# will:4
# be:4
# all:1
# permanently:1
# delet:1
# can:1
# recover:1
# sur:2
# by:1
# disagreeing:1
# long:1
# hav:1
# access:1
# our:1
# sit:1
# refresh:1
# wpstats:1
# dddddd:3
# focus:2
# activ:16
# link:2
# visit:5
# foot:1
# red:4
# gray:1
# gold:1
# orang:1
# left:2
# position:1
# relativ:1
# cent:1
# skip:1
# aqu:6
# pas:30
# seguirpas:2
# calcul:10
# realpas:2
# control:9
# categoriz:2
# ingres:75
# gast:53
# personalespas:2
# valor:26
# gastospas:2
# visualiz:7
# personalpas:2
# reduc:10
# aument:10
# ingresospas:2
# añad:5
# inversion:50
# fotopas:2
# punt:20
# cort:6
# financieraestrategi:2
# inversioninversion:2
# rent:8
# fij:5
# variableinversion:2
# prest:9
# crowlendinginversion:2
# desarroll:2
# personalbloglibr:2
# recomendadossobr:2
# interes:24
# segu:15
# hor:11
# diari:3
# energ:4
# trabaj:40
# dia:19
# consig:15
# jubilart:1
# años:17
# mejor:29
# si:78
# respuest:7
# entonc:11
# contrari:3
# bienven:1
# comunidadlibrefinancierodond:1
# aprend:6
# com:11
# pon:9
# signif:9
# establ:1
# hac:45
# ric:1
# situacion:13
# quenodepend:1
# intercambi:6
# tiemp:24
# diner:32
# sin:11
# consegu:23
# cubr:11
# estil:4
# esper:13
# cambi:17
# probabl:7
# ajust:3
# aprovech:7
# realment:15
# import:53
# lug:13
# inconscient:1
# mayor:18
# pais:2
# avanz:3
# entiend:1
# obten:6
# financieranodepend:1
# profesion:1
# tas:8
# ahorr:27
# diferent:17
# demostr:2
# objet:28
# trat:5
# vendert:1
# compart:4
# inform:5
# pod:20
# sal:5
# esclavitud:1
# sigl:1
# xxi:1
# dej:16
# depend:6
# quier:20
# tecnic:7
# circul:3
# olvid:1
# consum:7
# sum:3
# desplaz:1
# haci:13
# desconect:4
# lleg:18
# camin:15
# sencill:3
# ningun:8
# panace:1
# dig:2
# mint:4
# consistent:4
# clar:8
# llam:3
# carrer:2
# rat:2
# realiment:1
# vicios:1
# sumerg:1
# socied:6
# enseñ:5
# paragan:1
# dinerocon:1
# increment:2
# nivel:23
# vidaal:1
# adquier:1
# posesion:1
# coch:12
# comienz:1
# endeudart:1
# gener:25
# necesit:19
# gan:4
# frent:1
# lasdeudasy:1
# vuelt:1
# intent:3
# bucl:1
# resum:1
# cuant:7
# cicl:4
# sigu:4
# pilar:2
# leer:2
# numer:5
# libr:1
# relat:5
# finanz:11
# personal:10
# gust:5
# contig:1
# veas:7
# altern:10
# predefin:1
# jubil:4
# enfoqu:8
# escuel:1
# pues:14
# quizas:4
# afront:1
# futur:10
# prefier:3
# sig:8
# rebañ:1
# llev:5
# rut:1
# preestablec:1
# asi:8
# comet:1
# mism:12
# error:1
# benefici:5
# imaginat:1
# mund:3
# tod:9
# retir:8
# menospreci:1
# asignatur:2
# concret:6
# bien:12
# tipic:2
# introduc:1
# concept:3
# basic:9
# inflacion:11
# tip:17
# ayud:6
# ejempl:31
# moment:15
# decid:6
# convien:2
# hipotec:28
# much:10
# gent:3
# plant:4
# maner:19
# determin:4
# embarg:5
# busc:7
# convencional:1
# recom:7
# comienc:2
# seccion:3
# posterior:2
# ver:9
# recomend:5
# propong:2
# ser:12
# capaz:7
# ello:9
# unet:1
# plantill:13
# excel:5
# definit:3
# econom:8
# conscient:4
# qued:8
# nuev:9
# conten:3
# librefinancier:5
# articul:12
# aport:5
# personalesh:2
# leid:2
# condicion:2
# bas:10
# polit:9
# privacidadn:2
# spam:2
# public:2
# suscribirtet:2
# enlac:11
# email:4
# descarg:2
# financieroult:1
# asegur:6
# cumplimient:7
# adopt:3
# mental:7
# enfoc:7
# gran:8
# dud:8
# cab:4
# igual:6
# vez:16
# capac:1
# med:7
# mid:7
# cumpl:9
# aplic:4
# practic:5
# cualqui:8
# marqu:1
# profesional:3
# ayudart:2
# tare:1
# prepar:1
# downloads:1
# veras:6
# divid:1
# part:16
# bloqu:5
# realic:1
# prevision:8
# anual:19
# traves:8
# seri:4
# vay:5
# explic:9
# pestañ:3
# deb:18
# celd:5
# amarill:3
# gris:1
# autocalcul:3
# toc:2
# inicial:6
# total:7
# dispon:5
# invert:23
# mensual:25
# dividel:1
# pens:9
# exist:11
# posibiil:1
# insert:12
# crowfunding:2
# tan:4
# simpl:3
# fil:2
# repart:3
# ide:8
# previst:7
# porcentaj:5
# rentabil:12
# tom:8
# anterior:10
# post:13
# pasiv:41
# segur:22
# puest:18
# man:2
# obra:2
# vas:7
# comenz:5
# via:3
# siguient:24
# ultim:4
# salari:5
# montant:5
# cuent:22
# actual:7
# quer:1
# just:5
# inici:2
# cont:1
# nomin:2
# sobrep:1
# val:2
# result:11
# real:9
# cad:28
# cierr:6
# año:15
# podras:6
# insercion:1
# aun:4
# grafic:8
# abaj:2
# ira:1
# consecu:2
# vs:2
# tal:11
# vem:4
# hech:6
# simul:3
# pep:7
# net:3
# primer:7
# variabl:5
# index:1
# inviert:3
# segund:5
# restant:4
# ambas:1
# ademas:8
# march:1
# fuent:21
# supon:5
# pretend:1
# ve:3
# univers:1
# infinit:3
# posibil:4
# parec:2
# conserv:2
# utiliz:19
# format:3
# condicional:1
# rellen:1
# verd:2
# sab:7
# plasm:1
# realid:3
# sid:2
# rapid:2
# promedi:5
# bastant:2
# alin:2
# expect:1
# visual:1
# signific:2
# dedic:10
# verific:3
# ahor:12
# turn:2
# aprovechat:1
# clav:9
# buen:10
# alla:5
# motiv:3
# conscienci:1
# cuand:2
# fehacient:1
# compartel:2
# comentari:7
# comun:4
# enriquec:2
# read:24
# mor:8
# compr:27
# product:27
# adecuadotod:1
# acomet:4
# rop:3
# tecnolog:7
# vacacion:6
# larg:10
# muestr:3
# fech:7
# idon:1
# vam:8
# adquir:6
# final:7
# diciembr:2
# concesionari:7
# deshac:1
# stock:1
# vent:8
# elig:1
# ir:4
# mes:21
# encontr:5
# fuert:3
# descuent:15
# negoci:1
# trimestr:3
# eleg:4
# seman:5
# hazl:3
# lun:5
# men:14
# usuari:4
# establec:2
# especial:1
# incentiv:1
# volum:5
# unic:6
# comp:1
# cercan:1
# portal:13
# ciud:3
# ahorrart:1
# berlin:1
# septiembr:3
# perfect:2
# adivin:1
# mod:7
# black:2
# friday:2
# cuart:1
# viern:1
# noviembr:1
# cyber:1
# monday:1
# despues:10
# ojo:1
# marketing:4
# abus:1
# ocasion:7
# sub:11
# preci:28
# rebaj:2
# evolu:5
# amazon:7
# celebr:2
# mit:1
# compuest:1
# jorn:1
# laboral:1
# produc:1
# satisfaccion:1
# dependent:1
# planteandot:1
# lf:4
# propon:1
# ibas:1
# luj:1
# quis:2
# retirart:2
# suministr:1
# etern:1
# dejal:1
# buscat:1
# colchon:1
# compañer:1
# flexibl:4
# inflexion:1
# boton:1
# alcist:1
# suplement:1
# dand:1
# clas:2
# yog:2
# opto:1
# pur:1
# pasion:1
# extens:2
# collins:1
# autor:3
# path:1
# wealth:1
# inerci:1
# util:1
# recompens:1
# octob:2
# impo:1
# morecom:2
# adecuadoseptemb:2
# pe:1
# moreingres:2
# financieraseptemb:2
# economiaaugust:2
# morec:2
# noaugust:2
# morepiramid:2
# financierasjun:2
# may:2
# morehit:2
# financieraapril:2
# morejquery:2
# paus:2
# enter:2
# key:2
# jquery:2
# unirs:1
# financierobusquedasearch:1
# searchult:1
# v:2
# q:1
# financi:1
# fin:2
# autoriz:1
# material:1
# consent:1
# expres:3
# escrit:1
# estrict:1
# prohib:1
# redireccion:1
# miest:1
# siti:1
# recog:1
# privac:4
# modific:1
# preferent:1
# acept:1
# privacy:1
# preferencesi:1
# agreeprivacy:1
# preferenc:1
# centeroptionsconsent:1
# managementcooki:1
# settingsanalyticspolit:1
# cookiesconsent:1
# managementpolit:1
# cookiesrequiredconsient:1
# blognecesari:1
# usan:3
# almacen:2
# nombr:2
# ip:3
# formulari:2
# contact:2
# identific:1
# comprend:1
# math:2
# asblockinlineadditional:1
# settingsformul:1
# colortext:1
# idformul:1
# classestyp:1
# nothing:1
# previewinsertfunction:1
# atomicblocksshar:1
# titl:2
# w:2
# mabajax:1
# action:1
# wpspinn:1
# spinn:1
# basestylesurl:1
# wpgroh:1
# heateorsssloadevent:1
# t:1
# heateorssssharingajaxurl:1
# heateorssscloseiconpath:1
# heateorssspluginiconpath:1
# heateorssshorizontalsharingcounten:1
# heateorsssverticalsharingcounten:1
# heateorssssharingoffset:1
# heateorsssmobilestickysharingenabl:1
# heateorssscopylinkmessag:1
# heateorsssurlcountfetch:1
# heateorssssharestext:1
# heateorssssharetext:1
# heateorssspopup:1
# popupwindow:1
# resiz:1
# scrollbars:1
# status:1
# heateorssswhatsappshareapi:1
# pagination:2
# autoanimat:2
# autoanimatetrans:2
# animationloop:2
# slideshowsp:2
# slidesp:2
# pausehov:2
# pauseaction:2
# slidedirection:2
# touch:2
# tz:1
# srv:1

# %% [markdown]
# # 5. Lematizar palabras

# %%
from nltk.stem import WordNetLemmatizer
 
lemmatizer = WordNetLemmatizer()
 
print(lemmatizer.lemmatize('working', pos="v")) #sustantivos de manera predeterminada, especificar "v" si se quieren los verbos
# Out:
# work

# %%
#Alternativa para texto en español --- Instalar spacy: pip install spacy
import spacy
nlp = spacy.blank('es')
#alternativa: nlp= spacy.load('es_core_news_md') #más información abajo

# %%
#Lematizar tokens tras limpieza y convertidos los sinónimos
clean_tokens_sin_lem = []
separator = ' '
for token in nlp(separator.join(clean_tokens_sin)): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.lemma_, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)
# Out:
# background background PROPN
# circle circle PROPN
# at at PROPN
# color color NOUN
# fff fff PROPN
# solid solid PROPN
# transparent transparent PROPN
# color color NOUN
# hover hover VERB
# hover hover VERB
# transparent transparent ADJ
# color color NOUN
# fff fff PROPN
# solid solid PROPN
# transparent transparent PROPN
# color color NOUN
# hover hover VERB
# hover hover VERB
# transparent transparent INTJ
# media medio PROPN
# screen screen AUX
# and and PROPN
# display display PROPN
# none none PROPN
# important important PROPN
# media medio PROPN
# screen screen AUX
# and and PROPN
# display display PROPN
# none none PROPN
# important important PROPN
# display display PROPN
# none none PROPN
# media medio PROPN
# screen screen AUX
# and and INTJ
# white white PROPN
# important important PROPN
# important important PROPN
# important important PROPN
# li li PROPN
# important important PROPN
# width width PROPN
# important important PROPN
# important important PROPN
# important important PROPN
# important important PROPN
# important important PROPN
# display display PROPN
# block block PROPN
# important important PROPN
# display display PROPN
# block block PROPN
# important important PROPN
# width width PROPN
# auto auto PROPN
# important important PROPN
# bottom bottom PROPN
# important important PROPN
# top top PROPN
# auto auto PROPN
# important important PROPN
# inherit inherit PROPN
# display display PROPN
# none none PROPN
# important important PROPN
# libertad libertar NOUN
# financiera financiero ADJ
# context context VERB
# https https PROPN
# graph graph PROPN
# type type PROPN
# person person PROPN
# organization organization PROPN
# id ir ADP
# https https PROPN
# name name ADJ
# image image PROPN
# type type PROPN
# imageobject imageobject PROPN
# id ir ADP
# https https PROPN
# personlogo personlogo NOUN
# inlanguage inlanguage PROPN
# url url PROPN
# https https PROPN
# caption caption PROPN
# logo logo PROPN
# id ir ADP
# https https PROPN
# personlogo personlogo NOUN
# type type PROPN
# website website PROPN
# id ir ADP
# https https PROPN
# website website PROPN
# url url PROPN
# https https PROPN
# name name ADJ
# financiero financiero ADJ
# alcanza alcanzar VERB
# libertad libertar NOUN
# description description ADJ
# publisher publisher PROPN
# id ir ADP
# https https PROPN
# potentialaction potentialaction PROPN
# type type PROPN
# searchaction searchaction PROPN
# target target PROPN
# https https PROPN
# required required PROPN
# inlanguage inlanguage PROPN
# type type PROPN
# imageobject imageobject PROPN
# id ir ADP
# https https PROPN
# primaryimage primaryimage VERB
# inlanguage inlanguage PROPN
# url url PROPN
# https https PROPN
# width width PROPN
# height height PROPN
# caption caption PROPN
# libertad libertar PROPN
# financiera financiero ADJ
# type type PROPN
# webpage webpage PROPN
# id ir ADP
# https https PROPN
# webpage webpage PROPN
# url url PROPN
# https https PROPN
# name name ADJ
# libertad libertar NOUN
# financiera financiero ADJ
# ispartof ispartof AUX
# id ir ADP
# https https PROPN
# website website PROPN
# about about PROPN
# id ir ADP
# https https PROPN
# primaryimageofpage primaryimageofpage PROPN
# id ir ADP
# https https PROPN
# primaryimage primaryimage PROPN
# datepublished datepublished PROPN
# datemodified datemodified NOUN
# description description PROPN
# alcanzar alcanzar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# tener tener VERB
# vida vida NOUN
# deseas desear NOUN
# puede poder AUX
# blog blog PROPN
# inlanguage inlanguage PROPN
# potentialaction potentialaction PROPN
# type type PROPN
# readaction readaction PROPN
# target target PROPN
# https https PROPN
# dzgizzg dzgizzg ADJ
# var var VERB
# var var VERB
# true true NOUN
# var var VERB
# var var VERB
# disablestr disablestr ADJ
# function function PROPN
# to to PROPN
# detect detect PROPN
# opted opted PROPN
# out out PROPN
# users users PROPN
# function function PROPN
# return return PROPN
# disablestr disablestr PROPN
# disable disable ADJ
# tracking tracking PROPN
# if if PROPN
# the the PROPN
# cookie cookie PROPN
# exists exists PROPN
# if if PROPN
# window window PROPN
# disablestr disablestr PROPN
# true true PROPN
# function function PROPN
# function function PROPN
# disablestr disablestr PROPN
# dec dec PROPN
# utc utc PROPN
# window window PROPN
# disablestr disablestr PROPN
# true true NOUN
# if if PROPN
# typeof typeof PROPN
# gaoptout gaoptout PROPN
# function function PROPN
# gaoptout gaoptout PROPN
# if if PROPN
# function function PROPN
# i i CCONJ
# s segundo PROPN
# g gramo PROPN
# r r CCONJ
# m metro PROPN
# i i CCONJ
# i i CCONJ
# r r CCONJ
# r r CCONJ
# i i CCONJ
# r r CCONJ
# r r CCONJ
# arguments arguments PROPN
# i i CCONJ
# r r CCONJ
# new new PROPN
# date datar PROPN
# m metro PROPN
# window window PROPN
# document document PROPN
# true true PROPN
# else else VERB
# function function PROPN
# https https PROPN
# var var VERB
# noopfn noopfn PROPN
# function function PROPN
# return return PROPN
# null null PROPN
# var var PROPN
# noopnullfn noopnullfn PROPN
# function function PROPN
# return return PROPN
# null null PROPN
# var var PROPN
# tracker tracker PROPN
# function function PROPN
# return return PROPN
# null null PROPN
# var var VERB
# p página ADP
# noopfn noopfn ADJ
# noopfn noopfn ADJ
# noopfn noopfn AUX
# var var VERB
# function function PROPN
# var var PROPN
# len len PROPN
# if if PROPN
# len len PROPN
# return return PROPN
# var var VERB
# f f ADP
# arguments arguments PROPN
# if if PROPN
# typeof typeof PROPN
# f f CCONJ
# f f CCONJ
# null null PROPN
# typeof typeof PROPN
# running running PROPN
# function function PROPN
# arguments arguments PROPN
# because because PROPN
# you you PROPN
# are arar PROPN
# not not PROPN
# being being PROPN
# return return PROPN
# try try INTJ
# catch catch NOUN
# ex ex ADJ
# function function PROPN
# return return PROPN
# new new PROPN
# tracker tracker PROPN
# noopnullfn noopnullfn PROPN
# function function PROPN
# return return PROPN
# noopfn noopfn PROPN
# window window PROPN
# baseurl baseurl VERB
# https https PROPN
# ext ext PROPN
# svgurl svgurl VERB
# https https PROPN
# svgext svgext PROPN
# source source VERB
# concatemoji concatemoji PROPN
# https https PROPN
# function function PROPN
# t t INTJ
# var var VERB
# r r CCONJ
# n n INTJ
# i i CCONJ
# canvas canvas PROPN
# function function PROPN
# c c INTJ
# t t INTJ
# var var VERB
# this this PROPN
# var var PROPN
# return return PROPN
# this this PROPN
# t t PROPN
# function function PROPN
# l litro PROPN
# if if PROPN
# return return PROPN
# switch switch NOUN
# top top INTJ
# arial arial ADJ
# case casar PROPN
# flag flag PROPN
# return return PROPN
# c c PROPN
# c c INTJ
# you you PROPN
# will will PROPN
# longer longer PROPN
# have have VERB
# access access ADV
# to to PROPN
# our our PROPN
# site site PROPN
# and and PROPN
# will will PROPN
# be be PROPN
# logged logged PROPN
# out out PROPN
# refresh refresh PROPN
# cdata cdata PROPN
# var var PROPN
# id ir ADP
# pagination pagination PROPN
# autoanimate autoanimate PROPN
# autoanimatetrans autoanimatetrans PROPN
# animationloop animationloop PROPN
# slideshowspeed slideshowspeed PROPN
# slidespeed slidespeed PROPN
# pausehover pausehover PROPN
# pauseaction pauseaction PROPN
# slidedirection slidedirection PROPN
# touch touch PROPN
# wpstats wpstats PROPN
# display display PROPN
# none none PROPN
# ul ul DET
# ul ul PRON
# background background INTJ
# dddddd dddddd VERB
# ul ul DET
# ul ul DET
# li li PROPN
# dddddd dddddd VERB
# ul ul DET
# li li PROPN
# ul ul PROPN
# li li VERB
# ul ul DET
# color color NOUN
# focus focus PROPN
# active activar PROPN
# color color NOUN
# ul ul DET
# hover hover VERB
# background background ADJ
# dddddd dddddd AUX
# hover hover VERB
# focus focus PROPN
# active activar ADJ
# color color NOUN
# hover hover VERB
# hover hover VERB
# hover hover VERB
# color color NOUN
# color color NOUN
# hover hover VERB
# hover hover VERB
# color color NOUN
# hover hover VERB
# hover hover VERB
# active activar NOUN
# hover hover VERB
# color color NOUN
# ul ul DET
# li li ADP
# color color NOUN
# ul ul DET
# li li ADP
# hover hover VERB
# color color NOUN
# color color NOUN
# link link PROPN
# visited visited PROPN
# color color PROPN
# footer footer PROPN
# color color NOUN
# color color NOUN
# color color NOUN
# color color NOUN
# color color NOUN
# red red PROPN
# color color NOUN
# gray gray PROPN
# color color NOUN
# gold gold ADJ
# color color NOUN
# color color NOUN
# color color NOUN
# orange orange ADJ
# color color NOUN
# left left PROPN
# width width PROPN
# position position PROPN
# relative relative PROPN
# display display PROPN
# none none PROPN
# red red PROPN
# center center PROPN
# important important PROPN
# display display PROPN
# none none PROPN
# skip skip PROPN
# to to PROPN
# aquí aquí ADV
# pasos paso NOUN
# seguirpaso seguirpaso NOUN
# calcula calcular VERB
# realpaso realpaso ADJ
# controla controlar PROPN
# categoriza categorizar VERB
# ingresos ingreso NOUN
# gastos gasto ADJ
# personalespaso personalespaso PROPN
# valora valorar VERB
# gastospaso gastospaso PROPN
# visualiza visualizar PROPN
# financiero financiero ADJ
# personalpaso personalpaso ADJ
# reduce reducir VERB
# gastos gasto NOUN
# aumenta aumentar VERB
# ingresospaso ingresospaso PROPN
# añade añadir VERB
# inversiones inversión NOUN
# fotopaso fotopaso ADJ
# punto punto NOUN
# corte cortar VERB
# libertad libertar NOUN
# financieraestrategias financieraestrategias ADJ
# inversióninversión inversióninversión NOUN
# renta rentar NOUN
# fija fijo ADJ
# renta rentar NOUN
# variableinversión variableinversión PROPN
# préstamos préstamo NOUN
# crowlendinginversión crowlendinginversión NOUN
# desarrollo desarrollar PROPN
# personalbloglibros personalbloglibros ADJ
# recomendadossobre recomendadossobre VERB
# interesado interesar ADJ
# seguir seguir VERB
# llegado llegar ADJ
# lugar lugar NOUN
# conseguiremos conseguir VERB
# libertad libertar NOUN
# financiera financiero ADJ
# conseguir conseguir VERB
# libertad libertar NOUN
# financiera financiero ADJ
# camino caminar NOUN
# sencillo sencillo ADJ
# ninguna ninguno DET
# panacea panacea NOUN
# diga decir VERB
# contrario contrario ADJ
# mintiendo mentir VERB
# camino caminar NOUN
# consistencia consistencia VERB
# tener tener VERB
# objetivo objetivar NOUN
# claro claro ADJ
# salir salir PROPN
# llama llamar VERB
# carrera carrera NOUN
# rata rata INTJ
# decir decir VERB
# dejar dejar VERB
# realimentar realimentar VERB
# círculo círculo NOUN
# vicioso vicioso ADJ
# mayoría mayoría NOUN
# casos caso NOUN
# sumergidos sumergir ADJ
# círculo círculo ADJ
# carrera carrera NOUN
# rata rata VERB
# decir decir VERB
# sociedad sociedad NOUN
# enseñado enseñar ADJ
# trabajar trabajar VERB
# paraganar paraganar VERB
# dinerocon dinerocon NOUN
# incrementar incrementar VERB
# nivel nivel NOUN
# vidaal vidaal ADJ
# aumentar aumentar VERB
# nivel nivel NOUN
# vida vida PROPN
# adquieres adquirir PROPN
# posesiones posesionar PROPN
# casa casar PROPN
# coche coche NOUN
# comienzas comenzar NOUN
# endeudarte endeudarte NOUN
# generan generar AUX
# intereses interesar NOUN
# necesitas necesitar ADJ
# trabajar trabajar VERB
# ganar ganar VERB
# dinero dinero NOUN
# hacer hacer VERB
# frente frente NOUN
# lasdeudasy lasdeudasy ADV
# vuelta volver NOUN
# paso pasar NOUN
# intentando intentar AUX
# incrementar incrementar VERB
# nivel nivel NOUN
# vida vida NOUN
# mejor mejor ADJ
# casa casar NOUN
# mejor mejor ADJ
# coche coche NOUN
# continuando continuar VERB
# bucle bucle PROPN
# resumen resumir AUX
# cuanto cuanto ADV
# ganas ganar NOUN
# gastas gastar ADJ
# cambiar cambiar VERB
# ciclo ciclar NOUN
# vida vida PROPN
# alcanzar alcanzar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# siguiendo seguir VERB
# pilares pilar NOUN
# pilares pilar ADJ
# libertad libertar NOUN
# financiera financiero ADJ
# leer leer VERB
# numerosos numeroso ADJ
# libros libro NOUN
# relativos relativo ADJ
# finanzas finanzas NOUN
# personales personal ADJ
# gustaría gustar VERB
# compartir compartir VERB
# contigo contigo PRON
# aprendido aprender ADJ
# importante importante ADJ
# veas ver NOUN
# alternativa alternativo ADJ
# vida vida NOUN
# predefinida predefinir ADJ
# trabajar trabajar VERB
# sol sol NOUN
# sol sol NOUN
# jubilación jubilación NOUN
# enfoque enfocar VERB
# vida vida NOUN
# cambiará cambiar VERB
# enseñado enseñar ADJ
# libertad libertar NOUN
# financiera financiero ADJ
# escuela escuela VERB
# pues pues SCONJ
# quizás quizás ADV
# interesa interesar VERB
# sociedad sociedad NOUN
# aprenda aprender ADJ
# enfoques enfoque NOUN
# afrontar afrontar VERB
# futuro futuro NOUN
# financiero financiero ADJ
# prefiere preferir VERB
# sigamos seguir AUX
# rebaño rebañar NOUN
# llevemos llevar VERB
# ruta ruta NOUN
# preestablecida preestablecer ADJ
# así asir ADV
# sigamos seguir AUX
# cometiendo cometer VERB
# mismos mismo DET
# errores error NOUN
# beneficien beneficiar ADV
# imagínate imagínate VERB
# cambiaría cambiar VERB
# mundo mundo NOUN
# si si SCONJ
# todas todo DET
# personas personar NOUN
# lugar lugar NOUN
# trabajar trabajar VERB
# jubilación jubilación NOUN
# retirasen retirar VERB
# menospreciar menospreciar VERB
# ninguna ninguno DET
# asignatura asignatura NOUN
# concreta concreto ADJ
# bien bien ADV
# cambiar cambiar VERB
# horas hora NOUN
# asignaturas asignatura ADJ
# típicas típico ADJ
# introducirnos introducirnos ADJ
# conceptos concepto ADJ
# básicos básico ADJ
# inversión inversión NOUN
# inflación inflación VERB
# tipos tipo NOUN
# interés interés NOUN
# ayudarían ayudar VERB
# mayores mayor ADJ
# ejemplo ejemplo NOUN
# momento momento NOUN
# decidir decidir VERB
# si si SCONJ
# conviene convenir VERB
# hipotecarnos hipotecarnos VERB
# quizás quizás ADV
# si si SCONJ
# enseñado enseñar ADJ
# mucha mucho DET
# gente gente NOUN
# planteado plantear ADJ
# vida vida NOUN
# manera manera ADJ
# interesa interesar VERB
# determinados determinar ADJ
# embargo embargar NOUN
# diferente diferente ADJ
# buscando buscar VERB
# alternativa alternativo ADJ
# vida vida NOUN
# convencional convencional ADJ
# recomiendo recomer VERB
# comiences comenzar NOUN
# sección sección NOUN
# aquí aquí ADV
# posteriormente posteriormente ADV
# sección sección NOUN
# pasos paso NOUN
# seguir seguir VERB
# puedes poder AUX
# ver ver VERB
# recomendaciones recomendación NOUN
# propongo proponer VERB
# poder poder VERB
# alcanzar alcanzar VERB
# libertad libertar NOUN
# deseas desear ADJ
# ser ser VERB
# capaz capaz ADJ
# controlar controlar VERB
# futuro futuro ADJ
# ello él PRON
# únete únete ADJ
# consigue conseguir VERB
# plantilla plantilla NOUN
# excel excel AUX
# definitiva definitivo ADJ
# controlar controlar VERB
# finanzas finanzas NOUN
# controlarás controlar ADV
# ingresos ingreso NOUN
# gastos gasto ADJ
# inversiones inversión NOUN
# manera manera NOUN
# visualiza visualizar VERB
# económico económico ADJ
# consciente consciente ADJ
# cuánto cuánto PRON
# queda quedo VERB
# alcanzar alcanzar VERB
# libertad libertar NOUN
# nuevo nuevo ADJ
# contenido contener NOUN
# librefinanciero librefinanciero ADJ
# artículos artículo NOUN
# aporten aportar VERB
# valor valor NOUN
# finanzas finanzas PROPN
# personaleshe personaleshe PROPN
# leído leer VERB
# condiciones condicionar NOUN
# base basar NOUN
# política político ADJ
# privacidadno privacidadno VERB
# ningún ninguno DET
# tipo tipo NOUN
# spam spam PROPN
# publicidad publicidad NOUN
# suscribirtete suscribirtete PROPN
# llegará llegar VERB
# enlace enlazar NOUN
# email email ADJ
# descarga descargar NOUN
# plantillas plantilla NOUN
# ayudarán ayudar VERB
# futuro futuro NOUN
# financieroúltimos financieroúltimos VERB
# fin fin NOUN
# libertad libertar NOUN
# financiera financiero ADJ
# viviendo vivir VERB
# tiempos tiempo NOUN
# complicados complicar ADJ
# debido deber ADP
# pandemia pandemia NOUN
# generada generar ADJ
# puesto poner INTJ
# jaque jaque NOUN
# sociedad sociedad NOUN
# solo solo ADJ
# punto punto NOUN
# vista vestir ADJ
# financiero financiero ADJ
# sino sino CCONJ
# punto punto NOUN
# vista vestir ADJ
# social social ADJ
# dramático dramático ADJ
# afectando afectar VERB
# salud salud NOUN
# millones millón NOUN
# personas personar NOUN
# planeta planeta VERB
# solo solo ADV
# atrevo atrever ADJ
# hablar hablar VERB
# enfoque enfocar NOUN
# financiero financiero ADJ
# puesto poner INTJ
# puntos punto NOUN
# vista vestir ADV
# números número NOUN
# hablan hablar AUX
# solos solo NOUN
# lamentablemente lamentablemente ADV
# acabó acabar VERB
# enfoque enfocar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# pues pues SCONJ
# lejos lejos ADV
# realidad realidad NOUN
# si si SCONJ
# debemos deber AUX
# aprender aprender VERB
# crisis crisis NOUN
# económicas económico ADJ
# seguridad seguridad NOUN
# percibimos percibir VERB
# tener tener VERB
# trabajo trabajar NOUN
# estable estable ADJ
# puede poder AUX
# ir ir VERB
# traste traste INTJ
# noche noche NOUN
# mañana mañana ADV
# situaciones situación NOUN
# totalmente totalmente ADV
# alcance alcanzar VERB
# razón razón NOUN
# tener tener VERB
# estrategia estrategia NOUN
# financiera financiero ADJ
# diferente diferente ADJ
# hace hacer AUX
# menos menos ADV
# vulnerables vulnerable ADJ
# plazo plazo NOUN
# futuras futuro ADJ
# crisis crisis NOUN
# volverá volver VERB
# haber haber VERB
# ello él PRON
# enfoque enfocar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# sale salir VERB
# aún aun ADV
# reforzado reforzar ADJ
# etapa etapa NOUN
# vivimos vivir VERB
# activos activo ADJ
# renta rentar NOUN
# variable variable ADJ
# bajan bajar AUX
# valor valor NOUN
# cada cada DET
# totalmente totalmente ADV
# cierto cierto ADJ
# época época NOUN
# prácticamente prácticamente ADV
# cualquier cualquiera DET
# activo activar NOUN
# devaluando devaluar VERB
# enfoque enfocar NOUN
# financiero financiero ADJ
# inversión inversión NOUN
# consistente consistente ADJ
# largo largar ADJ
# plazo plazo NOUN
# ver ver VERB
# momento momento NOUN
# actual actual ADJ
# oportunidad oportunidad NOUN
# compra comprar VERB
# seguir seguir VERB
# mercado mercar NOUN
# clave clavar NOUN
# éxito éxito NOUN
# superar superar VERB
# emocionalmente emocionalmente ADJ
# momento momento NOUN
# tensión tensión INTJ
# viendo ver AUX
# bajar bajar VERB
# inversiones inversión NOUN
# vender vender VERB
# sino sino CCONJ
# hacer hacer VERB
# justo justar ADV
# contrario contrario ADJ
# post post ADJ
# explico explicar ADJ
# detalle detallar NOUN
# modo modo ADP
# referencia referenciar NOUN
# veas ver ADJ
# devaluación devaluación NOUN
# diferentes diferente ADJ
# índices índice NOUN
# bursátiles bursátil ADJ
# evolución evolución NOUN
# s segundo CCONJ
# evolución evolución NOUN
# euro euro NOUN
# stoxx stoxx NOUN
# resumen resumir AUX
# índices índice NOUN
# bursátiles bursátil ADJ
# decir decir VERB
# ejemplo ejemplo NOUN
# momento momento NOUN
# mínimo mínimo ADJ
# índice índice NOUN
# s segundo CCONJ
# tras tras ADP
# aparición aparición NOUN
# podríamos poder AUX
# haber haber VERB
# adquirido adquirir VERB
# mismo mismo DET
# activo activar NOUN
# menos menos ADV
# dicho decir ADJ
# así asir ADV
# ventajista ventajista VERB
# obviamente obviamente ADV
# queremos querer VERB
# caer caer VERB
# especulación especulación NOUN
# difícil difícil ADJ
# haber haber VERB
# acertado acertar VERB
# justo justar ADJ
# momento momento NOUN
# mínimo mínimo ADJ
# cierto cierto ADJ
# si si SCONJ
# estrategia estrategia NOUN
# basada basar ADJ
# inversión inversión NOUN
# consistente consistente ADJ
# manera manera NOUN
# mensual mensual ADJ
# probable probable ADJ
# aprovechado aprovechar ADJ
# situación situación NOUN
# poner poner VERB
# escenario escenario NOUN
# basado basar ADJ
# últimos último ADJ
# meses mesar NOUN
# vamos ir AUX
# ver ver VERB
# misma mismo DET
# comparativa comparativo NOUN
# utilizando utilizar VERB
# promedio promediar NOUN
# media medio INTJ
# móvil móvil ADJ
# últimos último ADJ
# meses mesar NOUN
# resumen resumir AUX
# índices índice NOUN
# bursátiles bursátil ADJ
# diferencia diferenciar VERB
# caso casar NOUN
# vemos ver VERB
# últimos último ADJ
# meses mesar NOUN
# aprovechado aprovechar ADJ
# obtener obtener VERB
# mismo mismo DET
# activo activar NOUN
# rebaja rebajar VERB
# caso casar NOUN
# s segundo CCONJ
# caso casar NOUN
# euro euro PROPN
# stoxx stoxx NOUN
# hecho hacer ADJ
# estrategia estrategia NOUN
# inversión inversión NOUN
# mensual mensual ADJ
# aprovechado aprovechar ADJ
# varias varios DET
# ocasiones ocasionar NOUN
# sabemos saber VERB
# bolsa bolsa NOUN
# rentabilidades rentabilidad NOUN
# pasadas pasar ADJ
# garantizan garantizar AUX
# rentabilidades rentabilidad NOUN
# futuras futuro ADJ
# hecho hacer ADJ
# probable probable ADJ
# siga seguir VERB
# vaivenes vaivén NOUN
# mercado mercar NOUN
# importante importante ADJ
# consigamos conseguir ADJ
# mantenernos mantenernos NOUN
# firmes firme ADJ
# desistir desistir VERB
# estrategia estrategia NOUN
# largoplacista largoplacista ADJ
# recuerda recordar VERB
# tiempo tiempo NOUN
# mercado mercar NOUN
# estrategia estrategia VERB
# largo largar ADJ
# plazo plazo NOUN
# siempre siempre ADV
# vencerá vencer VERB
# temporizar temporizar VERB
# mercado mercar NOUN
# especulación especulación NOUN
# impacta impactar ADJ
# crisis crisis NOUN
# mercado mercar NOUN
# cada cada DET
# fase fase NOUN
# libertad libertar NOUN
# financiera financiero ADJ
# sabemos saber VERB
# grandes grande ADJ
# rasgos rasgo NOUN
# existen existir AUX
# fases fase NOUN
# bien bien ADV
# diferenciadas diferenciar ADJ
# enfoque enfocar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# fase fase NOUN
# acumulación acumulación NOUN
# periodo periodo NOUN
# acumulando acumular VERB
# riqueza riqueza NOUN
# través través ADV
# diferentes diferente ADJ
# activos activo NOUN
# si si SCONJ
# seguimos seguir VERB
# regla reglar NOUN
# objetivo objetivar ADJ
# conseguir conseguir VERB
# portfolio portfolio ADJ
# valorado valorar ADJ
# veces vez NOUN
# gastos gasto NOUN
# retirada retirar ADJ
# periodo periodo NOUN
# alcanzado alcanzar ADJ
# valor valor NOUN
# objetivo objetivar ADJ
# partir partir INTJ
# podremos poder VERB
# vivir vivir VERB
# rentabilidades rentabilidad NOUN
# generan generar AUX
# activos activo NOUN
# crisis crisis NOUN
# económica económico ADJ
# fase fase NOUN
# acumulación acumulación NOUN
# deja dejar VERB
# ser ser VERB
# oportunidad oportunidad NOUN
# compra comprar VERB
# adquirir adquirir VERB
# nuevos nuevo ADJ
# activos activo NOUN
# precio preciar NOUN
# saldo saldar NOUN
# embargo embargar NOUN
# mayor mayor ADJ
# riesgo riesgo NOUN
# fase fase NOUN
# retirada retirar ADJ
# puesto poner ADJ
# seguir seguir VERB
# manteniendo mantener VERB
# nivel nivel NOUN
# vida vida INTJ
# necesario necesario ADJ
# retirar retirar VERB
# mayor mayor ADJ
# porcentaje porcentaje NOUN
# riqueza riqueza VERB
# cubrir cubrir VERB
# gastos gasto NOUN
# vamos ir AUX
# verlo verlo VERB
# ejemplo ejemplo NOUN
# gastos gasto NOUN
# anuales anual ADJ
# activos activo ADJ
# necesario necesario ADJ
# regla reglar NOUN
# x x ADJ
# imaginemos imaginar AUX
# alcanzado alcanzar ADJ
# valor valor NOUN
# activos activo ADJ
# sabemos saber VERB
# largo largar ADJ
# plazo plazo NOUN
# índice índice NOUN
# msci msci PROPN
# promedio promediar NOUN
# anual anual ADJ
# situación situación NOUN
# normal normal ADJ
# fase fase NOUN
# retirada retirar ADJ
# siguiente siguiente ADJ
# tras tras ADP
# año año NOUN
# valor valor NOUN
# portfolio portfolio ADJ
# x x PROPN
# dinero dinero NOUN
# valor valor NOUN
# portfolio portfolio ADJ
# valor valor NOUN
# portfolio portfolio ADJ
# final final ADJ
# habitual habitual ADJ
# considerando considerar VERB
# rentabilidad rentabilidad NOUN
# largo largar ADJ
# plazo plazo NOUN
# promedio promediar ADJ
# retirado retirar ADJ
# cubrir cubrir VERB
# gastos gasto NOUN
# además además ADV
# valor valor NOUN
# portfolio portfolio ADJ
# aún aun ADV
# mayor mayor ADJ
# ocurre ocurrir VERB
# si si SCONJ
# justo justar ADV
# empezamos empezar VERB
# fase fase NOUN
# retirada retirar ADJ
# caída caer ADJ
# mercado mercar NOUN
# pues pues SCONJ
# tras tras ADP
# año año NOUN
# resultado resultar NOUN
# siguiente siguiente ADJ
# suponiendo suponer VERB
# mercado mercar NOUN
# cae caer VERB
# valor valor NOUN
# portfolio portfolio ADJ
# x x PROPN
# dinero dinero NOUN
# valor valor NOUN
# portfolio portfolio ADJ
# valor valor NOUN
# portfolio portfolio ADJ
# final final ADJ
# activo activar ADJ
# sufre sufrir VERB
# daño dañar NOUN
# considerable considerable ADJ
# puesto poner ADJ
# retirar retirar VERB
# cubran cubrir VERB
# gastos gasto NOUN
# supone suponer VERB
# peso pesar NOUN
# porcentual porcentual ADJ
# mayor mayor ADJ
# escenario escenario NOUN
# habitual habitual ADJ
# recomiendas recomendar ADJ
# hacer hacer VERB
# mitigar mitigar VERB
# riesgo riesgo NOUN
# si si SCONJ
# fase fase NOUN
# retirada retirar ADJ
# aparece aparecer VERB
# crisis crisis NOUN
# económica económico ADJ
# solución solución NOUN
# inmediata inmediato ADJ
# retirar retirar VERB
# valor valor NOUN
# portfolio portfolio ADJ
# etapa etapa NOUN
# crisis crisis NOUN
# financiera financiero ADJ
# claro claro ADJ
# cubrir cubrir VERB
# gastos gasto NOUN
# ideal ideal ADJ
# poder poder VERB
# utilizar utilizar VERB
# fondo fondo PROPN
# emergencia emergencia NOUN
# comentado comentar ADJ
# ocasiones ocasionar NOUN
# si si SCONJ
# vemos ver VERB
# evolución evolución NOUN
# histórica histórico ADJ
# índice índice NOUN
# referencia referenciar NOUN
# msci msci PROPN
# world world PROPN
# pueden poder VERB
# identificar identificar VERB
# diferentes diferente DET
# crisis crisis NOUN
# fácilmente fácilmente ADV
# evolución evolución NOUN
# msci msci PROPN
# world world PROPN
# analicemos analizar AUX
# cuál cuál PRON
# debería deber AUX
# ser ser VERB
# fondo fondo NOUN
# emergencia emergencia NOUN
# ello él PRON
# podemos poder AUX
# hacer hacer VERB
# ejercicio ejercicio NOUN
# simulemos simular VERB
# ocurrido ocurrir ADJ
# portfolio portfolio ADJ
# si si SCONJ
# comenzado comenzar ADJ
# fase fase NOUN
# retirada retirar ADJ
# diferentes diferente ADJ
# años año NOUN
# así asir ADV
# verificar verificar VERB
# cuál cuál DET
# valor valor NOUN
# actual actual ADJ
# cartera cartero NOUN
# cierre cerrar VERB
# año año NOUN
# da dar ADP
# abanico abanicar NOUN
# simulaciones simulación NOUN
# basándonos basándonos ADJ
# datos dato NOUN
# históricos histórico ADJ
# escenario escenario NOUN
# aplicamos aplicar VERB
# regla reglar NOUN
# si si SCONJ
# aplicado aplicar ADJ
# regla reglar NOUN
# anualmente anualmente ADV
# independientemente independientemente ADV
# vaivénes vaivénes NOUN
# mercado mercar NOUN
# considerando considerar VERB
# debido deber ADP
# inflación inflación NOUN
# aumento aumentar ADJ
# coste coste NOUN
# vida vida NOUN
# vamos ir AUX
# tener tener VERB
# aumentar aumentar VERB
# retirada retirar ADJ
# dinero dinero NOUN
# anualmente anualmente ADV
# resultado resultar NOUN
# sido ser VERB
# siguiente siguiente ADJ
# valor valor NOUN
# portfolio portfolio ADJ
# función función NOUN
# año año NOUN
# comience comenzar NOUN
# fase fase NOUN
# retirada retirar ADJ
# tasa tasar ADJ
# vemos ver VERB
# existen existir AUX
# años año NOUN
# si si SCONJ
# comenzado comenzar ADJ
# fase fase NOUN
# retirada retirar ADJ
# valor valor NOUN
# portfolico portfolico ADJ
# actual actual ADJ
# cierre cerrar NOUN
# debajo debajo ADV
# valor valor NOUN
# inicial inicial ADJ
# linea linear ADJ
# verde verde ADJ
# estadísticamente estadísticamente ADJ
# cuenta contar VERB
# simulaciones simulación NOUN
# probabilidad probabilidad NOUN
# mantener mantener VERB
# incrementar incrementar VERB
# portfolio portfolio ADJ
# probabilidad probabilidad NOUN
# valor valor NOUN
# portfolio portfolio ADJ
# valor valor NOUN
# original original ADJ
# escenario escenario NOUN
# optimizando optimizar VERB
# tasa tasar VERB
# retirada retirar ADJ
# podemos poder AUX
# optimizar optimizar VERB
# tasa tasar NOUN
# retirada retirar ADJ
# años año NOUN
# renta rentar NOUN
# variable variable ADJ
# adversa adverso ADJ
# tasa tasar NOUN
# retirada retirar ADJ
# inferior inferior ADJ
# nula nulo ADJ
# ahí ahí ADV
# necesidad necesidad NOUN
# fondo fondo PROPN
# emergencia emergencia NOUN
# podemos poder AUX
# ejemplo ejemplo NOUN
# tomar tomar VERB
# siguiente siguiente ADJ
# fórmula fórmula NOUN
# tras tras ADP
# explorar explorar VERB
# diferentes diferente DET
# combinaciones combinación NOUN
# si si SCONJ
# rentabilidad rentabilidad NOUN
# tasa tasar VERB
# retirada retirar ADJ
# si si SCONJ
# rentabilidad rentabilidad NOUN
# rango rango PROPN
# tasa tasar VERB
# retirada retirar ADJ
# si si SCONJ
# rentabilidad rentabilidad NOUN
# tasa tasar VERB
# retirada retirar ADJ
# máximo máximo ADJ
# años año NOUN
# consecutivos consecutivo ADJ
# tasa tasar NOUN
# retirada retirar ADJ
# caso casar NOUN
# año año NOUN
# aplicamos aplicar VERB
# tasa tasar NOUN
# retirada retirar ADJ
# independientemente independientemente ADV
# haga hacer VERB
# mercado mercar NOUN
# sencilla sencillo ADJ
# regla reglar NOUN
# sido ser VERB
# evolución evolución NOUN
# rentabilidad rentabilidad NOUN
# índice índice NOUN
# msci msci PROPN
# tasa tasar ADJ
# retirada retirar ADJ
# aplicado aplicar ADJ
# tasa tasar ADJ
# retirada retirar NOUN
# optimizada optimizar ADJ
# vemos ver VERB
# situación situación NOUN
# adversa adverso ADJ
# sucedido suceder ADJ
# años año NOUN
# encadenado encadenar ADJ
# años año NOUN
# tasa tasar VERB
# retirada retirar ADJ
# hecho hacer ADJ
# año año NOUN
# activado activar ADJ
# regla reglar NOUN
# puesto poner ADJ
# relativa relativo ADJ
# años año NOUN
# consecutivos consecutivo ADJ
# retirada retirar ADJ
# resultado resultar NOUN
# simulaciones simulación ADJ
# valor valor NOUN
# portfolio portfolio ADJ
# función función NOUN
# año año NOUN
# comience comenzar NOUN
# fase fase NOUN
# retirada retirar ADJ
# tasa tasar ADJ
# optimizada optimizar ADJ
# estadísticamente estadísticamente ADJ
# cuenta contar VERB
# simulaciones simulación NOUN
# tasa tasar VERB
# retirada retirar ADJ
# optimizada optimizar ADJ
# probabilidad probabilidad NOUN
# mantener mantener VERB
# incrementar incrementar VERB
# portfolio portfolio ADJ
# probabilidad probabilidad NOUN
# valor valor NOUN
# portfolio portfolio ADJ
# valor valor NOUN
# original original ADJ
# situación situación NOUN
# escenario escenario NOUN
# favorable favorable ADJ
# cabía caber VERB
# esperar esperar VERB
# puesto poner INTJ
# simulaciones simulación NOUN
# mantenemos mantener VERB
# incrementamos incrementar VERB
# portfolio portfolio NOUN
# buena bueno ADJ
# aproximación aproximación NOUN
# disponer disponer VERB
# fondo fondo PROPN
# emergencia emergencia NOUN
# pueda poder VERB
# cubrir cubrir VERB
# años año NOUN
# gastos gasto ADJ
# si si SCONJ
# pensando pensar AUX
# comenzar comenzar VERB
# fase fase NOUN
# retirada retirar ADJ
# dispones disponer NOUN
# ninguna ninguno DET
# fuente fuente NOUN
# ingresos ingreso NOUN
# podemos poder AUX
# aprender aprender VERB
# crisis crisis NOUN
# respecto respectar INTJ
# situación situación NOUN
# finaciera finaciera ADJ
# si si SCONJ
# coger coger VERB
# múltiples múltiple ADJ
# lecciones lección NOUN
# aprendidas aprender ADJ
# clave clavar NOUN
# diversificación diversificación NOUN
# amplio amplio ADP
# palabra palabra NOUN
# decir decir VERB
# disponer disponer VERB
# múltiples múltiple ADJ
# fuentes fuente NOUN
# ingresos ingreso ADJ
# bien bien ADV
# múltiples múltiple ADJ
# tipos tipo NOUN
# activos activo ADJ
# solo solo INTJ
# renta rentar NOUN
# variable variable ADJ
# sino sino CCONJ
# opciones opción NOUN
# crowlending crowlending PROPN
# reducirá reducir VERB
# riesgo riesgo NOUN
# economía economía VERB
# colapse colapsar AUX
# puesto poner NOUN
# aunque aunque SCONJ
# economía economía NOUN
# global global ADJ
# baje bajar NOUN
# menos menos ADV
# probable probable ADJ
# suceda suceder INTJ
# conforme conformar VERB
# mayor mayor ADJ
# número número NOUN
# fuentes fuente NOUN
# ingresos ingreso NOUN
# activos activo ADJ
# improbable improbable ADJ
# colapsen colapsar VERB
# mismo mismo DET
# tiempo tiempo NOUN
# razón razón NOUN
# recomendación recomendación PROPN
# busques buscar NOUN
# tipos tipo NOUN
# fuentes fuente ADJ
# ingresos ingreso ADJ
# ejemplo ejemplo NOUN
# fuentes fuente NOUN
# ingresos ingreso NOUN
# pasivos pasivo ADJ
# detallaba detallar AUX
# post post VERB
# ingresos ingreso NOUN
# pasivos pasivo ADJ
# acelerador acelerador NOUN
# alcanzar alcanzar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# utilizar utilizar VERB
# diferentes diferente DET
# estrategias estrategia NOUN
# inversión inversión NOUN
# comentadas comentar ADJ
# artículo artículo NOUN
# conclusión conclusión NOUN
# resumen resumir AUX
# siempre siempre ADV
# crisis crisis NOUN
# parece parecer AUX
# acaba acabar AUX
# mundo mundo PROPN
# tener tener VERB
# cuenta contar NOUN
# crisis crisis NOUN
# pasará pasar VERB
# superaremos superar VERB
# esperemos esperar VERB
# pronto pronto ADV
# posible posible ADJ
# mientras mientras SCONJ
# puedas poder VERB
# aprovechar aprovechar VERB
# oportunidades oportunidad NOUN
# brinda brindar PROPN
# historia historia NOUN
# enseñado enseñar ADJ
# bucle bucle PROPN
# infinito infinito PROPN
# épocas época NOUN
# bonanza bonanza NOUN
# épocas época NOUN
# debacle debacle PROPN
# persona personar NOUN
# involucrada involucrar ADJ
# movimiento movimiento PROPN
# libertad libertar NOUN
# financiera financiero ADJ
# necesitas necesitar NOUN
# estrategias estrategia ADJ
# ambas ambos NUM
# etapas etapa NOUN
# si si SCONJ
# suerte suerte NOUN
# cerca cercar ADV
# fase fase NOUN
# retirada retirar ADJ
# considera considerar VERB
# propuesta proponer NOUN
# fondo fondo PROPN
# emergencia emergencia VERB
# ayude ayudar VERB
# mitigar mitigar VERB
# riesgo riesgo NOUN
# encadenar encadenar VERB
# periodos periodo NOUN
# adversos adverso ADJ
# extensos extenso NOUN
# obstante obstante INTJ
# mejor mejor ADJ
# mitigación mitigación NOUN
# riesgos riesgo NOUN
# propia propio DET
# diversificación diversificación NOUN
# nadie nadie PRON
# dijo decir VERB
# vida vida NOUN
# fácil fácil ADJ
# incluso incluso ADV
# vez vez NOUN
# alcanzada alcanzar ADJ
# libertad libertar NOUN
# financiera financiero ADJ
# clave clavar NOUN
# estrategia estrategia NOUN
# superar superar VERB
# tiempos tiempo NOUN
# adversos adverso ADJ
# read read PROPN
# more morar PROPN
# caminos camino NOUN
# alcanzar alcanzar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# triángulo triángulo PROPN
# dinerosi dinerosi PROPN
# seguido seguir ADJ
# blog blog PROPN
# sabes saber VERB
# clave clavar NOUN
# alcanzar alcanzar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# tasa tasar VERB
# ahorro ahorrar NOUN
# solo solo ADJ
# camino caminar NOUN
# alcanzar alcanzar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# claro claro ADJ
# ello él PRON
# post post ADJ
# explico explicar ADJ
# caminos camino NOUN
# alcanzar alcanzar VERB
# libertad libertar NOUN
# financiera financiero ADJ
# déjame déjame VERB
# mostrarte mostrarte PROPN
# variables variable NOUN
# fundamentales fundamental ADJ
# triángulo triángulo ADJ
# dinero dinero NOUN
# vértices vértice PROPN
# triángulo triángulo ADJ
# ingresos ingreso NOUN
# dinero dinero NOUN
# consigues conseguir PROPN
# trabajo trabajar NOUN
# negocio negociar ADJ
# dinero dinero NOUN
# gastas gastar PROPN
# día día NOUN
# dinero dinero PROPN
# obtienes obtener NOUN
# invertir invertir VERB
# dinero dinero NOUN
# actual actual ADJ
# finanzas finanzas NOUN
# encuentran encontrar AUX
# medio mediar NUM
# triángulo triángulo ADJ
# tener tener VERB
# cuenta contar NOUN
# si si SCONJ
# alguno alguno DET
# vértices vértice NOUN
# colapsa colapsar VERB
# entonces entonces ADV
# harán hacer VERB
# finanzas finanzas NOUN
# personales personal ADJ
# puesto poner NOUN
# necesario necesario ADJ
# equilibrio equilibrio NOUN
# variables variable PROPN
# ejemplo ejemplo NOUN
# si si SCONJ
# ingresos ingreso NOUN
# colapsan colapsar AUX
# importa importar NOUN
# bien bien ADV
# controles controlar NOUN
# gastos gasto ADJ
# puesto poner INTJ
# obtienes obtener NOUN
# suficiente suficiente ADJ
# dinero dinero NOUN
# decir decir VERB
# dinero dinero NOUN
# disponible disponible ADJ
# invertir invertir VERB
# caso casar NOUN
# persona personar NOUN
# trabajo trabajar NOUN
# bien bien ADV
# salario salariar ADJ
# controlas controlar NOUN
# gastos gasto NOUN
# da dar VERB
# mismo mismo DET
# cuantos cuanto DET
# ingresos ingreso NOUN
# puesto poner ADJ
# vas ir ADJ
# gastar gastar VERB
# igualmente igualmente ADV
# tampoco tampoco ADV
# dinero dinero NOUN
# ahorrado ahorrar ADJ
# invertir invertir VERB
# caso casar NOUN
# personas personar NOUN
# puesto poner ADJ
# trabajo trabajar NOUN
# bien bien ADV
# remunerado remunerar ADJ
# derrochan derrochar AUX
# dinero dinero NOUN
# comprando comprar VERB
# toda todo DET
# clase clase NOUN
# lujos lujo ADJ
# envueltos envolver NOUN
# denominada denominar ADJ
# carrera carrera NOUN
# rata rata VERB
# último último ADV
# si si SCONJ
# inversiones inversión NOUN
# nefastas nefasto ADJ
# importa importar VERB
# ahorres ahorrar NOUN
# invertir invertir VERB
# puesto poner NOUN
# continuamente continuamente ADV
# tirando tirar VERB
# dinero dinero NOUN
# ocurre ocurrir VERB
# personas personar NOUN
# basan basar AUX
# inversiones inversión NOUN
# pura puro ADJ
# especulación especulación NOUN
# conocimientos conocimiento NOUN
# necesarios necesario ADJ
# inversión inversión NOUN
# si si SCONJ
# consigues conseguir VERB
# tener tener VERB
# salario salariar NOUN
# decente decente ADJ
# país país NOUN
# vives vivir ADJ
# controlas controlar NOUN
# gastos gasto NOUN
# ahorrando ahorrar VERB
# menos menos ADV
# ganas ganar NOUN
# inviertes invertir ADJ
# fondos fondo NOUN
# índice índice NOUN
# roi roi PROPN
# esperado esperar ADJ
# anual anual ADJ
# puedes poder AUX
# decir decir VERB
# balance balance NOUN
# finanzas finanzas NOUN
# personales personal ADJ
# persona personar VERB
# promedio promediar NOUN
# camino caminar NOUN
# financiero financiero ADJ
# promedio promediar NOUN
# trabajar trabajar VERB
# jubilación jubilación NOUN
# decir decir VERB
# años año NOUN
# triángulo triángulo ADJ
# dinero dinero NOUN
# libertad libertar PROPN
# financiera financiero ADJ
# persona personar VERB
# promedio promediar NOUN
# voy ir AUX
# mostrar mostrar VERB
# triángulo triángulo ADJ
# dinero dinero NOUN
# funciona funcionar VERB
# persona personar VERB
# mentalidad mentalidad NOUN
# lf lf DET
# libertad libertar NOUN
# financiera financiero ADJ
# personas personar NOUN
# lf lf PRON
# promedio promediar NOUN
# ligeramente ligeramente ADV
# buenas bueno ADJ
# vértices vértice ADJ
# triángulo triángulo ADJ
# dinero dinero NOUN
# excepcionalmente excepcionalmente ADV
# buenas bueno ADJ
# vértice vértice VERB
# función función NOUN
# cuál cuál PRON
# vértice vértice VERB
# excepcional excepcional ADJ
# enmarcas enmarcar NOUN
# siguientes siguiente ADJ
# caminos camino NOUN
# camino caminar NOUN
# emprendedor emprendedor ADJ
# emprendedor emprendedor NOUN
# persona personar NOUN
# experta experto VERB
# hacer hacer VERB
# dinero dinero NOUN
# capaz capaz ADJ
# caer caer VERB
# rendido rendir ADJ
# cama cama NOUN
# montón montón PROPN
# ideas ideo NOUN
# levantarse levantarse VERB
# plan plan NOUN
# negocio negociar ADJ
# cabeza cabeza VERB
# bastante bastante ADV
# habitual habitual ADJ
# personas personar NOUN
# desconecten desconectar AUX
# nunca nunca ADV
# siempre siempre ADV
# ajetreo ajetrear NOUN
# mental mental ADJ
# encima encimar ADV
# resto restar NOUN
# sociedad sociedad NOUN
# normalmente normalmente ADV
# trabajan trabajar AUX
# semanalmente semanalmente ADV
# horas hora NOUN
# si si SCONJ
# conoces conocer VERB
# alguien alguien PRON
# parece parecer AUX
# energía energía NOUN
# infinita infinito ADJ
# siempre siempre ADV
# pensando pensar AUX
# cómo cómo PRON
# dónde dónde PRON
# añadir añadir VERB
# valor valor NOUN
# proponiendo proponer VERB
# ideas ideo NOUN
# modelos modelo ADJ
# negocio negociar NOUN
# persona personar VERB
# emprendedor emprendedor NOUN
# además además ADV
# suele soler AUX
# ser ser VERB
# persona personar NOUN
# extrovertida extrovertido ADJ
# encanta encantar VERB
# comunicarse comunicarse VERB
# demás demás PRON
# clave clavar NOUN
# conseguir conseguir VERB
# colaboraciones colaboración NOUN
# ideas ideo ADJ
# proyectos proyecto NOUN
# riesgo riesgo NOUN
# perfil perfil NOUN
# emprendedor emprendedor ADJ
# sabe saber VERB
# veces vez NOUN
# necesita necesitar VERB
# invertir invertir VERB
# dinero dinero NOUN
# negocios negocio NOUN
# conseguir conseguir VERB
# aún aun ADV
# dinero dinero NOUN
# debe deber AUX
# saber saber VERB
# controlar controlar VERB
# gastos gasto NOUN
# desarrollo desarrollar NOUN
# negocios negocio PROPN
# ir ir VERB
# bancarrota bancarrota PROPN
# puesto poner INTJ
# puede poder AUX
# darse darse VERB
# caso casar NOUN
# afán afán PROPN
# obtener obtener VERB
# retorno retornar NOUN
# tal tal DET
# analice analizar VERB
# viabilidad viabilidad NOUN
# ideas ideo VERB
# camino caminar NOUN
# optimizador optimizador ADJ
# optimizador optimizador ADJ
# experto experto ADJ
# optimizar optimizar VERB
# gastos gasto NOUN
# persona personar VERB
# siempre siempre ADV
# buscando buscar VERB
# cupón cupón ADJ
# descuento descontar NOUN
# hace hacer AUX
# imposible imposible ADJ
# pagar pagar VERB
# comisión comisión NOUN
# persona personar NOUN
# perfil perfil NOUN
# optimizador optimizador ADJ
# lleva llevar VERB
# control control NOUN
# exhaustivo exhaustivo ADJ
# gastos gasto NOUN
# explica explicar VERB
# post post PROPN
# capaz capaz ADJ
# responderte responderte NOUN
# cuánto cuánto PRON
# gastó gastar VERB
# comida comer NOUN
# día día INTJ
# mes mes INTJ
# pasado pasar ADJ
# hecho hacer ADJ
# encanta encantar VERB
# hacer hacer VERB
# puesto poner VERB
# aporta aportar VERB
# sensación sensación NOUN
# control control NOUN
# total total ADJ
# normalmente normalmente ADV
# tipo tipo NOUN
# personas personar NOUN
# suelen soler VERB
# ser ser VERB
# introvertidas introvertido VERB
# gusta gustar VERB
# dedicar dedicar VERB
# tiempo tiempo NOUN
# registrar registrar VERB
# analizar analizar VERB
# hoja hoja PROPN
# cálculo cálculo ADJ
# interactuar interactuar VERB
# demás demás PRON
# bastante bastante ADV
# común común ADJ
# digan decir VERB
# puedes poder AUX
# controlar controlar VERB
# ingresos ingreso NOUN
# tampoco tampoco ADV
# inversiones inversión NOUN
# puedes poder AUX
# controlar controlar VERB
# gastos gasto NOUN
# detalle detallar NOUN
# clave clavar NOUN
# perfil perfil ADJ
# optimizador optimizador ADJ
# consigue conseguir VERB
# sacar sacar VERB
# máximo máximo ADJ
# rendimiento rendimiento NOUN
# cada cada DET
# centavo centavo NOUN
# obteniendo obtener VERB
# unas uno DET
# tasas tasar NOUN
# ahorro ahorrar NOUN
# supuesto suponer ADJ
# adquieren adquirir AUX
# ninguna ninguno DET
# posesión posesión NOUN
# analizar analizar VERB
# milímetro milímetro NOUN
# aporte aportar VERB
# valor valor NOUN
# largo largar ADJ
# plazo plazo INTJ
# decir decir VERB
# analizar analizar VERB
# relación relación NOUN
# haciendo hacer VERB
# mínima mínimo ADJ
# posible posible ADJ
# mismo mismo DET
# calidad calidad INTJ
# producto producto INTJ
# buena bueno ADJ
# larga largo ADJ
# duración duración NOUN
# coste coste NOUN
# bajo bajar ADP
# posible posible ADJ
# ejemplo ejemplo NOUN
# esperando esperar VERB
# época época NOUN
# idónea idóneo ADJ
# principal principal ADJ
# peligro peligrar NOUN
# optimizador optimizador ADJ
# ser ser VERB
# demasiado demasiar ADV
# conservador conservador ADJ
# inversiones inversión NOUN
# naturaleza naturaleza VERB
# alta alto ADJ
# aversión aversión NOUN
# riesgo riesgo NOUN
# piensa pensar VERB
# clave clavar NOUN
# reducir reducir VERB
# costes coste NOUN
# minimizar minimizar VERB
# riesgo riesgo NOUN
# realidad realidad NOUN
# largo largar ADJ
# plazo plazo NOUN
# riesgo riesgo NOUN
# perder perder VERB
# dinero dinero NOUN
# debido deber ADP
# inflación inflación NOUN
# superior superior ADJ
# riesgo riesgo NOUN
# invertir invertir VERB
# fondo fondo PROPN
# índice índice PROPN
# explica explicar VERB
# aquí aquí ADV
# camino caminar NOUN
# inversor inversor ADJ
# aquella aquel DET
# persona personar NOUN
# sabe saber VERB
# convertir convertir VERB
# dinero dinero NOUN
# dinero dinero NOUN
# tal tal DET
# manera manera NOUN
# anualmente anualmente ADV
# pueda poder VERB
# conseguir conseguir VERB
# retornos retorno NOUN
# inversión inversión NOUN
# anual anual ADJ
# típicamente típicamente ADV
# varias varios DET
# vías vía NOUN
# inversión inversión NOUN
# renta rentar VERB
# variable variable ADJ
# sector sector NOUN
# inmobiliario inmobiliario ADJ
# inversión inversión NOUN
# startups startups VERB
# mentalidad mentalidad NOUN
# trabajo trabajar NOUN
# convencional convencional ADJ
# perdedores perdedor NOUN
# dinero dinero NOUN
# puede poder AUX
# trabajar trabajar VERB
# duro durar ADJ
# persona personar NOUN
# nunca nunca ADV
# podría poder AUX
# realidad realidad NOUN
# tipo tipo NOUN
# personas personar NOUN
# encuentran encontrar AUX
# rara raro ADJ
# vez vez PROPN
# warren warren PROPN
# buffet buffet NOUN
# complicado complicar ADJ
# manera manera NOUN
# sostenida sostener ADJ
# persona personar NOUN
# consiga conseguir VERB
# obtener obtener VERB
# rentabilidades rentabilidad NOUN
# elevadas elevar ADJ
# si si SCONJ
# consigue conseguir VERB
# años año NOUN
# muchas mucho DET
# ocasiones ocasionar NOUN
# fruto fruto NOUN
# suerte suerte NOUN
# suerte suerte NOUN
# sustituye sustituir VERB
# habilidad habilidad NOUN
# suele soler AUX
# haber haber VERB
# buen bueno ADJ
# final final NOUN
# aunque aunque SCONJ
# posible posible ADJ
# conseguir conseguir VERB
# libertad libertar NOUN
# financiera financiero ADJ
# camino caminar NOUN
# ...
# financieraapril financieraapril ADJ
# dedicado dedicar ADJ
# explicar explicar VERB
# diferentes diferente DET
# hitos hito NOUN
# irás ir ADV
# alcanzando alcanzar VERB
# camino caminar NOUN
# hacia hacia ADP
# libertad libertar NOUN
# financiera financiero ADJ
# read read PROPN
# morejquery morejquery PROPN
# document document PROPN
# function function PROPN
# const const PROPN
# perecentpostscarouselcontainer perecentpostscarouselcontainer VERB
# const const PROPN
# perecentpostsarrows perecentpostsarrows PROPN
# const const PROPN
# perecentpostsarrow perecentpostsarrow PROPN
# const const PROPN
# perecentpostsindicatorscontainer perecentpostsindicatorscontainer VERB
# const const PROPN
# perecentpostsindicators perecentpostsindicators PROPN
# li li PROPN
# const const PROPN
# perecentpostspanel perecentpostspanel PROPN
# interval interval PROPN
# pause pausar PROPN
# hover hover VERB
# li li PROPN
# function function PROPN
# event event PROPN
# if if PROPN
# space space PROPN
# key key PROPN
# this this PROPN
# function function PROPN
# event event PROPN
# this this PROPN
# li li PROPN
# if if PROPN
# tab tab PROPN
# key key PROPN
# if if PROPN
# shift shift PROPN
# tab tab PROPN
# key key PROPN
# this this PROPN
# not not ADV
# else else VERB
# let let PROPN
# tabid tabid PROPN
# this this PROPN
# this this PROPN
# this this PROPN
# tabid tabid PROPN
# if if PROPN
# enter enter PROPN
# key key PROPN
# this this PROPN
# if if PROPN
# right right PROPN
# arrow arrow PROPN
# if if PROPN
# this this PROPN
# this this PROPN
# else else PROPN
# this this PROPN
# if if PROPN
# left left PROPN
# arrow arrow PROPN
# if if PROPN
# this this PROPN
# this this PROPN
# else else PROPN
# this this PROPN
# if if PROPN
# home home PROPN
# key key PROPN
# this this PROPN
# if if PROPN
# end end PROPN
# key key PROPN
# this this PROPN
# function function PROPN
# event event PROPN
# let let PROPN
# tabpanel tabpanel PROPN
# if if PROPN
# tab tab PROPN
# key key PROPN
# this this PROPN
# if if PROPN
# shift shift PROPN
# tab tab PROPN
# key key PROPN
# if if PROPN
# this this PROPN
# if if PROPN
# this this PROPN
# focus focus PROPN
# this this PROPN
# tabpanel tabpanel PROPN
# if if PROPN
# window window PROPN
# one one PROPN
# row row PROPN
# for for PROPN
# mobiles mobiles ADJ
# div div VERB
# item item PROPN
# items items PROPN
# remove remove PROPN
# original original ADJ
# divs divs PROPN
# add add PROPN
# class class PROPN
# active activar PROPN
# for for PROPN
# the the PROPN
# first first PROPN
# item item PROPN
# if if PROPN
# if if PROPN
# indicators indicators PROPN
# bullets bullets PROPN
# are arar PROPN
# enabled enabled PROPN
# const const PROPN
# perecentpostsitemsnumber perecentpostsitemsnumber PROPN
# get get PROPN
# numer numer INTJ
# of of INTJ
# items items PROPN
# remove remove PROPN
# indicators indicators PROPN
# bullets bullets PROPN
# items items PROPN
# for for PROPN
# i i CCONJ
# i i CCONJ
# perecentpostsitemsnumber perecentpostsitemsnumber PROPN
# li li PROPN
# const const PROPN
# perecentpostspanel perecentpostspanel PROPN
# interval interval PROPN
# pause pausar PROPN
# null null PROPN
# li li PROPN
# function function PROPN
# event event PROPN
# if if PROPN
# space space PROPN
# key key PROPN
# this this PROPN
# function function PROPN
# event event PROPN
# this this PROPN
# li li PROPN
# if if PROPN
# tab tab PROPN
# key key PROPN
# if if PROPN
# shift shift PROPN
# tab tab PROPN
# key key PROPN
# this this PROPN
# not not ADV
# else else VERB
# let let PROPN
# tabid tabid PROPN
# this this PROPN
# this this PROPN
# this this PROPN
# tabid tabid PROPN
# if if PROPN
# enter enter PROPN
# key key PROPN
# this this PROPN
# if if PROPN
# right right PROPN
# arrow arrow PROPN
# if if PROPN
# this this PROPN
# this this PROPN
# else else PROPN
# this this PROPN
# if if PROPN
# left left PROPN
# arrow arrow PROPN
# if if PROPN
# this this PROPN
# this this PROPN
# else else PROPN
# this this PROPN
# if if PROPN
# home home PROPN
# key key PROPN
# this this PROPN
# if if PROPN
# end end PROPN
# key key PROPN
# this this PROPN
# function function PROPN
# event event PROPN
# let let PROPN
# tabpanel tabpanel PROPN
# if if PROPN
# tab tab PROPN
# key key PROPN
# this this PROPN
# if if PROPN
# shift shift PROPN
# tab tab PROPN
# key key PROPN
# if if PROPN
# this this PROPN
# if if PROPN
# this this PROPN
# focus focus PROPN
# this this PROPN
# tabpanel tabpanel PROPN
# if if PROPN
# window window PROPN
# one one PROPN
# row row PROPN
# for for PROPN
# mobiles mobiles ADJ
# div div VERB
# item item PROPN
# items items PROPN
# remove remove PROPN
# original original ADJ
# divs divs PROPN
# add add PROPN
# class class PROPN
# active activar PROPN
# for for PROPN
# the the PROPN
# first first PROPN
# item item PROPN
# if if PROPN
# if if PROPN
# indicators indicators PROPN
# bullets bullets PROPN
# are arar PROPN
# enabled enabled PROPN
# const const PROPN
# perecentpostsitemsnumber perecentpostsitemsnumber PROPN
# get get PROPN
# numer numer INTJ
# of of INTJ
# items items PROPN
# remove remove PROPN
# indicators indicators PROPN
# bullets bullets PROPN
# items items PROPN
# for for PROPN
# i i CCONJ
# i i CCONJ
# perecentpostsitemsnumber perecentpostsitemsnumber PROPN
# add add PROPN
# bullets bullets PROPN
# for for PROPN
# mobile mobile PROPN
# li li PROPN
# i i CCONJ
# i i CCONJ
# perecentpostsindicatorscontainer perecentpostsindicatorscontainer VERB
# add add PROPN
# class class PROPN
# active activar PROPN
# for for PROPN
# the the PROPN
# first first PROPN
# bullet bullet PROPN
# uso usar NOUN
# autorizado autorizar ADJ
# copia copiar NOUN
# material material ADJ
# consentimiento consentimiento NOUN
# expreso expresar ADJ
# escrito escribir ADJ
# autor autor NOUN
# estrictamente estrictamente ADV
# prohibido prohibir ADJ
# puede poder AUX
# utilizar utilizar VERB
# enlaces enlazar NOUN
# blog blog VERB
# siempre siempre ADV
# aparezca aparecer VERB
# claramente claramente ADV
# autoría autoría VERB
# redirección redirección NOUN
# contenido contener NOUN
# aquí aquí ADV
# pasos paso NOUN
# seguirpaso seguirpaso NOUN
# calcula calcular VERB
# realpaso realpaso ADJ
# controla controlar PROPN
# categoriza categorizar VERB
# ingresos ingreso NOUN
# gastos gasto ADJ
# personalespaso personalespaso PROPN
# valora valorar VERB
# gastospaso gastospaso PROPN
# visualiza visualizar PROPN
# financiero financiero ADJ
# personalpaso personalpaso ADJ
# reduce reducir VERB
# gastos gasto NOUN
# aumenta aumentar VERB
# ingresospaso ingresospaso PROPN
# añade añadir VERB
# inversiones inversión NOUN
# fotopaso fotopaso ADJ
# punto punto NOUN
# corte cortar VERB
# libertad libertar NOUN
# financieraestrategias financieraestrategias ADJ
# inversióninversión inversióninversión NOUN
# renta rentar NOUN
# fija fijo ADJ
# renta rentar NOUN
# variableinversión variableinversión PROPN
# préstamos préstamo NOUN
# crowlendinginversión crowlendinginversión NOUN
# desarrollo desarrollar PROPN
# personalbloglibros personalbloglibros ADJ
# recomendadossobre recomendadossobre VERB
# míeste míeste PROPN
# sitio sitiar NOUN
# web web PROPN
# utiliza utilizar PROPN
# cookies cookies PROPN
# propias propio ADJ
# terceros tercero ADJ
# según según SCONJ
# recoge recoger VERB
# política político ADJ
# privacidad privacidad NOUN
# política político ADJ
# cookies cookies PROPN
# mejorar mejorar VERB
# experiencia experiencia NOUN
# usuario usuario NOUN
# puedes poder AUX
# modificar modificar VERB
# preferencias preferencia NOUN
# cualquier cualquiera DET
# momento momento NOUN
# acepto aceptar ADJ
# uso usar NOUN
# cookies cookies PROPN
# fines finar PROPN
# privacy privacy INTJ
# preferencesi preferencesi ADJ
# agreeprivacy agreeprivacy NOUN
# preference preference PROPN
# centeroptionsconsent centeroptionsconsent PROPN
# managementcookie managementcookie PROPN
# settingsanalyticspolítica settingsanalyticspolítica ADJ
# privacidad privacidad NOUN
# política político ADJ
# cookiesconsent cookiesconsent PROPN
# managementpolítica managementpolítica ADJ
# privacidad privacidad NOUN
# política político ADJ
# cookiesrequiredconsiento cookiesrequiredconsiento ADJ
# uso usar NOUN
# datos dato NOUN
# conforme conformar ADJ
# política político ADJ
# privacidad privacidad NOUN
# política político ADJ
# cookies cookies PROPN
# blognecesariase blognecesariase PROPN
# usan usar AUX
# almacenar almacenar VERB
# nombre nombrar NOUN
# ip ip PROPN
# email email NOUN
# datos dato NOUN
# dejas dejar VERB
# expresamente expresamente ADV
# formularios formulario NOUN
# comentarios comentario ADJ
# contacto contactar NOUN
# usan usar AUX
# almacenar almacenar VERB
# nombre nombrar NOUN
# ip ip PROPN
# email email NOUN
# datos dato NOUN
# dejas dejar VERB
# expresamente expresamente ADV
# formularios formulario NOUN
# comentarios comentario ADJ
# contacto contactar NOUN
# usan usar AUX
# identificar identificar VERB
# ip ip AUX
# poder poder VERB
# comprender comprender VERB
# mejor mejor ADV
# visitantes visitante NOUN
# ofrecerles ofrecerles ADJ
# mejor mejor ADV
# math math NOUN
# asblockinlineadditional asblockinlineadditional ADJ
# settingsformula settingsformula PROPN
# colortext colortext PROPN
# color color NOUN
# idformula idformula VERB
# classestype classestype PROPN
# math math PROPN
# nothing nothing ADJ
# to to PROPN
# previewinsertfunction previewinsertfunction PROPN
# atomicblocksshare atomicblocksshare PROPN
# url url PROPN
# title title PROPN
# w w PROPN
# h hora ADP
# var var VERB
# left left NOUN
# w w CCONJ
# var var VERB
# top top INTJ
# h hora ADP
# return return PROPN
# url url PROPN
# title title PROPN
# cdata cdata NOUN
# var var VERB
# mabajax mabajax PROPN
# ajaxurl ajaxurl VERB
# https https PROPN
# action action PROPN
# wpspinner wpspinner PROPN
# https https PROPN
# https https INTJ
# spinner spinner VERB
# https https INTJ
# https https ADJ
# basestylesurl basestylesurl VERB
# https https PROPN
# heateorsssloadevent heateorsssloadevent PROPN
# var var PROPN
# if if PROPN
# typeof typeof PROPN
# function function PROPN
# else else VERB
# t t CCONJ
# var var VERB
# heateorssssharingajaxurl heateorssssharingajaxurl VERB
# heateorssscloseiconpath heateorssscloseiconpath SCONJ
# heateorssspluginiconpath heateorssspluginiconpath DET
# heateorssshorizontalsharingcountenable heateorssshorizontalsharingcountenable ADJ
# heateorsssverticalsharingcountenable heateorsssverticalsharingcountenable ADJ
# heateorssssharingoffset heateorssssharingoffset PROPN
# var var VERB
# heateorsssmobilestickysharingenabled heateorsssmobilestickysharingenabled PROPN
# var var VERB
# heateorssscopylinkmessage heateorssscopylinkmessage NOUN
# link link PROPN
# copied copied INTJ
# var var VERB
# heateorsssurlcountfetched heateorsssurlcountfetched NOUN
# heateorssssharestext heateorssssharestext PROPN
# heateorssssharetext heateorssssharetext VERB
# function function PROPN
# heateorssspopup heateorssspopup PROPN
# popupwindow popupwindow PROPN
# resizable resizable ADJ
# scrollbars scrollbars PROPN
# status status PROPN
# var var VERB
# heateorssswhatsappshareapi heateorssswhatsappshareapi PROPN
# web web PROPN
# v v PROPN
# j j PROPN
# blog blog PROPN
# post post PROPN
# tz tz PROPN
# srv srv PROPN

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_lem = nltk.FreqDist(clean_tokens_sin_lem)
for key,val in freq_clean_sin_lem.items():
    print (str(key) + ':' + str(val))
    
#Visualizar Tokens
freq_clean_sin_lem.plot(30, cumulative=False)
# Out:
# libertar:81
# financiero:93
# background:6
# circle:1
# at:1
# color:31
# fff:2
# solid:3
# transparent:9
# hover:23
# medio:5
# screen:3
# and:6
# display:10
# none:10
# important:29
# white:1
# li:14
# width:5
# block:2
# auto:2
# bottom:1
# top:3
# inherit:1
# context:1
# https:30
# graph:1
# type:6
# person:1
# organization:1
# ir:52
# name:3
# image:1
# imageobject:2
# personlogo:2
# url:8
# caption:1
# logo:1
# sameas:1
# website:3
# alcanzar:50
# publisher:1
# potentialaction:1
# searchaction:1
# target:1
# required:1
# primaryimage:2
# height:2
# webpage:2
# inlanguage:1
# ispartof:1
# about:1
# primaryimageofpage:1
# datepublished:1
# datemodified:1
# description:1
# tener:34
# vida:25
# desear:3
# poder:98
# blog:12
# var:31
# true:5
# disablestr:5
# function:24
# to:5
# detect:1
# opted:1
# out:3
# users:1
# return:14
# disable:1
# tracking:1
# if:9
# the:1
# técnico:7
# círculo:3
# olvidar:1
# consumir:7
# sumar:1
# desplazamiento:1
# hacia:13
# desconectar:4
# llegar:18
# caminar:14
# sencillo:3
# ninguno:8
# panacea:1
# decir:32
# mentir:1
# consistencia:1
# claro:6
# llamar:3
# carrera:2
# rata:2
# realimentar:1
# vicioso:1
# sumergir:1
# sociedad:6
# enseñar:5
# paraganar:1
# dinerocon:1
# incrementar:2
# nivel:21
# vidaal:1
# adquirir:7
# posesionar:1
# coche:12
# comenzar:8
# endeudarte:1
# generar:24
# necesitar:19
# ganar:4
# frente:1
# lasdeudasy:1
# volver:4
# pasar:15
# intentar:2
# continuar:3
# bucle:1
# resumir:1
# cuanto:4
# ciclar:4
# pilar:2
# leer:5
# numeroso:2
# libro:1
# relativo:4
# finanzas:11
# personal:8
# gustar:5
# contigo:1
# ver:31
# alternativo:10
# predefinir:1
# sol:2
# jubilación:4
# enfocar:12
# escuela:1
# pues:14
# quizás:4
# enfoque:3
# afrontar:1
# futuro:10
# preferir:3
# rebañar:1
# llevar:5
# ruta:1
# preestablecer:1
# asir:8
# cometer:1
# mismo:12
# error:1
# beneficiar:4
# imagínate:1
# mundo:3
# todo:9
# retirar:8
# menospreciar:1
# asignatura:2
# concreto:3
# bien:12
# típico:2
# introducirnos:1
# concepto:3
# básico:3
# inflación:11
# tipo:17
# interés:10
# ayudar:6
# mayor:15
# ejemplo:31
# momento:15
# decidir:6
# convenir:2
# hipotecarnos:1
# mucho:10
# gente:3
# plantear:5
# manera:19
# determinar:4
# embargar:5
# diferente:13
# buscar:7
# convencional:1
# recomer:7
# sección:3
# posteriormente:2
# recomendación:3
# proponer:4
# ser:17
# capaz:8
# él:9
# únete:1
# plantilla:13
# excel:5
# definitivo:3
# económico:8
# consciente:4
# cuánto:3
# quedo:5
# nuevo:9
# contener:4
# librefinanciero:5
# artículo:12
# aportar:5
# valor:20
# personaleshe:2
# condicionar:2
# basar:10
# político:9
# privacidadno:2
# spam:2
# publicidad:2
# suscribirtete:2
# enlazar:11
# email:4
# descargar:2
# financieroúltimos:1
# asegurar:6
# cumplimiento:7
# objetivo:17
# adoptar:3
# mentalidad:4
# gran:8
# dudar:8
# caber:3
# igual:4
# vez:24
# medir:14
# cumplir:9
# aplicar:3
# prácticamente:2
# cualquiera:9
# marcar:8
# profesional:3
# ayudarte:2
# tarea:1
# preparar:2
# downloads:1
# dividir:1
# partir:16
# blocar:5
# realizar:11
# previsión:8
# anual:14
# través:8
# seriar:4
# dato:9
# vaya:5
# anualmente:5
# explicar:9
# pestaña:3
# deber:18
# celda:5
# amarillo:3
# gris:1
# autocalculadas:1
# tocarlas:1
# inicial:5
# total:5
# disponible:4
# invertir:26
# mensualmente:5
# divídelo:1
# pensar:15
# cabo:1
# existir:11
# posibiilidad:1
# insertar:9
# solo:11
# crowfunding:2
# inserto:3
# tan:4
# simple:3
# fila:2
# cálculo:4
# repartir:3
# mensual:20
# continuación:1
# ideo:8
# prever:7
# porcentaje:5
# rentabilidad:12
# tomar:8
# noto:1
# anterior:7
# post:13
# pasivo:41
# seguro:17
# poner:26
# mano:2
# obrar:2
# vía:3
# autocalculen:1
# siguiente:24
# autocalculados:1
# último:4
# salariar:5
# montante:5
# contar:19
# actual:4
# justamente:1
# iniciar:2
# nómina:2
# sobrepasar:2
# valer:2
# resultar:11
# real:9
# cada:28
# cerrar:6
# inserción:1
# aun:4
# gráfico:7
# abajar:2
# consecución:2
# control:1
# vs:2
# tal:11
# simulación:3
# pepe:7
# neto:3
# primero:5
# variable:5
# indexar:1
# segundar:3
# restante:4
# ambos:1
# además:8
# marchar:1
# fuente:21
# suponer:11
# pretender:1
# universo:1
# infinito:3
# posibilidad:4
# parecer:3
# conservador:2
# utilizar:19
# formato:3
# condicional:1
# relleno:1
# verde:2
# saber:7
# importancia:5
# plasmar:1
# realidad:3
# número:3
# rápidamente:2
# promediar:5
# bastante:2
# alinear:2
# expectativa:1
# visualmente:1
# dedicar:9
# verificar:4
# ahora:12
# turnar:2
# aprovéchate:1
# clavar:7
# bueno:10
# allá:5
# motivante:1
# consciencia:1
# cuándo:2
# fehacientemente:1
# compártelo:2
# comentario:7
# comunidad:3
# enriquecer:2
# read:24
# morar:8
# comprar:26
# producto:27
# adecuadotodos:1
# acometer:4
# ropa:3
# tecnología:4
# vacación:6
# largar:10
# mostrar:9
# fecho:7
# idóneo:1
# final:7
# diciembre:2
# concesionario:7
# deshacerse:1
# stock:1
# venta:8
# elegir:5
# mes:12
# encontrar:14
# fuerte:3
# descuento:9
# igualmente:1
# negociar:1
# trimestre:3
# semana:5
# hazlo:2
# lunes:5
# menos:14
# usuario:4
# establecimiento:1
# especial:1
# justar:4
# incentivar:1
# volumen:5
# descontar:6
# únicamente:3
# comparar:4
# cercano:1
# visitar:3
# portal:13
# ciudad:3
# ahorrarte:1
# berlina:1
# septiembre:3
# perfecto:1
# adivinar:1
# moda:3
# black:2
# friday:2
# cuartar:1
# viernes:1
# noviembre:1
# cyber:1
# monday:1
# después:10
# tecnológico:3
# ojo:1
# marketing:4
# abusivo:1
# ocasionar:5
# subir:9
# preciar:22
# rebajar:2
# anteriormente:3
# evolución:5
# amazon:7
# herramienta:5
# gadget:1
# versión:3
# preste:1
# atención:3
# evento:3
# mobile:1
# world:1
# congress:1
# febrero:1
# ifa:1
# principio:2
# presentar:2
# multitud:3
# predecesor:1
# samsung:1
# apple:1
# smartphone:3
# insignia:1
# previo:1
# vivienda:11
# según:4
# estudio:1
# trovimap:1
# estación:1
# verano:1
# competencia:1
# bajo:5
# competir:1
# comprador:2
# independientemente:1
# época:1
# varios:3
# clave:2
# bruto:3
# vestir:3
# métrico:1
# caro:2
# barato:3
# alquilarla:1
# inmueble:2
# similar:1
# zona:1
# x:2
# informar:1
# banco:3
# españa:2
# considerar:6
# superar:2
# per:5
# price:1
# earnings:1
# ratio:1
# fórmula:1
# inverso:1
# alquiler:2
# amortizar:19
# mediar:1
# tornar:3
# relación:2
# hipotecar:27
# recordar:3
# norma:2
# viaje:2
# clásico:1
# skyscanner:3
# comparativo:3
# heateorssscopylinkmessage:1
# copied:1
# heateorsssurlcountfetched:1
# heateorssssharestext:1
# heateorssssharetext:1
# heateorssspopup:1
# popupwindow:1
# resizable:1
# scrollbars:1
# status:1
# heateorssswhatsappshareapi:1
# pagination:2
# autoanimate:2
# autoanimatetrans:2
# animationloop:2
# slideshowspeed:2
# slidespeed:2
# pausehover:2
# pauseaction:2
# slidedirection:2
# touch:2
# tz:1
# srv:1

# %% [markdown]
# # Altenativa Spacy

# %%
#Alternativa para texto en español --- Instalar spicy: pip install spacy
#Instalar python -m spacy download es_core_news_sm
import spacy
nlp= spacy.load('es_core_news_sm')

# %%
clean_tokens_sin_lem=[]
palabras='comer comida comería comido comen'
for token in nlp(palabras): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)
    
print (clean_tokens_sin_lem)
clean_tokens_sin_lem=[]
# Out:
# comer VERB
# comida NOUN
# comería VERB
# comido ADJ
# comen PROPN
# ['comer', 'comer', 'comer', 'comer', 'comer']

# %% [markdown]
# ## Alternativa web https://es.wikipedia.org/wiki/Finanzas

# %%
# LEER TEXTO DESDE URL

from bs4 import BeautifulSoup
 
import urllib.request
  
response = urllib.request.urlopen('https://es.wikipedia.org/wiki/Finanzas') #Obtiene el contenido HTML de la página web http://librefinanciero.com/
 
html = response.read()
 
soup = BeautifulSoup(html,"html5lib") # Limpia el texto HTML capturado
 
text = soup.get_text(strip=True)
 
print (text)
# Out:
# Finanzas - Wikipedia, la enciclopedia libredocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"756b8f3d-1558-4263-95d3-ec8c63417a4e","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Finanzas","wgTitle":"Finanzas","wgCurRevisionId":144209527,"wgRevisionId":144209527,"wgArticleId":142062,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Artículos que necesitan referencias adicionales","Wikipedia:Referenciar (aún sin clasificar)","Wikipedia:Artículos con identificadores LCCN","Wikipedia:Artículos con identificadores AAT","Finanzas","Administración","Economía de la empresa"],"wgPageContentLanguage":"es",
# "wgPageContentModel":"wikitext","wgRelevantPageName":"Finanzas","wgRelevantArticleId":142062,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"español","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q43015","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":true};RLSTATE={"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready",
# "ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","mediawiki.toc","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});FinanzasDe Wikipedia, la enciclopedia libreIr a la navegaciónIr a la búsquedaLas finanzasLasfinanzasson unaramade laadministracióny de laeconomíaque estudia el intercambio decapitalentreindividuos,empresas, oEstadosy con la incertidumbre y el riesgo que estas actividades conllevan.[1]​ Se dedica al estudio de la obtención de capital para la inversión en bienes productivos y de las decisiones de inversión de los ahorradores.Así mismo, su estudio se basa en laobtencióny laadministracióndel dinero para lograr sus respectivos objetivos, tomando en cuenta todos los riesgos que ella implica, basándose en todos y cada uno de sus componentes que la integra para mantener un buen control.Las finanzas estudian cómo los agentes económicos (empresas, familias o Estado) deben tomar decisiones de inversión, ahorro y gasto en condiciones de incertidumbre. Al momento de tomar estas decisiones los agentes pueden optar por diversos tipos de recursos financieros tales como: dinero, bonos, acciones o derivados, incluyendo la compra de bienes de capital como maquinarias, edificios y otras infraestructuras. Ver diferencia entre ahorro e inversión.Las finanzas va ligada con la administración por ejemplo, al considerar un nuevo producto, el administrador financiero requiere que el personal de finanzas le proporcione los cálculos de presupuesto. Y la función de las finanzas administrativas puede describirse ampliamente al considerar su papel dentro de la organización, su relación con la economía y la contabilidad y las principales actividades del administrador financiero.Está relacionado con lastransaccionesy con la administración del dinero.[2]​ En ese marco se estudia la obtención y gestión, por parte de una compañía, un individuo, o del propio Estado, de los fondos que necesita para cumplir sus objetivos, y de los criterios con que dispone de susactivos; en otras palabras, lo relativo a la obtención y gestión del dinero, así como de otros valores o sucedáneos del dinero, como lo son lostítulos, losbonos, etc. Según Bodie y Merton, las finanzas «estudian la manera en que losrecursosescasos se asignan a través del tiempo». Las finanzas tratan, por lo tanto, de las condiciones y la oportunidad con que se consigue el capital, de los usos de este, y los retornos que un inversionista obtiene de sus inversiones.[3]​El estudio académico de las finanzas se divide principalmente en dos ramas,[4]​ que reflejan las posiciones respectivas de aquel que necesita fondos o dinero para realizar una inversión, llamadafinanzas corporativas, y de aquel que quiere invertir su dinero dándoselo a alguien que lo quiera usar para invertir, llamadavaluación de activos.[5]​ El área de finanzas corporativas estudia cómo le conviene más a un inversionista conseguir dinero, por ejemplo, si vendiendo acciones, pidiendo prestado a un banco o vendiendo deuda en el mercado. El  ...
# Estas dos ramas de las finanzas se dividen en otras más. Algunas de las áreas más populares dentro del estudio de las finanzas son: Intermediación Financiera, Finanzas Conductistas, Microestructura de los Mercados Financieros, Desarrollo Financiero, Finanzas Internacionales, y Finanzas de Consumidor.[6]​ Una disciplina recientemente creada son las neurofinanzas, rama de laneuroeconomía, encargada del estudio de los sesgos relacionados con el manejo de la economía.[7]​Las finanzas personales son la aplicación de las finanzas y sus principios a una persona o familia en su deseo de realizar sus actividades con la mejor distribución de dinero para ello. Así, deben reconocer cómo ocupar sus ingresos en educación, salud, alimentación, vestimenta, seguros, lujos, transporte, etc. Se deben tener en cuenta los ingresos, los gastos, los ahorros y siempre estableciendo los riesgos y los eventos futuros. Parte de las finanzas personales son los cheques, las cuentas de ahorro, las tarjetas de crédito, los préstamos, las inversiones en el mercado de valores, los planes de jubilación, los impuestos, etc.Índice1Conceptos clave2Clasificación2.1Finanzas privadas2.2Finanzas públicas2.2.1Corto Plazo2.2.2Largo plazo2.2.3Mediano plazo2.2.4Política fiscal2.2.5Disciplinas auxiliares3Véase también4ReferenciasConceptos clave[editar]Este artículo o sección tienereferencias, pero necesita más para complementar suverificabilidad.Este aviso fue puesto el 25 de mayo de 2019.Riesgoybeneficio: Los inversores actúan en los diferentes mercados intentando obtener el mayor rendimiento para su dinero a la vez que pretenden minimizar el riesgo de su inversión. El mercado de capitales ofrece en cada momento una frontera eficiente, que relaciona una determinada rentabilidad con un determinado nivel de riesgo o volatilidad. El inversor obtiene una mayor rentabilidad esperada a cambio de soportar una mayor incertidumbre. El precio de la incertidumbre es la diferencia entre la rentabilidad de la inversión y el tipo de interés de aquellos valores que se consideran seguros. A esta diferencia la conocemos como prima de riesgo.El valor del dinero en el tiempo: Ante la misma cantidad de dinero, un inversor prefiere disponer de ella en el presente que en el futuro. Por ello, el transvase intertemporal de dinero cuenta con un factor de descuento (si intercambiamos renta futura por capital presente, por ejemplo, en un préstamo hipotecario), o con una rentabilidad (si ìntercambiamos renta presente por renta futura, por ejemplo, en un plan de pensiones).Tasa de interés: y representa una tasa de intercambio entre el precio del dinero al día de hoy en términos del dinero futuro.En España la tasa de interés es conocida como el tipo de interés.La tasa de interés afecta directamente el consumo, el comercio y la inversión, pues parte del consumo se paga mediante tarjetas de crédito, parte de la mercancía comprada y vendida por los comercios es comprada a crédito, y las inversiones siempre se apoyan con préstamos bancarios o emisión de deuda mediante bonos: Al subir la tasa de interés el consumo y la inversión disminuyen, pues individuos y empresas encuentran más difícil pagar sus deudas; al bajar la tasa de interés el consumo y la inversión aumentan por el estímulo que representa pagar menos intereses. Esta relación entre tasa de interés, consumo e inversión es utilizada por los diseñadores de políticas macroeconómicas para manipularlos para afectar crecimiento económico, empleo e inflación: Para disminuir la inflación inducen un aumento en las tasas de interés; cuando quieren aumentar el empleo, inducen su disminución. Tales acciones usualmente son llevadas a cabo mediante el Banco Central de cada país al establecer la llamada tasa de descuento - la tasa de interés a la cual presta dinero a los bancos. Este cambio en la tasa de descuento impacta los costos del dinero en los bancos y, por tanto, impacta la tasa de interés que tales bancos cobran por sus préstamos.La relación entreliqui ...
# pueden aplicarse cláusulas adicionales. Al usar este sitio, usted acepta nuestrostérminos de usoy nuestrapolítica de privacidad.Wikipedia® es una marca registrada de laFundación Wikimedia, Inc., una organización sin ánimo de lucro.Política de privacidadAcerca de WikipediaLimitación de responsabilidadVersión para móvilesDesarrolladoresEstadísticasDeclaración de cookies(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.295","walltime":"0.371","ppvisitednodes":{"value":2217,"limit":1000000},"postexpandincludesize":{"value":16777,"limit":2097152},"templateargumentsize":{"value":1770,"limit":2097152},"expansiondepth":{"value":23,"limit":100},"expensivefunctioncount":{"value":8,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":7808,"limit":5000000},"entityaccesscount":{"value":8,"limit":400},"timingprofile":["100.00%  291.942      1 -total"," 62.66%  182.917      1 Plantilla:Control_de_autoridades"," 16.91%   49.354      1 Plantilla:Referencias_adicionales"," 14.29%   41.710      1 Plantilla:Listaref"," 11.39%   33.262      1 Plantilla:Aviso","  9.55%   27.880      3 Plantilla:Cita_web","  9.03%   26.369      2 Plantilla:Problemas_artículo/validar","  6.32%   18.453     12 Plantilla:Str_mid","  5.98%   17.473     24 Plantilla:Trim","  5.79%   16.892      1 Plantilla:Portal"]},"scribunto":{"limitreport-timeusage":{"value":"0.161","limit":"10.000"},"limitreport-memusage":{"value":3873500,"limit":52428800}},"cachereport":{"origin":"mw1456","timestamp":"20220626042010","ttl":86400,"transientcontent":true}}});});{"@context":"https:\/\/schema.org","@type":"Article","name":"Finanzas","url":"https:\/\/es.wikipedia.org\/wiki\/Finanzas","sameAs":"http:\/\/www.wikidata.org\/entity\/Q43015","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q43015","author":{"@type":"Organization","name":"Colaboradores de los proyectos Wikimedia"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2005-06-04T20:46:22Z","dateModified":"2022-06-15T10:28:29Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/d\/d3\/Manual_de_finanzas_personales_y_familia_041.jpg","headline":"rama de la econom\u00eda y administraci\u00f3n de empresas"}{"@context":"https:\/\/schema.org","@type":"Article","name":"Finanzas","url":"https:\/\/es.wikipedia.org\/wiki\/Finanzas","sameAs":"http:\/\/www.wikidata.org\/entity\/Q43015","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q43015","author":{"@type":"Organization","name":"Colaboradores de los proyectos Wikimedia"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2005-06-04T20:46:22Z","dateModified":"2022-06-15T10:28:29Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/d\/d3\/Manual_de_finanzas_personales_y_familia_041.jpg","headline":"rama de la econom\u00eda y administraci\u00f3n de empresas"}(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":158,"wgHostname":"mw1432"});});

# %%
#Crear tokens por palabras
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text,"spanish")
tokens=[word.lower() for word in tokens if word.isalpha()] # Remover los signos de puntuación
print(tokens)
# Out:
# ['finanzas', 'wikipedia', 'la', 'enciclopedia', 'wgbreakframes', 'false', 'wgseparatortransformtable', 'wgdigittransformtable', 'wgdefaultdateformat', 'dmy', 'wgmonthnames', 'enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre', 'wgrequestid', 'wgcspnonce', 'false', 'wgcanonicalnamespace', 'wgcanonicalspecialpagename', 'false', 'wgnamespacenumber', 'wgpagename', 'finanzas', 'wgtitle', 'finanzas', 'wgcurrevisionid', 'wgrevisionid', 'wgarticleid', 'wgisarticle', 'true', 'wgisredirect', 'false', 'wgaction', 'view', 'wgusername', 'null', 'wgusergroups', 'wgcategories', 'wikipedia', 'artículos', 'que', 'necesitan', 'referencias', 'adicionales', 'wikipedia', 'referenciar', 'aún', 'sin', 'clasificar', 'wikipedia', 'artículos', 'con', 'identificadores', 'lccn', 'wikipedia', 'artículos', 'con', 'identificadores', 'aat', 'finanzas', 'administración', 'economía', 'de', 'la', 'empresa', 'wgpagecontentlanguage', 'es', 'wgpagecontentmodel', 'wikitext', 'wgrelevantpagename', 'finanzas', 'wgrelevantarticleid', 'wgisprobablyeditable', 'true', 'wgrelevantpageisprobablyeditable', 'true', 'wgrestrictionedit', 'wgrestrictionmove', 'wgvisualeditor', 'pagelanguagecode', 'es', 'pagelanguagedir', 'ltr', 'pagevariantfallbacks', 'es', 'wgmfdisplaywikibasedescriptions', 'search', 'true', 'nearby', 'true', 'watchlist', 'true', 'tagline', 'true', 'wgwmeschemaeditattemptstepoversample', 'false', 'wgwmepagelength', 'wgnoticeproject', 'wikipedia', 'wgmediavieweronclick', 'true', 'wgmediaviewerenabledbydefault', 'true', 'wgpopupsflags', 'wgulscurrentautonym', 'español', 'wgeditsubmitbuttonlabelpublish', 'true', 'wgcentralauthmobiledomain', 'false', 'wgulsposition', 'interlanguage', 'wgulsiscompactlinksenabled', 'true', 'wgwikibaseitemid', 'gehomepagesuggestededitsenabletopics', 'true', 'wggetopicsmatchmodeenabled', 'true', 'ready', 'ready', 'ready', 'ready', 'ready', 'user', 'ready', 'loading', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'site', 'function', 'function', 'jquery', 'require', 'module', 'patroltoken', 'watchtoken', 'csrftoken', 'finanzasde', 'wikipedia', 'la', 'enciclopedia', 'libreir', 'a', 'la', 'navegaciónir', 'a', 'la', 'búsquedalas', 'finanzaslasfinanzasson', 'unaramade', 'laadministracióny', 'de', 'laeconomíaque', 'estudia', 'el', 'intercambio', 'decapitalentreindividuos', 'empresas', 'oestadosy', 'con', 'la', 'incertidumbre', 'y', 'el', 'riesgo', 'que', 'estas', 'actividades', 'conllevan', 'se', 'dedica', 'al', 'estudio', 'de', 'la', 'obtención', 'de', 'capital', 'para', 'la', 'inversión', 'en', 'bienes', 'productivos', 'y', 'de', 'las', 'decisiones', 'de', 'inversión', 'de', 'los', 'mismo', 'su', 'estudio', 'se', 'basa', 'en', 'laobtencióny', 'laadministracióndel', 'dinero', 'para', 'lograr', 'sus', 'respectivos', 'objetivos', 'tomando', 'en', 'cuenta', 'todos', 'los', 'riesgos', 'que', 'ella', 'implica', 'basándose', 'en', 'todos', 'y', 'cada', 'uno', 'de', 'sus', 'componentes', 'que', 'la', 'integra', 'para', 'mantener', 'un', 'buen', 'finanzas', 'estudian', 'cómo', 'los', 'agentes', 'económicos', 'empresas', 'familias', 'o', 'estado', 'deben', 'tomar', 'decisiones', 'de', 'inversión', 'ahorro', 'y', 'gasto', 'en', 'condiciones', 'de', 'incertidumbre', 'al', 'momento', 'de', 'tomar', 'estas', 'decisiones', 'los', 'agentes', 'pueden', 'optar', 'por', 'diversos', 'tipos', 'de', 'recursos', 'financieros', 'tales', 'como', 'dinero', 'bonos', 'acciones', 'o', 'derivados', 'incluyendo', 'la', 'compra', 'de', 'bienes', 'de', 'capital', 'como', 'maquinarias', 'edificios', 'y', 'otras', 'infraestructuras', 'ver', 'diferencia', 'entre', 'ahorro', 'e', 'finanzas', 'va', 'ligada', 'con', 'la', 'administración', 'por', 'ejemplo', 'al', 'considerar', 'un', 'nuevo', 'producto', 'el', 'administrador', 'financiero', 'requiere', 'que', 'el', 'personal', 'de', 'finanzas', 'le', 'proporcione', 'los', 'cálculos', 'de', 'presupuesto', 'y', 'la', 'función', 'de', 'las', 'finanzas', ...

# %%
#Verificar frecuencia de palabras 
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print (str(key) + ':' + str(val))
# Out:
# finanzas:45
# wikipedia:9
# la:93
# enciclopedia:2
# wgbreakframes:1
# false:6
# wgseparatortransformtable:1
# wgdigittransformtable:1
# wgdefaultdateformat:1
# dmy:1
# wgmonthnames:1
# enero:1
# febrero:1
# marzo:1
# abril:2
# mayo:4
# junio:4
# julio:1
# agosto:1
# septiembre:2
# octubre:1
# noviembre:1
# diciembre:1
# wgrequestid:1
# wgcspnonce:1
# wgcanonicalnamespace:1
# wgcanonicalspecialpagename:1
# wgnamespacenumber:1
# wgpagename:1
# wgtitle:1
# wgcurrevisionid:1
# wgrevisionid:1
# wgarticleid:1
# wgisarticle:1
# true:14
# wgisredirect:1
# wgaction:1
# view:1
# wgusername:1
# null:1
# wgusergroups:1
# wgcategories:1
# artículos:6
# que:41
# necesitan:2
# referencias:2
# adicionales:2
# referenciar:2
# aún:2
# sin:4
# clasificar:2
# con:31
# identificadores:4
# lccn:1
# aat:1
# administración:5
# economía:14
# de:213
# empresa:10
# wgpagecontentlanguage:1
# es:16
# wgpagecontentmodel:1
# wikitext:1
# wgrelevantpagename:1
# wgrelevantarticleid:1
# wgisprobablyeditable:1
# wgrelevantpageisprobablyeditable:1
# wgrestrictionedit:1
# wgrestrictionmove:1
# wgvisualeditor:1
# pagelanguagecode:1
# pagelanguagedir:1
# ltr:1
# pagevariantfallbacks:1
# wgmfdisplaywikibasedescriptions:1
# search:1
# nearby:1
# watchlist:1
# tagline:1
# wgwmeschemaeditattemptstepoversample:1
# wgwmepagelength:1
# wgnoticeproject:1
# wgmediavieweronclick:1
# wgmediaviewerenabledbydefault:1
# wgpopupsflags:1
# wgulscurrentautonym:1
# español:1
# wgeditsubmitbuttonlabelpublish:1
# wgcentralauthmobiledomain:1
# wgulsposition:1
# interlanguage:1
# wgulsiscompactlinksenabled:1
# wgwikibaseitemid:1
# gehomepagesuggestededitsenabletopics:1
# wggetopicsmatchmodeenabled:1
# ready:12
# user:1
# loading:1
# site:1
# function:4
# jquery:1
# require:1
# module:1
# patroltoken:1
# watchtoken:1
# csrftoken:1
# finanzasde:1
# libreir:1
# a:37
# navegaciónir:1
# búsquedalas:1
# finanzaslasfinanzasson:1
# unaramade:1
# laadministracióny:1
# laeconomíaque:1
# estudia:4
# el:60
# intercambio:3
# decapitalentreindividuos:1
# empresas:7
# oestadosy:1
# incertidumbre:4
# y:70
# riesgo:3
# estas:4
# actividades:3
# conllevan:1
# se:23
# dedica:1
# al:13
# estudio:5
# obtención:3
# capital:6
# para:25
# inversión:13
# en:50
# bienes:2
# productivos:1
# las:66
# decisiones:3
# los:58
# mismo:2
# su:15
# basa:1
# laobtencióny:1
# laadministracióndel:1
# dinero:25
# lograr:1
# sus:14
# respectivos:1
# objetivos:3
# tomando:1
# cuenta:3
# todos:3
# riesgos:4
# ella:2
# implica:1
# basándose:1
# cada:4
# uno:2
# componentes:1
# integra:1
# mantener:1
# un:30
# buen:1
# estudian:2
# cómo:4
# agentes:2
# económicos:2
# familias:1
# o:18
# estado:3
# deben:3
# tomar:3
# ahorro:3
# gasto:3
# condiciones:2
# momento:2
# pueden:7
# optar:1
# por:26
# diversos:2
# tipos:3
# recursos:5
# financieros:5
# tales:3
# como:10
# bonos:2
# acciones:4
# derivados:1
# incluyendo:1
# compra:1
# maquinarias:1
# edificios:1
# otras:8
# infraestructuras:1
# ver:2
# diferencia:3
# entre:12
# e:3
# va:1
# ligada:1
# ejemplo:8
# considerar:2
# nuevo:2
# producto:1
# administrador:2
# financiero:3
# requiere:1
# personal:3
# le:3
# proporcione:1
# cálculos:1
# presupuesto:3
# función:2
# administrativas:2
# puede:3
# describirse:1
# ampliamente:1
# papel:2
# dentro:2
# organización:4
# relación:4
# contabilidad:6
# principales:1
# del:24
# relacionado:2
# lastransaccionesy:1
# ese:1
# marco:3
# gestión:2
# parte:5
# una:26
# compañía:2
# individuo:1
# propio:1
# fondos:4
# idiomasafrikaansaragonésالعربيةasturianuazərbaycancaتۆرکجهбашҡортсабеларускаябеларуская:1
# тарашкевіца:1
# melayunorsk:1
# nynorsknorsk:1
# bokmålpolskiپښتوportuguêsromânăрусскийсаха:1
# тылаsicilianuscotssrpskohrvatski:1
# српскохрватскиsimple:1
# englishslovenčinaslovenščinachishonashqipсрпски:1
# enlacesesta:1
# página:1
# editó:1
# última:1
# jun:1
# texto:1
# está:1
# disponible:1
# bajo:1
# lalicencia:1
# creative:1
# commons:1
# atribución:1
# compartir:1
# igual:1
# aplicarse:1
# cláusulas:1
# sitio:1
# usted:1
# acepta:1
# nuestrostérminos:1
# usoy:1
# nuestrapolítica:1
# marca:1
# registrada:1
# lafundación:1
# wikimedia:5
# ánimo:1
# privacidadacerca:1
# wikipedialimitación:1
# responsabilidadversión:1
# móvilesdesarrolladoresestadísticasdeclaración:1
# cookies:1
# wgpageparsereport:1
# limitreport:1
# cputime:1
# walltime:1
# ppvisitednodes:1
# value:10
# limit:10
# postexpandincludesize:1
# templateargumentsize:1
# expansiondepth:1
# expensivefunctioncount:1
# entityaccesscount:1
# timingprofile:1
# plantilla:9
# listaref:1
# trim:1
# scribunto:1
# cachereport:1
# origin:1
# timestamp:1
# ttl:1
# transientcontent:1
# context:2
# type:8
# article:2
# name:6
# url:4
# sameas:2
# http:4
# mainentity:2
# author:2
# organization:4
# colaboradores:2
# proyectos:2
# publisher:2
# foundation:2
# inc:2
# logo:2
# imageobject:2
# datepublished:2
# datemodified:2
# image:2
# headline:2
# wgbackendresponsetime:1
# wghostname:1

# %%
#Visualizar Tokens
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
freq.plot(30, cumulative=False)

# %%
from nltk.corpus import stopwords

clean_tokens = tokens[:]
 
for token in tokens:
 
    if token in stopwords.words('spanish'):
 
        clean_tokens.remove(token)

# %%
print(clean_tokens)
# Out:
# ['finanzas', 'wikipedia', 'enciclopedia', 'wgbreakframes', 'false', 'wgseparatortransformtable', 'wgdigittransformtable', 'wgdefaultdateformat', 'dmy', 'wgmonthnames', 'enero', 'febrero', 'marzo', 'abril', 'mayo', 'junio', 'julio', 'agosto', 'septiembre', 'octubre', 'noviembre', 'diciembre', 'wgrequestid', 'wgcspnonce', 'false', 'wgcanonicalnamespace', 'wgcanonicalspecialpagename', 'false', 'wgnamespacenumber', 'wgpagename', 'finanzas', 'wgtitle', 'finanzas', 'wgcurrevisionid', 'wgrevisionid', 'wgarticleid', 'wgisarticle', 'true', 'wgisredirect', 'false', 'wgaction', 'view', 'wgusername', 'null', 'wgusergroups', 'wgcategories', 'wikipedia', 'artículos', 'necesitan', 'referencias', 'adicionales', 'wikipedia', 'referenciar', 'aún', 'clasificar', 'wikipedia', 'artículos', 'identificadores', 'lccn', 'wikipedia', 'artículos', 'identificadores', 'aat', 'finanzas', 'administración', 'economía', 'empresa', 'wgpagecontentlanguage', 'wgpagecontentmodel', 'wikitext', 'wgrelevantpagename', 'finanzas', 'wgrelevantarticleid', 'wgisprobablyeditable', 'true', 'wgrelevantpageisprobablyeditable', 'true', 'wgrestrictionedit', 'wgrestrictionmove', 'wgvisualeditor', 'pagelanguagecode', 'pagelanguagedir', 'ltr', 'pagevariantfallbacks', 'wgmfdisplaywikibasedescriptions', 'search', 'true', 'nearby', 'true', 'watchlist', 'true', 'tagline', 'true', 'wgwmeschemaeditattemptstepoversample', 'false', 'wgwmepagelength', 'wgnoticeproject', 'wikipedia', 'wgmediavieweronclick', 'true', 'wgmediaviewerenabledbydefault', 'true', 'wgpopupsflags', 'wgulscurrentautonym', 'español', 'wgeditsubmitbuttonlabelpublish', 'true', 'wgcentralauthmobiledomain', 'false', 'wgulsposition', 'interlanguage', 'wgulsiscompactlinksenabled', 'true', 'wgwikibaseitemid', 'gehomepagesuggestededitsenabletopics', 'true', 'wggetopicsmatchmodeenabled', 'true', 'ready', 'ready', 'ready', 'ready', 'ready', 'user', 'ready', 'loading', 'ready', 'ready', 'ready', 'ready', 'ready', 'ready', 'site', 'function', 'function', 'jquery', 'require', 'module', 'patroltoken', 'watchtoken', 'csrftoken', 'finanzasde', 'wikipedia', 'enciclopedia', 'libreir', 'navegaciónir', 'búsquedalas', 'finanzaslasfinanzasson', 'unaramade', 'laadministracióny', 'laeconomíaque', 'estudia', 'intercambio', 'decapitalentreindividuos', 'empresas', 'oestadosy', 'incertidumbre', 'riesgo', 'actividades', 'conllevan', 'dedica', 'estudio', 'obtención', 'capital', 'inversión', 'bienes', 'productivos', 'decisiones', 'inversión', 'mismo', 'estudio', 'basa', 'laobtencióny', 'laadministracióndel', 'dinero', 'lograr', 'respectivos', 'objetivos', 'tomando', 'cuenta', 'riesgos', 'implica', 'basándose', 'cada', 'componentes', 'integra', 'mantener', 'buen', 'finanzas', 'estudian', 'cómo', 'agentes', 'económicos', 'empresas', 'familias', 'deben', 'tomar', 'decisiones', 'inversión', 'ahorro', 'gasto', 'condiciones', 'incertidumbre', 'momento', 'tomar', 'decisiones', 'agentes', 'pueden', 'optar', 'diversos', 'tipos', 'recursos', 'financieros', 'tales', 'dinero', 'bonos', 'acciones', 'derivados', 'incluyendo', 'compra', 'bienes', 'capital', 'maquinarias', 'edificios', 'infraestructuras', 'ver', 'diferencia', 'ahorro', 'finanzas', 'va', 'ligada', 'administración', 'ejemplo', 'considerar', 'nuevo', 'producto', 'administrador', 'financiero', 'requiere', 'personal', 'finanzas', 'proporcione', 'cálculos', 'presupuesto', 'función', 'finanzas', 'administrativas', 'puede', 'describirse', 'ampliamente', 'considerar', 'papel', 'dentro', 'organización', 'relación', 'economía', 'contabilidad', 'principales', 'actividades', 'administrador', 'relacionado', 'lastransaccionesy', 'administración', 'dinero', 'marco', 'estudia', 'obtención', 'gestión', 'parte', 'compañía', 'individuo', 'propio', 'fondos', 'necesita', 'cumplir', 'objetivos', 'criterios', 'dispone', 'susactivos', 'palabras', 'relativo', 'obtención', 'gestión', 'dinero', 'así', 'valores', 'sucedáneos', 'dinero', 'lostítulos', 'losbonos', 'etc', 'según', 'bodie', 'merton', 'finanzas', 'estudian', 'mane ...

# %%
from nltk.corpus import wordnet
 
synonyms = []
 
for syn in wordnet.synsets('investment'):

    for lemma in syn.lemmas():
 
        synonyms.append(lemma.name())
 
print(synonyms)
# Out:
# ['investing', 'investment', 'investment', 'investment_funds', 'investment', 'investment', 'investment', 'investment', 'investiture']

# %%
#Reemplazar tokens sinónimos
for ind,sin in enumerate(synonyms):
    clean_tokens_sin = [word.replace(synonyms[ind],'investment') for word in clean_tokens]

# %%
from nltk.stem import PorterStemmer
 
#Derivación regresiva textos en español
from nltk.stem import SnowballStemmer
 
spanish_stemmer = SnowballStemmer('spanish')
 
print(spanish_stemmer.stem("trabajando"))
print(spanish_stemmer.stem("trabajo"))
stemmer = PorterStemmer()
clean_tokens_sin_stems = [spanish_stemmer.stem(token) for token in clean_tokens_sin]
# Out:
# trabaj
# trabaj

# %%
import spacy
nlp = spacy.blank('es')
#Lematizar tokens tras limpieza y convertidos los sinónimos
clean_tokens_sin_lem = []
separator = ' '
for token in nlp(separator.join(clean_tokens_sin)): #Se juntan los tokens en una string, string es el formato necesario para nlp
    print(token.text, token.lemma_, token.pos_)
    clean_tokens_sin_lem.append(token.lemma_)
# Out:
# finanzas finanzas
# wikipedia wikipedia
# enciclopedia enciclopedia
# wgbreakframes wgbreakframes
# false false
# wgseparatortransformtable wgseparatortransformtable
# wgdigittransformtable wgdigittransformtable
# wgdefaultdateformat wgdefaultdateformat
# dmy dmy
# wgmonthnames wgmonthnames
# enero enero
# febrero febrero
# marzo marzo
# abril abril
# mayo mayo
# junio junio
# julio julio
# agosto agosto
# septiembre septiembre
# octubre octubre
# noviembre noviembre
# diciembre diciembre
# wgrequestid wgrequestid
# wgcspnonce wgcspnonce
# false false
# wgcanonicalnamespace wgcanonicalnamespace
# wgcanonicalspecialpagename wgcanonicalspecialpagename
# false false
# wgnamespacenumber wgnamespacenumber
# wgpagename wgpagename
# finanzas finanzas
# wgtitle wgtitle
# finanzas finanzas
# wgcurrevisionid wgcurrevisionid
# wgrevisionid wgrevisionid
# wgarticleid wgarticleid
# wgisarticle wgisarticle
# true true
# wgisredirect wgisredirect
# false false
# wgaction wgaction
# view view
# wgusername wgusername
# null null
# wgusergroups wgusergroups
# wgcategories wgcategories
# wikipedia wikipedia
# artículos artículos
# necesitan necesitan
# referencias referencias
# adicionales adicionales
# wikipedia wikipedia
# referenciar referenciar
# aún aún
# clasificar clasificar
# wikipedia wikipedia
# artículos artículos
# identificadores identificadores
# lccn lccn
# wikipedia wikipedia
# artículos artículos
# identificadores identificadores
# aat aat
# finanzas finanzas
# administración administración
# economía economía
# empresa empresa
# wgpagecontentlanguage wgpagecontentlanguage
# wgpagecontentmodel wgpagecontentmodel
# wikitext wikitext
# wgrelevantpagename wgrelevantpagename
# finanzas finanzas
# wgrelevantarticleid wgrelevantarticleid
# wgisprobablyeditable wgisprobablyeditable
# true true
# wgrelevantpageisprobablyeditable wgrelevantpageisprobablyeditable
# true true
# wgrestrictionedit wgrestrictionedit
# wgrestrictionmove wgrestrictionmove
# wgvisualeditor wgvisualeditor
# pagelanguagecode pagelanguagecode
# pagelanguagedir pagelanguagedir
# ltr ltr
# pagevariantfallbacks pagevariantfallbacks
# wgmfdisplaywikibasedescriptions wgmfdisplaywikibasedescriptions
# search search
# true true
# nearby nearby
# true true
# watchlist watchlist
# true true
# tagline tagline
# true true
# wgwmeschemaeditattemptstepoversample wgwmeschemaeditattemptstepoversample
# false false
# wgwmepagelength wgwmepagelength
# wgnoticeproject wgnoticeproject
# wikipedia wikipedia
# wgmediavieweronclick wgmediavieweronclick
# true true
# wgmediaviewerenabledbydefault wgmediaviewerenabledbydefault
# true true
# wgpopupsflags wgpopupsflags
# wgulscurrentautonym wgulscurrentautonym
# español español
# wgeditsubmitbuttonlabelpublish wgeditsubmitbuttonlabelpublish
# true true
# wgcentralauthmobiledomain wgcentralauthmobiledomain
# false false
# wgulsposition wgulsposition
# interlanguage interlanguage
# wgulsiscompactlinksenabled wgulsiscompactlinksenabled
# true true
# wgwikibaseitemid wgwikibaseitemid
# gehomepagesuggestededitsenabletopics gehomepagesuggestededitsenabletopics
# true true
# wggetopicsmatchmodeenabled wggetopicsmatchmodeenabled
# true true
# ready ready
# ready ready
# ready ready
# ready ready
# ready ready
# user user
# ready ready
# loading loading
# ready ready
# ready ready
# ready ready
# ready ready
# ready ready
# ready ready
# site site
# function function
# function function
# jquery jquery
# require require
# module module
# patroltoken patroltoken
# watchtoken watchtoken
# csrftoken csrftoken
# finanzasde finanzasde
# wikipedia wikipedia
# enciclopedia enciclopedia
# libreir libreir
# navegaciónir navegaciónir
# búsquedalas búsquedalas
# finanzaslasfinanzasson finanzaslasfinanzasson
# unaramade unaramade
# laadministracióny laadministracióny
# laeconomíaque laeconomíaque
# estudia estudia
# intercambio intercambio
# decapitalentreindividuos decapitalentreindividuos
# empresas empresas
# oestadosy oestadosy
# incertidumbre incertidumbre
# riesgo riesgo
# actividades actividades
# conllevan conllevan
# dedica dedica
# estudio estudio
# obtención obtención
# capital capital
# inversión inversión
# bienes bienes
# productivos productivos
# decisiones decisiones
# inversión inversión
# mismo mismo
# estudio estudio
# basa basa
# laobtencióny laobtencióny
# laadministracióndel laadministracióndel
# dinero dinero
# lograr lograr
# respectivos respectivos
# objetivos objetivos
# tomando tomando
# cuenta cuenta
# riesgos riesgos
# implica implica
# basándose basándose
# cada cada
# componentes componentes
# integra integra
# mantener mantener
# buen buen
# finanzas finanzas
# estudian estudian
# cómo cómo
# agentes agentes
# económicos económicos
# empresas empresas
# familias familias
# deben deben
# tomar tomar
# decisiones decisiones
# inversión inversión
# ahorro ahorro
# gasto gasto
# condiciones condiciones
# incertidumbre incertidumbre
# momento momento
# tomar tomar
# decisiones decisiones
# agentes agentes
# pueden pueden
# optar optar
# diversos diversos
# tipos tipos
# recursos recursos
# financieros financieros
# tales tales
# dinero dinero
# bonos bonos
# acciones acciones
# derivados derivados
# incluyendo incluyendo
# compra compra
# bienes bienes
# capital capital
# maquinarias maquinarias
# edificios edificios
# infraestructuras infraestructuras
# ver ver
# diferencia diferencia
# ahorro ahorro
# finanzas finanzas
# va va
# ligada ligada
# administración administración
# ejemplo ejemplo
# considerar considerar
# nuevo nuevo
# producto producto
# administrador administrador
# financiero financiero
# requiere requiere
# personal personal
# finanzas finanzas
# proporcione proporcione
# cálculos cálculos
# presupuesto presupuesto
# función función
# finanzas finanzas
# administrativas administrativas
# puede puede
# describirse describirse
# ampliamente ampliamente
# considerar considerar
# papel papel
# dentro dentro
# organización organización
# relación relación
# economía economía
# contabilidad contabilidad
# principales principales
# actividades actividades
# administrador administrador
# relacionado relacionado
# lastransaccionesy lastransaccionesy
# administración administración
# dinero dinero
# marco marco
# estudia estudia
# obtención obtención
# gestión gestión
# parte parte
# compañía compañía
# individuo individuo
# propio propio
# fondos fondos
# necesita necesita
# cumplir cumplir
# objetivos objetivos
# criterios criterios
# dispone dispone
# susactivos susactivos
# palabras palabras
# relativo relativo
# obtención obtención
# gestión gestión
# dinero dinero
# así así
# valores valores
# sucedáneos sucedáneos
# dinero dinero
# lostítulos lostítulos
# losbonos losbonos
# etc etc
# según según
# bodie bodie
# merton merton
# finanzas finanzas
# estudian estudian
# manera manera
# losrecursosescasos losrecursosescasos
# asignan asignan
# través través
# tiempo tiempo
# finanzas finanzas
# tratan tratan
# condiciones condiciones
# oportunidad oportunidad
# consigue consigue
# capital capital
# usos usos
# retornos retornos
# inversionista inversionista
# obtiene obtiene
# inversiones inversiones
# estudio estudio
# académico académico
# finanzas finanzas
# divide divide
# principalmente principalmente
# dos dos
# ramas ramas
# reflejan reflejan
# posiciones posiciones
# respectivas respectivas
# aquel aquel
# necesita necesita
# fondos fondos
# dinero dinero
# realizar realizar
# inversión inversión
# llamadafinanzas llamadafinanzas
# corporativas corporativas
# aquel aquel
# quiere quiere
# invertir invertir
# dinero dinero
# dándoselo dándoselo
# alguien alguien
# quiera quiera
# usar usar
# invertir invertir
# llamadavaluación llamadavaluación
# activos activos
# área área
# finanzas finanzas
# corporativas corporativas
# estudia estudia
# cómo cómo
# conviene conviene
# inversionista inversionista
# conseguir conseguir
# dinero dinero
# ejemplo ejemplo
# si si
# vendiendo vendiendo
# acciones acciones
# pidiendo pidiendo
# prestado prestado
# banco banco
# vendiendo vendiendo
# deuda deuda
# mercado mercado
# área área
# valuación valuación
# activos activos
# estudia estudia
# cómo cómo
# conviene conviene
# inversionista inversionista
# invertir invertir
# dinero dinero
# ejemplo ejemplo
# si si
# comprando comprando
# acciones acciones
# deuda deuda
# acumulado acumulado
# dinero dinero
# efectivo efectivo
# dos dos
# ramas ramas
# finanzas finanzas
# dividen dividen
# áreas áreas
# populares populares
# dentro dentro
# estudio estudio
# finanzas finanzas
# intermediación intermediación
# financiera financiera
# finanzas finanzas
# conductistas conductistas
# microestructura microestructura
# mercados mercados
# financieros financieros
# desarrollo desarrollo
# financiero financiero
# finanzas finanzas
# internacionales internacionales
# finanzas finanzas
# consumidor consumidor
# disciplina disciplina
# recientemente recientemente
# creada creada
# neurofinanzas neurofinanzas
# rama rama
# laneuroeconomía laneuroeconomía
# encargada encargada
# estudio estudio
# sesgos sesgos
# relacionados relacionados
# manejo manejo
# economía economía
# finanzas finanzas
# personales personales
# aplicación aplicación
# finanzas finanzas
# principios principios
# persona persona
# familia familia
# deseo deseo
# realizar realizar
# actividades actividades
# mejor mejor
# distribución distribución
# dinero dinero
# ello ello
# así así
# deben deben
# reconocer reconocer
# cómo cómo
# ocupar ocupar
# ingresos ingresos
# educación educación
# salud salud
# alimentación alimentación
# vestimenta vestimenta
# seguros seguros
# lujos lujos
# transporte transporte
# deben deben
# tener tener
# cuenta cuenta
# ingresos ingresos
# gastos gastos
# ahorros ahorros
# siempre siempre
# estableciendo estableciendo
# riesgos riesgos
# eventos eventos
# futuros futuros
# parte parte
# finanzas finanzas
# personales personales
# cheques cheques
# cuentas cuentas
# ahorro ahorro
# tarjetas tarjetas
# crédito crédito
# préstamos préstamos
# inversiones inversiones
# mercado mercado
# valores valores
# planes planes
# jubilación jubilación
# impuestos impuestos
# clave clave
# editar editar
# artículo artículo
# sección sección
# tienereferencias tienereferencias
# necesita necesita
# complementar complementar
# aviso aviso
# puesto puesto
# mayo mayo
# inversores inversores
# actúan actúan
# diferentes diferentes
# mercados mercados
# intentando intentando
# obtener obtener
# mayor mayor
# rendimiento rendimiento
# dinero dinero
# vez vez
# pretenden pretenden
# minimizar minimizar
# riesgo riesgo
# inversión inversión
# mercado mercado
# capitales capitales
# ofrece ofrece
# cada cada
# momento momento
# frontera frontera
# eficiente eficiente
# relaciona relaciona
# determinada determinada
# rentabilidad rentabilidad
# determinado determinado
# nivel nivel
# riesgo riesgo
# volatilidad volatilidad
# inversor inversor
# obtiene obtiene
# mayor mayor
# rentabilidad rentabilidad
# esperada esperada
# cambio cambio
# soportar soportar
# mayor mayor
# incertidumbre incertidumbre
# precio precio
# incertidumbre incertidumbre
# diferencia diferencia
# rentabilidad rentabilidad
# inversión inversión
# tipo tipo
# interés interés
# aquellos aquellos
# valores valores
# consideran consideran
# seguros seguros
# diferencia diferencia
# conocemos conocemos
# prima prima
# valor valor
# dinero dinero
# tiempo tiempo
# misma misma
# cantidad cantidad
# dinero dinero
# inversor inversor
# prefiere prefiere
# disponer disponer
# presente presente
# futuro futuro
# ello ello
# transvase transvase
# intertemporal intertemporal
# dinero dinero
# cuenta cuenta
# factor factor
# descuento descuento
# si si
# intercambiamos intercambiamos
# renta renta
# futura futura
# capital capital
# presente presente
# ejemplo ejemplo
# préstamo préstamo
# hipotecario hipotecario
# rentabilidad rentabilidad
# si si
# ìntercambiamos ìntercambiamos
# renta renta
# presente presente
# renta renta
# futura futura
# ejemplo ejemplo
# plan plan
# pensiones pensiones
# interés interés
# representa representa
# tasa tasa
# intercambio intercambio
# precio precio
# dinero dinero
# día día
# hoy hoy
# términos términos
# dinero dinero
# españa españa
# tasa tasa
# interés interés
# conocida conocida
# tipo tipo
# tasa tasa
# interés interés
# afecta afecta
# directamente directamente
# consumo consumo
# comercio comercio
# inversión inversión
# pues pues
# parte parte
# consumo consumo
# paga paga
# mediante mediante
# tarjetas tarjetas
# crédito crédito
# parte parte
# mercancía mercancía
# comprada comprada
# vendida vendida
# comercios comercios
# comprada comprada
# crédito crédito
# inversiones inversiones
# siempre siempre
# apoyan apoyan
# préstamos préstamos
# bancarios bancarios
# emisión emisión
# deuda deuda
# mediante mediante
# bonos bonos
# subir subir
# tasa tasa
# interés interés
# consumo consumo
# inversión inversión
# disminuyen disminuyen
# pues pues
# individuos individuos
# empresas empresas
# encuentran encuentran
# difícil difícil
# pagar pagar
# deudas deudas
# bajar bajar
# tasa tasa
# interés interés
# consumo consumo
# inversión inversión
# aumentan aumentan
# estímulo estímulo
# representa representa
# pagar pagar
# menos menos
# intereses intereses
# relación relación
# tasa tasa
# interés interés
# consumo consumo
# inversión inversión
# utilizada utilizada
# diseñadores diseñadores
# políticas políticas
# macroeconómicas macroeconómicas
# manipularlos manipularlos
# afectar afectar
# crecimiento crecimiento
# económico económico
# empleo empleo
# inflación inflación
# disminuir disminuir
# inflación inflación
# inducen inducen
# aumento aumento
# tasas tasas
# interés interés
# quieren quieren
# aumentar aumentar
# empleo empleo
# inducen inducen
# disminución disminución
# tales tales
# acciones acciones
# usualmente usualmente
# llevadas llevadas
# cabo cabo
# mediante mediante
# banco banco
# central central
# cada cada
# país país
# establecer establecer
# llamada llamada
# tasa tasa
# descuento descuento
# tasa tasa
# interés interés
# presta presta
# dinero dinero
# bancos bancos
# cambio cambio
# tasa tasa
# descuento descuento
# impacta impacta
# costos costos
# dinero dinero
# bancos bancos
# impacta impacta
# tasa tasa
# interés interés
# tales tales
# bancos bancos
# cobran cobran
# relación relación
# entreliquidezeinversión entreliquidezeinversión
# necesidad necesidad
# contar contar
# dinero dinero
# líquido líquido
# intercambio intercambio
# porbienes porbienes
# servicioscomo servicioscomo
# realizar realizar
# inversión inversión
# hace hace
# mercado mercado
# propiaofertaydemanda propiaofertaydemanda
# propios propios
# costes costes
# oportunidad oportunidad
# hace hace
# referencia referencia
# sacrificio sacrificio
# debe debe
# hacer hacer
# cualquier cualquier
# agente agente
# participe participe
# mercado mercado
# decidir decidir
# prescindir prescindir
# consumo consumo
# inversión inversión
# emplear emplear
# recursos recursos
# siendo siendo
# definiciónescasos definiciónescasos
# proceso proceso
# económico económico
# consiste consiste
# aumento aumento
# continuo continuo
# precios precios
# mayor mayor
# parte parte
# productos productos
# servicios servicios
# pérdida pérdida
# valor valor
# dinero dinero
# poder poder
# adquirir adquirir
# esosbienes esosbienes
# servicios servicios
# inflación inflación
# impacta impacta
# principalmente principalmente
# economía economía
# país país
# nuevo nuevo
# costo costo
# vida vida
# inflación inflación
# impacto impacto
# directo directo
# tasa tasa
# interés interés
# puesto puesto
# inflación inflación
# reduce reduce
# valor valor
# dinero dinero
# mayor mayor
# inflación inflación
# mayor mayor
# tasa tasa
# interés interés
# necesaria necesaria
# compensar compensar
# ahorrador ahorrador
# prestar prestar
# dinero dinero
# editar editar
# varias varias
# fuentes fuentes
# finanzas finanzas
# deudas deudas
# obligaciones obligaciones
# utilidades utilidades
# brutas brutas
# préstamos préstamos
# largos largos
# plazos plazos
# capital capital
# préstamo préstamo
# tarjetas tarjetas
# créditos créditos
# fondos fondos
# riesgos riesgos
# laborales laborales
# fuentes fuentes
# financieras financieras
# útiles útiles
# diferentes diferentes
# situaciones situaciones
# pueden pueden
# clasificarse clasificarse
# base base
# tiempo tiempo
# control control
# empresa empresa
# puede puede
# elegir elegir
# fuentes fuentes
# financiación financiación
# alternativa alternativa
# elección elección
# debe debe
# ser ser
# correcta correcta
# adecuada adecuada
# supone supone
# gran gran
# reto reto
# gerentes gerentes
# finanzas finanzas
# empresas empresas
# proceso proceso
# selección selección
# debe debe
# ser ser
# analizado analizado
# comprender comprender
# todas todas
# características características
# cada cada
# base base
# necesite necesite
# empresa empresa
# conocer conocer
# fuentes fuentes
# financiación financiación
# necesario necesario
# saber saber
# cuáles cuáles
# clasificaciones clasificaciones
# finanzas finanzas
# finanzas finanzas
# clasifican clasifican
# dos dos
# ramas ramas
# finanzas finanzas
# públicas públicas
# privadas privadas
# editar editar
# básicamente básicamente
# tipo tipo
# finanzas finanzas
# trata trata
# optimización optimización
# finanzas finanzas
# nivel nivel
# personal personal
# familia familia
# ahorros ahorros
# personales personales
# sometidas sometidas
# presupuesto presupuesto
# ejemplo ejemplo
# persona persona
# puede puede
# financiar financiar
# vehículo vehículo
# cualquier cualquier
# banco banco
# finanza finanza
# privada privada
# planificación planificación
# financiera financiera
# nivel nivel
# individual individual
# trata trata
# utilización utilización
# recursos recursos
# monetarios monetarios
# personal personal
# familiar familiar
# considerando considerando
# acontecimientos acontecimientos
# futuros futuros
# riesgos riesgos
# asociados asociados
# finanzas finanzas
# privadas privadas
# incluyen incluyen
# cuentas cuentas
# deahorroriesgos deahorroriesgos
# laboralesplanes laboralesplanes
# retirospréstamos retirospréstamos
# personalesinversiones personalesinversiones
# mercado mercado
# valoresgestión valoresgestión
# impuestostarjetas impuestostarjetas
# créditofinanzas créditofinanzas
# públicas públicas
# editar editar
# finanza finanza
# encargada encargada
# tratar tratar
# optimizar optimizar
# objetivos objetivos
# económicos económicos
# inversión inversión
# pib pib
# déficit déficit
# superávit superávit
# mediante mediante
# estimación estimación
# necesidades necesidades
# futuras futuras
# asignación asignación
# fondos fondos
# acuerdo acuerdo
# disponibilidad disponibilidad
# finanzas finanzas
# públicas públicas
# constituyen constituyen
# rama rama
# economía economía
# ayuda ayuda
# examinar examinar
# consecuencias consecuencias
# diferentes diferentes
# tipos tipos
# inversiones inversiones
# impuestos impuestos
# gastos gastos
# empleados empleados
# empresas empresas
# estatales estatales
# gobiernos gobiernos
# analiza analiza
# eficacia eficacia
# procedimientos procedimientos
# desarrollo desarrollo
# técnico técnico
# empresa empresa
# finanzas finanzas
# públicas públicas
# encargan encargan
# provisiones provisiones
# necesarias necesarias
# nivel nivel
# comercio comercio
# empresa empresa
# necesita necesita
# constantemente constantemente
# capital capital
# base base
# diferentes diferentes
# inversiones inversiones
# corto corto
# plazo plazo
# editar editar
# largo largo
# plazo plazo
# editar editar
# mediano mediano
# plazo plazo
# editar editar
# inversiones inversiones
# corto corto
# plazo plazo
# utilizan utilizan
# satisfacer satisfacer
# necesidades necesidades
# actuales actuales
# empresa empresa
# inversiones inversiones
# largo largo
# plazo plazo
# utilizadas utilizadas
# adquisición adquisición
# activos activos
# fijos fijos
# empresa empresa
# ejemplo ejemplo
# tierras tierras
# maquinaria maquinaria
# inversiones inversiones
# mediano mediano
# plazo plazo
# incluyen incluyen
# utilidades utilidades
# retenidas retenidas
# ejemplo ejemplo
# préstamos préstamos
# temporales temporales
# cambios cambios
# empresa empresa
# ramas ramas
# finanzas finanzas
# públicas públicas
# ingresos ingresos
# ingresos ingresos
# obtenidos obtenidos
# gobierno gobierno
# través través
# impuestos impuestos
# impuestos impuestos
# renta renta
# derecho derecho
# importación importación
# fuentes fuentes
# tributarias tributarias
# multas multas
# honorarios honorarios
# públicos públicos
# diferentes diferentes
# tipos tipos
# gastos gastos
# incurre incurre
# gobierno gobierno
# empresa empresa
# correcto correcto
# pública pública
# gasto gasto
# público público
# gobierno gobierno
# excede excede
# ingresos ingresos
# gobierno gobierno
# toma toma
# prestado prestado
# continuar continuar
# correcto correcto
# presupuesto presupuesto
# utilizado utilizado
# determinar determinar
# gastos gastos
# gobierno gobierno
# mismo mismo
# hace hace
# forma forma
# fiscal fiscal
# editar editar
# política política
# fiscal fiscal
# ver ver
# marco marco
# político político
# gobierno gobierno
# después después
# tomar tomar
# consideración consideración
# gasto gasto
# público público
# vías vías
# ingresos ingresos
# gobierno gobierno
# finanzas finanzas
# juegan juegan
# papel papel
# fundamental fundamental
# organización organización
# gobierno gobierno
# empresa empresa
# correcta correcta
# organización organización
# gastos gastos
# pueden pueden
# elevarse elevarse
# tal tal
# manera manera
# deuda deuda
# pública pública
# crezca crezca
# convertirse convertirse
# deuda deuda
# auxiliares auxiliares
# editar editar
# especialidad especialidad
# financiera financiera
# vínculo vínculo
# ciencias ciencias
# diversas diversas
# teorías teorías
# económicas económicas
# administrativas administrativas
# economía economía
# finanzas finanzas
# gran gran
# conocimiento conocimiento
# común común
# finanzas finanzas
# pueden pueden
# ser ser
# rama rama
# economía economía
# así así
# administración administración
# concepto concepto
# administración administración
# financiera financiera
# finanzas finanzas
# públicas públicas
# economía economía
# materia materia
# aledaña aledaña
# finanzas finanzas
# contabilidad contabilidad
# método método
# registro registro
# contable contable
# produce produce
# información información
# acomodada acomodada
# estructurada estructurada
# llamados llamados
# financieros financieros
# finanzas finanzas
# bien bien
# pueden pueden
# relacionadas relacionadas
# matemáticas matemáticas
# llamadas llamadas
# matemáticas matemáticas
# financieras financieras
# otorgan otorgan
# bases bases
# cálculo cálculo
# necesarias necesarias
# solucionar solucionar
# diversos diversos
# situaciones situaciones
# financieras financieras
# valor valor
# dinero dinero
# proceso proceso
# estimación estimación
# posibilidades posibilidades
# ocurrencia ocurrencia
# finanzas finanzas
# relación relación
# derecho derecho
# método método
# financiero financiero
# soporte soporte
# comulgo comulgo
# reglas reglas
# normas normas
# leyes leyes
# encuentra encuentra
# marco marco
# legal legal
# operan operan
# economía economía
# finanzas finanzas
# conjunto conjunto
# economía economía
# función función
# administrar administrar
# recursos recursos
# escasos escasos
# deseos deseos
# ilimitados ilimitados
# necesidades necesidades
# superiores superiores
# casos casos
# recursos recursos
# contabilidad contabilidad
# contabilidad contabilidad
# posee posee
# técnica técnica
# ocupa ocupa
# registrar registrar
# resumir resumir
# operaciones operaciones
# mercantiles mercantiles
# negocio negocio
# fin fin
# interpretar interpretar
# resultados resultados
# consiguiente consiguiente
# gerentes gerentes
# directores directores
# través través
# contabilidad contabilidad
# pueden pueden
# orientarse orientarse
# curso curso
# siguen siguen
# negocios negocios
# mediante mediante
# datos datos
# contables contables
# estadísticos estadísticos
# datos datos
# permiten permiten
# conocer conocer
# estabilidad estabilidad
# solvencia solvencia
# compañía compañía
# corriente corriente
# cobros cobros
# pagos pagos
# tendencias tendencias
# ventas ventas
# costos costos
# gastos gastos
# generales generales
# manera manera
# pueda pueda
# conocer conocer
# capacidad capacidad
# financiera financiera
# matemáticas matemáticas
# matemática matemática
# financiera financiera
# campo campo
# matemáticas matemáticas
# aplicadas aplicadas
# analiza analiza
# valora valora
# calcula calcula
# materias materias
# relacionadas relacionadas
# mercados mercados
# financieros financieros
# especial especial
# valor valor
# dinero dinero
# tiempo tiempo
# así así
# matemáticas matemáticas
# financieras financieras
# ocuparán ocuparán
# cálculo cálculo
# valor valor
# tasas tasas
# interés interés
# rentabilidad rentabilidad
# distintos distintos
# productos productos
# existen existen
# mercados mercados
# financieros financieros
# editar editar
# portal portal
# economía economía
# contenido contenido
# relacionado relacionado
# editar editar
# copia copia
# archivada archivada
# archivado archivado
# desdeel desdeel
# originalel originalel
# junio junio
# consultado consultado
# junio junio
# economía economía
# finanzas finanzas
# públicas públicas
# república república
# zvi zvi
# robert robert
# merton merton
# finanzas finanzas
# pearson pearson
# educación educación
# society society
# for for
# financial financial
# studies studies
# junio junio
# fabian fabian
# mayo mayo
# importancia importancia
# departamento departamento
# contabilidad contabilidad
# economía economía
# fácil fácil
# consultado consultado
# mayo mayo
# gissela gissela
# abril abril
# razones razones
# financieras financieras
# interpretación interpretación
# ejemplos ejemplos
# fórmulas fórmulas
# economía economía
# fácil fácil
# consultado consultado
# septiembre septiembre
# padilla padilla
# victor victor
# i i
# finanzas finanzas
# grupo grupo
# editorial editorial
# parra parra
# hr hr
# display display
# none none
# display display
# none none
# display display
# flex flex
# solid solid
# color color
# ul ul
# li li
# control control
# autoridadesproyectos autoridadesproyectos
# wikimediadatos wikimediadatos
# financeidentificadoreslccn financeidentificadoreslccn
# enciclopediasbritannica enciclopediasbritannica
# urldatos urldatos
# financeobtenido financeobtenido
# https https
# categorías categorías
# finanzasadministracióneconomía finanzasadministracióneconomía
# empresacategorías empresacategorías
# ocultas ocultas
# wikipedia wikipedia
# artículos artículos
# necesitan necesitan
# referencias referencias
# adicionaleswikipedia adicionaleswikipedia
# referenciar referenciar
# aún aún
# clasificar clasificar
# wikipedia wikipedia
# artículos artículos
# identificadores identificadores
# lccnwikipedia lccnwikipedia
# artículos artículos
# identificadores identificadores
# aatmenú aatmenú
# navegaciónherramientas navegaciónherramientas
# personalesno personalesno
# accedidodiscusióncontribucionescrear accedidodiscusióncontribucionescrear
# cuentaaccederespacios cuentaaccederespacios
# nombresartículodiscusiónespañolvistasleereditarver nombresartículodiscusiónespañolvistasleereditarver
# historialmásbuscarnavegaciónportadaportal historialmásbuscarnavegaciónportadaportal
# comunidadactualidadcambios comunidadactualidadcambios
# recientespáginas recientespáginas
# nuevaspágina nuevaspágina
# aleatoriaayudadonacionesnotificar aleatoriaayudadonacionesnotificar
# errorherramientaslo errorherramientaslo
# enlaza enlaza
# aquícambios aquícambios
# enlazadassubir enlazadassubir
# archivopáginas archivopáginas
# especialesenlace especialesenlace
# permanenteinformación permanenteinformación
# páginacitar páginacitar
# páginaelemento páginaelemento
# librodescargar librodescargar
# pdfversión pdfversión
# imprimiren imprimiren
# proyectoswikimedia proyectoswikimedia
# commonsen commonsen
# idiomasafrikaansaragonésالعربيةasturianuazərbaycancaتۆرکجهбашҡортсабеларускаябеларуская idiomasafrikaansaragonésالعربيةasturianuazərbaycancaتۆرکجهбашҡортсабеларускаябеларуская
# тарашкевіца тарашкевіца
# melayunorsk melayunorsk
# nynorsknorsk nynorsknorsk
# bokmålpolskiپښتوportuguêsromânăрусскийсаха bokmålpolskiپښتوportuguêsromânăрусскийсаха
# тылаsicilianuscotssrpskohrvatski тылаsicilianuscotssrpskohrvatski
# српскохрватскиsimple српскохрватскиsimple
# englishslovenčinaslovenščinachishonashqipсрпски englishslovenčinaslovenščinachishonashqipсрпски
# enlacesesta enlacesesta
# página página
# editó editó
# última última
# vez vez
# jun jun
# texto texto
# disponible disponible
# bajo bajo
# lalicencia lalicencia
# creative creative
# commons commons
# atribución atribución
# compartir compartir
# igual igual
# pueden pueden
# aplicarse aplicarse
# cláusulas cláusulas
# adicionales adicionales
# usar usar
# sitio sitio
# usted usted
# acepta acepta
# nuestrostérminos nuestrostérminos
# usoy usoy
# nuestrapolítica nuestrapolítica
# marca marca
# registrada registrada
# lafundación lafundación
# wikimedia wikimedia
# organización organización
# ánimo ánimo
# privacidadacerca privacidadacerca
# wikipedialimitación wikipedialimitación
# responsabilidadversión responsabilidadversión
# móvilesdesarrolladoresestadísticasdeclaración móvilesdesarrolladoresestadísticasdeclaración
# cookies cookies
# function function
# wgpageparsereport wgpageparsereport
# limitreport limitreport
# cputime cputime
# walltime walltime
# ppvisitednodes ppvisitednodes
# value value
# limit limit
# postexpandincludesize postexpandincludesize
# value value
# limit limit
# templateargumentsize templateargumentsize
# value value
# limit limit
# expansiondepth expansiondepth
# value value
# limit limit
# expensivefunctioncount expensivefunctioncount
# value value
# limit limit
# value value
# limit limit
# value value
# limit limit
# entityaccesscount entityaccesscount
# value value
# limit limit
# timingprofile timingprofile
# plantilla plantilla
# plantilla plantilla
# plantilla plantilla
# listaref listaref
# plantilla plantilla
# aviso aviso
# plantilla plantilla
# plantilla plantilla
# plantilla plantilla
# plantilla plantilla
# trim trim
# plantilla plantilla
# portal portal
# scribunto scribunto
# value value
# limit limit
# value value
# limit limit
# cachereport cachereport
# origin origin
# timestamp timestamp
# ttl ttl
# transientcontent transientcontent
# true true
# context context
# https https
# type type
# article article
# name name
# finanzas finanzas
# url url
# https https
# sameas sameas
# http http
# mainentity mainentity
# http http
# author author
# type type
# organization organization
# name name
# colaboradores colaboradores
# proyectos proyectos
# wikimedia wikimedia
# publisher publisher
# type type
# organization organization
# name name
# wikimedia wikimedia
# foundation foundation
# inc inc
# logo logo
# type type
# imageobject imageobject
# url url
# https https
# datepublished datepublished
# datemodified datemodified
# image image
# https https
# headline headline
# rama rama
# empresas empresas
# context context
# https https
# type type
# article article
# name name
# finanzas finanzas
# url url
# https https
# sameas sameas
# http http
# mainentity mainentity
# http http
# author author
# type type
# organization organization
# name name
# colaboradores colaboradores
# proyectos proyectos
# wikimedia wikimedia
# publisher publisher
# type type
# organization organization
# name name
# wikimedia wikimedia
# foundation foundation
# inc inc
# logo logo
# type type
# imageobject imageobject
# url url
# https https
# datepublished datepublished
# datemodified datemodified
# image image
# https https
# headline headline
# rama rama
# empresas empresas
# function function
# wgbackendresponsetime wgbackendresponsetime
# wghostname wghostname

# %%
# Recalcular frecuencia de palabras con sinónimos agregados
freq_clean_sin_lem = nltk.FreqDist(clean_tokens_sin_lem)
for key,val in freq_clean_sin_lem.items():
    print (str(key) + ':' + str(val))
    
#Visualizar Tokens
freq_clean_sin_lem.plot(30, cumulative=False)
# Out:
# finanzas:45
# wikipedia:9
# enciclopedia:2
# wgbreakframes:1
# false:6
# wgseparatortransformtable:1
# wgdigittransformtable:1
# wgdefaultdateformat:1
# dmy:1
# wgmonthnames:1
# enero:1
# febrero:1
# marzo:1
# abril:2
# mayo:4
# junio:4
# julio:1
# agosto:1
# septiembre:2
# octubre:1
# noviembre:1
# diciembre:1
# wgrequestid:1
# wgcspnonce:1
# wgcanonicalnamespace:1
# wgcanonicalspecialpagename:1
# wgnamespacenumber:1
# wgpagename:1
# wgtitle:1
# wgcurrevisionid:1
# wgrevisionid:1
# wgarticleid:1
# wgisarticle:1
# true:14
# wgisredirect:1
# wgaction:1
# view:1
# wgusername:1
# null:1
# wgusergroups:1
# wgcategories:1
# artículos:6
# necesitan:2
# referencias:2
# adicionales:2
# referenciar:2
# aún:2
# clasificar:2
# identificadores:4
# lccn:1
# aat:1
# administración:5
# economía:14
# empresa:10
# wgpagecontentlanguage:1
# wgpagecontentmodel:1
# wikitext:1
# wgrelevantpagename:1
# wgrelevantarticleid:1
# wgisprobablyeditable:1
# wgrelevantpageisprobablyeditable:1
# wgrestrictionedit:1
# wgrestrictionmove:1
# wgvisualeditor:1
# pagelanguagecode:1
# pagelanguagedir:1
# ltr:1
# pagevariantfallbacks:1
# wgmfdisplaywikibasedescriptions:1
# search:1
# nearby:1
# watchlist:1
# tagline:1
# wgwmeschemaeditattemptstepoversample:1
# wgwmepagelength:1
# wgnoticeproject:1
# wgmediavieweronclick:1
# wgmediaviewerenabledbydefault:1
# wgpopupsflags:1
# wgulscurrentautonym:1
# español:1
